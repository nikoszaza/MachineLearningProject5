# %% [markdown]
# # Crete AirBNB

# %%
import pandas as pd
import nltk
import numpy as np
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from gensim.utils import simple_preprocess
from keras.preprocessing import sequence
nltk.download('vader_lexicon')

analyzer = SentimentIntensityAnalyzer()
df = pd.read_csv("reviews.csv")
df.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\zazat\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       27966   495260  2011-09-02       730165          Maja
# 1       27966  1088520  2012-04-06      1463423       Russell
# 2       27966  1638334  2012-07-05      2761210       Jessica
# 3       27966  1884289  2012-08-04      2814925          Paul
# 4       27966  1972549  2012-08-13      3039803       Lavinia
#
#                                             comments
# 0  Manolis and his family were wonderful hosta. I...
# 1  Nice apartment. Manolis and his family are lov...
# 2  Antonia was a fantastic host! She will no doub...
# 3  Manolis has an excellent apartment in Amoudara...
# 4  Everything was wonderful! The weather, beach, ...

# %% [markdown]
# ## Data preprocessing

# %%
labels = []
comments = df["comments"].convert_dtypes()
for i in range(len(df)):
    try:
        pol_score = analyzer.polarity_scores(comments[i])
    except:
        labels.append(-1)
    else:
        if pol_score['neg'] > pol_score['pos']:
            labels.append(0)
        else:
            labels.append(1)
        
df["label"] = labels
df.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       27966   495260  2011-09-02       730165          Maja
# 1       27966  1088520  2012-04-06      1463423       Russell
# 2       27966  1638334  2012-07-05      2761210       Jessica
# 3       27966  1884289  2012-08-04      2814925          Paul
# 4       27966  1972549  2012-08-13      3039803       Lavinia
#
#                                             comments  label
# 0  Manolis and his family were wonderful hosta. I...      1
# 1  Nice apartment. Manolis and his family are lov...      1
# 2  Antonia was a fantastic host! She will no doub...      1
# 3  Manolis has an excellent apartment in Amoudara...      1
# 4  Everything was wonderful! The weather, beach, ...      1

# %%
print(df[df["label"] == 0].shape)
print(df[df["label"] == 1].shape)
# Out:
# (24276, 7)
# (247595, 7)

# %% [markdown]
# It is an unbalanced dataset, with ratio 90 positive- 10 negative

# %%
df[df["label"] == -1]
# Out:
#         listing_id                  id        date  reviewer_id reviewer_name  \
# 118161    17679432           465056953  2019-06-07    111548578        Mohsen
# 187676    25838702  588211111278640865  2022-03-22    436186279        Denise
# 247483    42148921  587406873715874033  2022-03-21    442559359     Christina
#
#        comments  label
# 118161      NaN     -1
# 187676      NaN     -1
# 247483      NaN     -1

# %%
df  = df.dropna()
df[df["label"] == -1]
# Out:
# Empty DataFrame
# Columns: [listing_id, id, date, reviewer_id, reviewer_name, comments, label]
# Index: []

# %%
df_pos = df[df["label"] == 1]
df_neg = df[df["label"] == 0]

# %%
df_pos = df_pos.sample(len(df_neg))
print(df_pos.shape)
print(df_neg.shape)
# Out:
# (24276, 7)
# (24276, 7)

# %% [markdown]
# Now it is a balanced dataset

# %%
df = pd.concat([df_neg, df_pos], axis=0)

# %%
df["comments"]
# Out:
# 69        Wir hatten eine schöne Zeit in Antonia Apartme...
# 71        Les moments que nous avons passés avec Antonia...
# 85        Assurément ma meilleure expérience Airbnb! Man...
# 112       Sehr empfehlenswert! Antonia und Manolis sind ...
# 129       Eirini und Vincent waren fabelhafte Gastgeber....
#                                 ...
# 72497     Find something better seems hard.<br/>The vill...
# 108713                                   This is very clean
# 66235     This is our first stay with AirBNB. We have st...
# 15061     I cannot say enough good things about this vil...
# 212614    What a lovely experience at Isabella’s home in...
# Name: comments, Length: 48552, dtype: object

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree
#storing the puntuation free text
df['comments_str'] = df['comments'].apply(lambda x:str(x))
df['clean_comments'] = df['comments_str'].apply(lambda x:remove_punctuation(x))
df['comments_lower'] = df['clean_comments'].apply(lambda x: x.lower())
df.head()
# Out:
#      listing_id                  id        date  reviewer_id reviewer_name  \
# 69        27966            40643115  2015-08-01     37775738      Angelika
# 71        27966            44093265  2015-08-24     20693705         Karim
# 85        27966           102259818  2016-09-17      6941208         Annik
# 112       27966  402574129623837353  2021-07-09    177831668        Olesya
# 129       28970             3320683  2013-01-10      4016237        Gudrun
#
#                                               comments  label  \
# 69   Wir hatten eine schöne Zeit in Antonia Apartme...      0
# 71   Les moments que nous avons passés avec Antonia...      0
# 85   Assurément ma meilleure expérience Airbnb! Man...      0
# 112  Sehr empfehlenswert! Antonia und Manolis sind ...      0
# 129  Eirini und Vincent waren fabelhafte Gastgeber....      0
#
#                                           comments_str  \
# 69   Wir hatten eine schöne Zeit in Antonia Apartme...
# 71   Les moments que nous avons passés avec Antonia...
# 85   Assurément ma meilleure expérience Airbnb! Man...
# 112  Sehr empfehlenswert! Antonia und Manolis sind ...
# 129  Eirini und Vincent waren fabelhafte Gastgeber....
#
#                                         clean_comments  \
# 69   Wir hatten eine schöne Zeit in Antonia Apartme...
# 71   Les moments que nous avons passés avec Antonia...
# 85   Assurément ma meilleure expérience Airbnb Mano...
# 112  Sehr empfehlenswert Antonia und Manolis sind s...
# 129  Eirini und Vincent waren fabelhafte Gastgeber ...
#
#                                         comments_lower
# 69   wir hatten eine schöne zeit in antonia apartme...
# 71   les moments que nous avons passés avec antonia...
# 85   assurément ma meilleure expérience airbnb mano...
# 112  sehr empfehlenswert antonia und manolis sind s...
# 129  eirini und vincent waren fabelhafte gastgeber ...

# %%
# tokenizing the comments
tokenized_comments = []

for comment in df["comments_lower"]:
    tokenized_comments.append(comment.split())
    
tokenized_comments
# Out:
# [['wir',
#   'hatten',
#   'eine',
#   'schöne',
#   'zeit',
#   'in',
#   'antonia',
#   'apartment',
#   'alles',
#   'war',
#   'so',
#   'wie',
#   'beschrieben',
#   'täglich',
#   'wurden',
#   'wir',
#   'mit',
#   'griechischen',
#   'köstlichkeiten',
#   'verwöhnt',
#   'und',
#   'auch',
#   'bei',
#   'sonnenbrand',
#   'gab',
#   'es',
#   'hilfe',
#   'das',
#   'apartment',
#   'war',
#   'sehr',
#   'schön',
#   'und',
#   'ruhig',
#   'gelegen',
#   'vielen',
#   'dank'],
#  ['les',
#   'moments',
#   'que',
#   'nous',
#   'avons',
#   'passés',
#   'avec',
#   'antonia',
#   'sa',
#   'famille',
#   'et',
#   'ses',
#   'amies',
#   'étaient',
#   'absolument',
#   'fabuleux',
#   'elle',
#   'a',
#   'été',
#   'très',
#   'attentive',
#   'à',
#   'tous',
#   'nos',
#   'besoins',
#   'très',
#   'serviable',
#   'et',
#   'toutes',
#   'ses',
#   'petites',
#   'attentions',
#   'nous',
#   'ont',
#   'beaucoup',
#   'touchés',
#   'nous',
#   'avons',
#   'grâce',
#   'à',
#   'elle',
#   'pu',
#   'découvrir',
#   'la',
#   'vraie',
#   'hospitalité',
#   'des',
#   'crétois',
#   'ses',
#   '15',
#   'jours',
#   'nous',
#   'ont',
#   'fait',
#   'rencontrer',
#   'de',
#   'très',
#   'belles',
#   'personnes',
#   'que',
#   'nous',
#   'pouvons',
#   'à',
#   'présent',
#   'considérer',
#   'comme',
#   'des',
#   'amis',
#   'voire',
#   'même',
#   'une',
#   'nouvelle',
#   'famille',
#   'merci',
#   'à',
#   'toi',
#   'antonia',
#   'pour',
#   'ton',
#   'amour',
#   'ta',
#   'générosité',
#   'et',
#   'tes',
#   'recettes',
#   'succulentes',
#   'merci',
#   'à',
#   'toi',
#   'manolis',
#   'pour',
#   'tes',
#   'conseils',
#   'avisés',
#   'depuis',
#   'londres',
#   'à',
#   'toi',
#   'aussi',
#   'vassily',
#   'pour',
#   'ta',
#   'gentillesse',
#   'et',
#   'ta',
#   'cuisson',
#   'parfaite',
#   'des',
#   'souvlakis',
#   'et',
#   'jespère',
#   'que',
#   'les',
#   'prochains',
#   'hôtes',
#   'pourrons',
#   'aussi',
#   'rencontrer',
#   'le',
#   'reste',
#   'de',
#   'cette',
#   'belle',
#   'famille',
#   'ainsi',
#   'que',
#   'les',
#   'adorables',
#   'angéliqui',
#   'et',
#   'monolis',
#   'qui',
#   'ont',
#   'eu',
#   'la',
#   'gentillesse',
#   'de',
#   'nous',
#   'convier',
#   'dans',
#   'leur',
#   'belle',
#   'maison',
#   'dans',
#   'la',
#   'montagne',
#   'on',
#   'a',
#   'vraiment',
#   'hâte',
#   'de',
#   'revenir'],
#  ['assurément',
#   'ma',
#   'meilleure',
#   'expérience',
#   'airbnb',
#   'manolis',
#   'a',
#   'répondu',
#   'très',
#   'rapidement',
#   'à',
#   'mes',
#   'diverses',
#   'demandes',
#   'et',
#   'questions',
#   'par',
#   'email',
#   'ou',
#   'hidden',
#   'by',
#   'airbnb',
#   'cest',
#   'antonia',
#   'qui',
#   'ma',
#   'accueillie',
#   'comme',
#   'un',
#   'membre',
#   'de',
#   'la',
#   'famille',
#   'il',
#   'y',
#   'avait',
#   'de',
#   'quoi',
#   'boire',
#   'et',
#   'manger',
#   'au',
#   'frigo',
#   'lappartement',
#   'est',
#   'extrêmement',
#   'propre',
#   'très',
#   'bien',
#   'équipé',
#   'et',
#   'joliment',
#   'décoré',
#   'la',
#   'situation',
#   'à',
#   '10',
#   'minutes',
#   'à',
#   'pieds',
#   'de',
#   'la',
#   'plage',
#   'est',
#   'idéale',
#   'br',
#   'br',
#   'rien',
#   'à',
#   'dire',
#   'mon',
#   'séjour',
#   'sest',
#   'parfaitement',
#   'déroulé'],
#  ['sehr',
#   'empfehlenswert',
#   'antonia',
#   'und',
#   'manolis',
#   'sind',
#   'sehr',
#   'nette',
#   'und',
#   'hilfsbereite',
#   'gastgeber',
#   'auf',
#   'kreta',
#   'haben',
#   'wir',
#   'drei',
#   'wohnungen',
#   'gemietet',
#   'die',
#   'von',
#   'antonia',
#   'war',
#   'mit',
#   'abstand',
#   'die',
#   'beste',
#   'es',
#   'gibt',
#   'tatsächlich',
#   'alles',
#   'was',
#   'man',
#   'im',
#   'normalen',
#   'leben',
#   'brauch',
#   'mehr',
#   'als',
#   'sechs',
#   'badetücher',
#   'sehr',
#   'saubere',
#   'umgebung',
#   'herdplatte',
#   'zum',
#   'kochen',
#   'gute',
#   'waschmaschine',
#   'voll',
#   'ausgestatte',
#   'küche',
#   'als',
#   'wilkommensgeschenk',
#   'gab',
#   'es',
#   'ein',
#   'griechischer',
#   'salat',
#   'mit',
#   'selbstgemachten',
#   'olivenöl',
#   'und',
#   'essig',
#   'wir',
#   'habe',
#   'viele',
#   'hilfestellungen',
#   'und',
#   'tipps',
#   'beim',
#   'reisen',
#   'erhalten',
#   'manolis',
#   'hat',
#   'uns',
#   'weitere',
#   'woche',
#   'auf',
#   'wahtsapp',
#   'beim',
#   'reisen',
#   'unterstützt',
#   'eine',
#   'nette',
#   'und',
#   'feindliche',
#   'familie',
#   'wir',
#   'sind',
#   'vom',
#   'reisen',
#   'und',
#   'wohnen',
#   'sehr',
#   'begeistert'],
#  ['eirini',
#   'und',
#   'vincent',
#   'waren',
#   'fabelhafte',
#   'gastgeber',
#   'wir',
#   'wurden',
#   'vom',
#   'flughafen',
#   'abgeholt',
#   'und',
#   'auch',
#   'wieder',
#   'hingebracht',
#   'obwohl',
#   'der',
#   'flug',
#   'sehr',
#   'früh',
#   'am',
#   'morgen',
#   'war',
#   'bei',
#   'der',
#   'ankunft',
#   'waren',
#   'im',
#   'haus',
#   'eine',
#   'flasche',
#   'rotwein',
#   'brot',
#   'und',
#   'wasser',
#   'und',
#   'eine',
#   'ganz',
#   'fantastische',
#   'selbstgemachte',
#   'kumquatmarmelade',
#   'und',
#   'obst',
#   'für',
#   'ein',
#   'frühstück',
#   'bzw',
#   'den',
#   'ankunftsabend',
#   'brsehr',
#   'schön',
#   'war',
#   'auch',
#   'ein',
#   'holzofen',
#   'mit',
#   'großem',
#   'glasfenster',
#   'der',
#   'an',
#   'einen',
#   'kamin',
#   'erinnerte',
#   'was',
#   'sehr',
#   'gemütlich',
#   'war',
#   'an',
#   'vielen',
#   'recht',
#   'kalten',
#   'kretischen',
#   'winterabenden',
#   'brdie',
#   'lage',
#   'des',
#   'hauses',
#   'ist',
#   'total',
#   'zentral',
#   'und',
#   'trotzdem',
#   'ruhig',
#   'interessante',
#   'museen',
#   'das',
#   'meer',
#   'restaurants',
#   'und',
#   'cafés',
#   'sind',
#   'in',
#   'unmittelbarer',
#   'nähe',
#   'bralles',
#   'in',
#   'allem',
#   'war',
#   'es',
#   'ein',
#   'wunderbarer',
#   'aufenthalt',
#   'den',
#   'man',
#   'nie',
#   'in',
#   'einem',
#   'hotel',
#   'hätte',
#   'man',
#   'wohnt',
#   'richtig',
#   'in',
#   'heraklion',
#   'und',
#   'nicht',
#   'in',
#   'einer',
#   'anonymen',
#   'tourismuseinrichtung',
#   'wie',
#   'es',
#   'sie',
#   'überall',
#   'gibt'],
#  ['nous',
#   'venons',
#   'de',
#   'passer',
#   '7',
#   'semaines',
#   'dans',
#   'la',
#   'maison',
#   'deirini',
#   'et',
#   'nous',
#   'en',
#   'sommes',
#   'très',
#   'contents',
#   'située',
#   'dans',
#   'la',
#   'vielle',
#   'ville',
#   'à',
#   'quelques',
#   'pas',
#   'de',
#   'la',
#   'corniche',
#   'et',
#   'du',
#   'centre',
#   'ville',
#   'pas',
#   'très',
#   'loin',
#   'de',
#   'la',
#   'gare',
#   'de',
#   'bus',
#   'cest',
#   'le',
#   'lieu',
#   'idéal',
#   'pour',
#   'découvrir',
#   'heraklion',
#   'et',
#   'la',
#   'crète',
#   'tout',
#   'en',
#   'évitant',
#   'les',
#   'zones',
#   'à',
#   'touristes',
#   'ce',
#   'que',
#   'nous',
#   'avons',
#   'le',
#   'plus',
#   'apprécié',
#   'par',
#   'rapport',
#   'à',
#   'dautres',
#   'locations',
#   'que',
#   'nous',
#   'avions',
#   'eu',
#   'dans',
#   'dautres',
#   'pays',
#   'est',
#   'la',
#   'qualité',
#   'de',
#   'léquipement',
#   'de',
#   'la',
#   'cuisine',
#   'eirini',
#   'était',
#   'en',
#   'vacances',
#   'pendant',
#   'notre',
#   'séjour',
#   'mais',
#   'pour',
#   'le',
#   'moindre',
#   'besoin',
#   'bouteille',
#   'de',
#   'gaz',
#   'ou',
#   'renseignement',
#   'vangelis',
#   'son',
#   'père',
#   'est',
#   'là',
#   'et',
#   'dune',
#   'rare',
#   'disponibilité',
#   'et',
#   'gentillesse',
#   'de',
#   'plus',
#   'eirini',
#   'nous',
#   'avait',
#   'laissé',
#   'une',
#   'liste',
#   'de',
#   'bonnes',
#   'adresses',
#   'ou',
#   'boire',
#   'un',
#   'verre',
#   'et',
#   'dîner',
#   'et',
#   'certains',
#   'comme',
#   'spiros',
#   'sont',
#   'devenus',
#   'des',
#   'amis',
#   'comme',
#   'cest',
#   'une',
#   'zone',
#   'sans',
#   'touristes',
#   'vous',
#   'faites',
#   'de',
#   'nombreuses',
#   'rencontres',
#   'et',
#   'certains',
#   'sont',
#   'même',
#   'venus',
#   'nous',
#   'offrir',
#   'des',
#   'cadeaux',
#   'pour',
#   'notre',
#   'départ',
#   'vraiment',
#   'un',
#   'bon',
#   'souvenir'],
#  ['vielen',
#   'dank',
#   'brwir',
#   'haben',
#   'die',
#   'zeit',
#   'in',
#   'dem',
#   'sehr',
#   'individuellen',
#   'haus',
#   'sehr',
#   'genossen',
#   'eirini',
#   'ist',
#   'sehr',
#   'hilfreich',
#   'und',
#   'die',
#   'dachterrasse',
#   'lädt',
#   'zum',
#   'chillen',
#   'sonnen',
#   'ein',
#   'wir',
#   'kommen',
#   'gerne',
#   'wieder'],
#  ['die',
#   'unterkunft',
#   'ist',
#   'auf',
#   'jeden',
#   'fall',
#   'weiterzuempfehlen',
#   'vor',
#   'allem',
#   'hat',
#   'uns',
#   'gefallen',
#   'dass',
#   'man',
#   'durch',
#   'die',
#   'lage',
#   'einen',
#   'einblick',
#   'in',
#   'das',
#   'leben',
#   'der',
#   'einheimischen',
#   'bekommt',
#   'wir',
#   'haben',
#   'außerdem',
#   'tolle',
#   'tipps',
#   'bekommen',
#   'und',
#   'uns',
#   'sehr',
#   'wohl',
#   'gefühlt'],
#  ['dimitrios',
#   'et',
#   'son',
#   'père',
#   'sont',
#   'deux',
#   'personnes',
#   'adorables',
#   'qui',
#   'feront',
#   'tout',
#   'pour',
#   'que',
#   'votre',
#   'séjour',
#   'en',
#   'crête',
#   'soit',
#   'parfait',
#   'la',
#   'villa',
#   'est',
#   'romantique',
#   'et',
#   'atypique',
#   'remplie',
#   'de',
#   'petites',
#   'attentions',
#   'chaleureuses',
#   'et',
#   'vous',
#   'fait',
#   'vous',
#   'sentir',
#   'réellement',
#   'comme',
#   'si',
#   'vous',
#   'étiez',
#   'chez',
#   'vous',
#   'il',
#   'nous',
#   'a',
#   'directement',
#   'indiqué',
#   'les',
#   'adresses',
#   'idéales',
#   'selon',
#   'le',
#   'gré',
#   'des',
#   'besoins',
#   'tout',
#   'pour',
#   'savoir',
#   's’adapter',
#   'vite',
#   'sur',
#   'place',
#   'un',
#   'superbe',
#   'séjour',
#   'passé',
#   'la',
#   'bas'],
#  ['la',
#   'stanza',
#   'rispecchiava',
#   'quanto',
#   'descritto',
#   'brlunica',
#   'pecca',
#   'è',
#   'stata',
#   'la',
#   'colazione',
#   'che',
#   'era',
#   'un',
#   'po',
#   'misera'],
#  ['the',
#   'experience',
#   'in',
#   'dimitris',
#   'villas',
#   'wasnt',
#   'very',
#   'good',
#   'room',
#   'was',
#   'small',
#   'no',
#   'balcony',
#   'noisy',
#   'because',
#   'of',
#   'the',
#   'neighbours',
#   'but',
#   'most',
#   'of',
#   'all',
#   'the',
#   'unpolite',
#   'and',
#   'rude',
#   'behavior',
#   'of',
#   'the',
#   'girl',
#   'who',
#   'welcome',
#   'us'],
#  ['de',
#   'ontvangst',
#   'was',
#   'heel',
#   'vriendelijk',
#   'en',
#   'we',
#   'kregen',
#   'een',
#   'koel',
#   'glaasje',
#   'witte',
#   'wijn',
#   'aangeboden',
#   'door',
#   'we',
#   'veronderstellen',
#   'de',
#   'vrouw',
#   'van',
#   'dimitris',
#   'want',
#   'die',
#   'hebben',
#   'we',
#   'niet',
#   'gezien',
#   'de',
#   'kamers',
#   'waren',
#   'rustig',
#   'gelegen',
#   'en',
#   'het',
#   'was',
#   'er',
#   'aangenaam',
#   'buiten',
#   'zitten',
#   'onder',
#   'de',
#   'patio',
#   'de',
#   'kamers',
#   'zelf',
#   'waren',
#   'proper',
#   'maar',
#   'oubollig',
#   'de',
#   'badkamer',
#   'was',
#   'veel',
#   'te',
#   'klein',
#   'het',
#   'ontbijt',
#   'was',
#   'in',
#   'orde',
#   'maar',
#   'te',
#   'weinig',
#   'tafels',
#   'buiten',
#   'voorzien',
#   'terwijl',
#   'er',
#   'plaats',
#   'genoeg',
#   'was',
#   'het',
#   'zwembad',
#   'zag',
#   'er',
#   'fantastisch',
#   'uit',
#   'maar',
#   'hebben',
#   'we',
#   'niet',
#   'gebruikt',
#   'omdat',
#   'de',
#   'zee',
#   'meer',
#   'lonkte',
#   'matala',
#   'is',
#   'heel',
#   'gezellig',
#   'met',
#   'lekkere',
#   'restaurants',
#   'en',
#   'een',
#   'klein',
#   'gezellig',
#   'kiezelstrand',
#   'een',
#   'speciale',
#   'sfeer',
#   'is',
#   'aanwezig',
#   'door',
#   'de',
#   'natuurlijke',
#   'grotten',
#   'in',
#   'de',
#   'rotswand',
#   'brzo',
#   'een',
#   'klein',
#   'hotelletje',
#   'heeft',
#   'wel',
#   'niet',
#   'dezelfde',
#   'sfeer',
#   'als',
#   'bij',
#   'particulieren',
#   'die',
#   'een',
#   'bb',
#   'uitbaten'],
#  ['wir',
#   'waren',
#   '3',
#   'tage',
#   'in',
#   'matala',
#   'die',
#   'unterkunft',
#   'ist',
#   'sehr',
#   'sauber',
#   'und',
#   'alle',
#   'leute',
#   'sind',
#   'sehr',
#   'freundlich',
#   'und',
#   'hilfsbereit',
#   'die',
#   'lage',
#   'ist',
#   'sehr',
#   'ruhig',
#   'und',
#   'das',
#   'zentrum',
#   'von',
#   'matala',
#   'kann',
#   'man',
#   'bequem',
#   'zu',
#   'fuß',
#   'erreichen',
#   'danke',
#   'für',
#   'die',
#   '3',
#   'tage',
#   'sagen',
#   'kerstin',
#   'und',
#   'reinhard'],
#  ['beaucoup',
#   'de',
#   'points',
#   'positifs',
#   'un',
#   'cadre',
#   'très',
#   'joli',
#   'au',
#   'calme',
#   'dans',
#   'la',
#   'nature',
#   'et',
#   'bien',
#   'entretenu',
#   'centre',
#   'ville',
#   'accessible',
#   'à',
#   'pieds',
#   '5',
#   'min',
#   'la',
#   'chambre',
#   'correspond',
#   'au',
#   'descriptif',
#   'et',
#   'est',
#   'propre',
#   'petit',
#   'bémol',
#   'il',
#   'y',
#   'a',
#   'peu',
#   'de',
#   'pression',
#   'dans',
#   'la',
#   'douche',
#   'mais',
#   'il',
#   'semblerait',
#   'que',
#   'ce',
#   'soit',
#   'normal',
#   'à',
#   'matala',
#   'la',
#   'fille',
#   'de',
#   'dimitris',
#   'était',
#   'accueillante',
#   'et',
#   'serviable',
#   'nous',
#   'recommandons'],
#  ['quelle',
#   'déception',
#   'une',
#   'très',
#   'mauvaise',
#   'expérience',
#   'brun',
#   'attrapetouristes',
#   'sous',
#   'des',
#   'aspects',
#   'babacool',
#   'une',
#   'gestion',
#   'économique',
#   'à',
#   'bas',
#   'coûts',
#   'brla',
#   'zone',
#   'de',
#   'matala',
#   'étant',
#   'hyper',
#   'touristique',
#   'il',
#   'leur',
#   'semble',
#   'donc',
#   'inutile',
#   'de',
#   'faire',
#   'des',
#   'efforts',
#   'pour',
#   'rendre',
#   'le',
#   'séjour',
#   'de',
#   'leurs',
#   'hôtes',
#   'agréable',
#   'ceux',
#   'qui',
#   'ne',
#   'seraient',
#   'pas',
#   'contents',
#   'seraient',
#   'remplacés',
#   'aussitôt',
#   'brmauvais',
#   'rapport',
#   'qualitéprix',
#   'brdifficultés',
#   'pour',
#   'trouver',
#   'lhôtel',
#   'via',
#   'le',
#   'site',
#   'ou',
#   'en',
#   'échangeant',
#   'par',
#   'mail',
#   'car',
#   'pas',
#   'dadresse',
#   'réelle',
#   'indiquée',
#   'et',
#   'les',
#   'coordonnées',
#   'gps',
#   'fournies',
#   'fausses',
#   'braccueil',
#   'expéditif',
#   'sans',
#   'chaleur',
#   'avec',
#   'remise',
#   'des',
#   'clés',
#   'en',
#   '15',
#   'secondes',
#   'et',
#   'aucun',
#   'autre',
#   'contact',
#   'en',
#   '2',
#   'jours',
#   'brchambre',
#   'propre',
#   'mais',
#   'vraiment',
#   'petite',
#   'salle',
#   'de',
#   'bain',
#   'nauséabonde',
#   'fortes',
#   'odeurs',
#   'de',
#   'fosse',
#   'septique',
#   'pas',
#   'de',
#   'pression',
#   'pour',
#   'la',
#   'douche',
#   'et',
#   'pas',
#   'deau',
#   'chaude',
#   'ni',
#   'deau',
#   'tiede',
#   'brpetit',
#   'déjeuner',
#   'minable',
#   'avec',
#   'des',
#   'produits',
#   'bas',
#   'de',
#   'gamme',
#   'brtout',
#   'nest',
#   'quapparence',
#   'leur',
#   'atout',
#   'est',
#   'leur',
#   'piscine',
#   'brla',
#   'pire',
#   'adresse',
#   'de',
#   'tout',
#   'notre',
#   'circuit',
#   'en',
#   'crète',
#   'brsurtout',
#   'a',
#   'eviter'],
#  ['quiet',
#   'and',
#   'peaceful',
#   'shame',
#   'that',
#   'the',
#   'pool',
#   'wasnt',
#   'open',
#   'nice',
#   'place'],
#  ['a',
#   'dump',
#   'that',
#   'should',
#   'be',
#   'avoided',
#   'and',
#   'owners',
#   'that',
#   'try',
#   'to',
#   'blatantly',
#   'rip',
#   'you',
#   'off',
#   'by',
#   'moving',
#   'you',
#   'into',
#   'lower',
#   'class',
#   'and',
#   'smaller',
#   'rooms',
#   'that',
#   'sell',
#   'on',
#   'other',
#   'platforms',
#   'for',
#   'half',
#   'the',
#   'price',
#   'upon',
#   'complaining',
#   'they',
#   'become',
#   'very',
#   'defensive',
#   'and',
#   'aggressive',
#   'i',
#   'understand',
#   'mistakes',
#   'can',
#   'happen',
#   'but',
#   'you',
#   'deal',
#   'with',
#   'the',
#   'guest',
#   'in',
#   'a',
#   'way',
#   'that',
#   'resolves',
#   'the',
#   'issue',
#   'favourably',
#   'for',
#   'both',
#   'sides',
#   'clearly',
#   'it',
#   'states',
#   'a',
#   '3',
#   'bed',
#   'room',
#   'but',
#   'upon',
#   'arrival',
#   'we',
#   'were',
#   'given',
#   'a',
#   'smaller',
#   '2',
#   'bed',
#   'which',
#   'is',
#   'normally',
#   '20',
#   'euros',
#   'cheaper',
#   'but',
#   'no',
#   'mention',
#   'of',
#   'refunding',
#   'the',
#   'difference',
#   'only',
#   'aggressive',
#   'remarks',
#   'we',
#   'were',
#   'not',
#   'the',
#   'first',
#   'guests',
#   'with',
#   'this',
#   'experience',
#   'as',
#   'on',
#   'other',
#   'platforms',
#   'others',
#   'complained',
#   'about',
#   'the',
#   'same',
#   'handling',
#   'if',
#   'you',
#   'do',
#   'complain',
#   'all',
#   'they',
#   'do',
#   'is',
#   'try',
#   'to',
#   'discredit',
#   'you',
#   'in',
#   'one',
#   'way',
#   'or',
#   'another',
#   'this',
#   'is',
#   'not',
#   'a',
#   'true',
#   'airbnb',
#   'experience',
#   'avoid',
#   'this',
#   'pit',
#   'if',
#   'you',
#   'want',
#   'a',
#   'good',
#   'holiday'],
#  ['chambre',
#   'propre',
#   'et',
#   'pratique',
#   'pour',
#   'un',
#   'court',
#   'séjour',
#   'à',
#   'matala',
#   'proche',
#   'du',
#   'centre',
#   'à',
#   'peine',
#   '10’',
#   'à',
#   'pied',
#   'très',
#   'bon',
#   'emplacement',
#   'la',
#   'piscine',
#   'est',
#   'vraiment',
#   'le',
#   'plus',
#   'attirant',
#   'de',
#   'cet',
#   'endroit',
#   'mais',
#   'si',
#   'vous',
#   'visité',
#   'matala',
#   'et',
#   'ses',
#   'plages',
#   'la',
#   'piscine',
#   'ne',
#   'pas',
#   'de',
#   'grand',
#   'intérêt',
#   'petit',
#   'déjeuné',
#   'correct',
#   'confortable',
#   'le',
#   'mobilier',
#   'est',
#   'ancien',
#   'mais',
#   'ça',
#   'va',
#   'la',
#   'sdb',
#   'est',
#   'très',
#   'inconfortable',
#   'mais',
#   'qualité',
#   'prix',
#   'raisonnable',
#   'pour',
#   'l’endroit',
#   'il',
#   'vont',
#   'vous',
#   'demander',
#   'de',
#   'payer',
#   'les',
#   '“taxes',
#   'de',
#   'ville”',
#   'bien',
#   'à',
#   'part',
#   'les',
#   'taxes',
#   'séjour',
#   'et',
#   'taxe',
#   'airbnb',
#   'que',
#   'vous',
#   'avez',
#   'déjà',
#   'payé',
#   'sur',
#   'le',
#   'site',
#   'soyez',
#   'pas',
#   'surpris',
#   'la',
#   'télécommande',
#   'ne',
#   'marche',
#   'pas',
#   'et',
#   'là',
#   'toute',
#   'petite',
#   'tv',
#   'est',
#   'très',
#   'ancienne',
#   'vous',
#   'serez',
#   'près',
#   'du',
#   'centre',
#   'des',
#   'restaurants',
#   'de',
#   'commerces',
#   'et',
#   'mini',
#   'market',
#   'et',
#   'carrefour',
#   'l’établissement',
#   'ne',
#   'possède',
#   'un',
#   'lieux',
#   'pour',
#   'faire',
#   'à',
#   'mange',
#   'attention',
#   'brbrbrla',
#   'habitación',
#   'confortable',
#   'pero',
#   'un',
#   'poco',
#   'vieja',
#   'si',
#   'pasa',
#   'solo',
#   'unos',
#   'días',
#   'está',
#   'bien',
#   'está',
#   'cerca',
#   'del',
#   'centro',
#   'a',
#   'pie',
#   'solo',
#   '10’',
#   'mn',
#   'possède',
#   'una',
#   'piscina',
#   'pequeña',
#   'pero',
#   'si',
#   'va',
#   'a',
#   'visitar',
#   'matala',
#   'y',
#   'sus',
#   'playas',
#   'no',
#   'es',
#   'muy',
#   'útil',
#   'el',
#   'desayuno',
#   'es',
#   'correcto',
#   'el',
#   'control',
#   'de',
#   'la',
#   'tv',
#   'no',
#   'funciona',
#   'es',
#   'una',
#   'tv',
#   'bastante',
#   'antigua',
#   'tiene',
#   'aire',
#   'acondicionado',
#   'imprescindible',
#   'y’a',
#   'que',
#   'es',
#   'hace',
#   'mucho',
#   'calor',
#   'le',
#   'pedirán',
#   'que',
#   'pague',
#   'una',
#   'taxe',
#   'de',
#   'ciudad',
#   'que',
#   'no',
#   'está',
#   'incluida',
#   'en',
#   'el',
#   'pago',
#   'total',
#   'no',
#   'es',
#   'casi',
#   'nada',
#   'pero',
#   'para',
#   'que',
#   'se',
#   'sorprenda',
#   'a',
#   'parte',
#   'las',
#   'taxes',
#   'de',
#   'estadía',
#   'y',
#   'las',
#   'taxes',
#   'de',
#   'airbnb',
#   'por',
#   'supuesto'],
#  ['we',
#   'have',
#   'a',
#   'nice',
#   'stay',
#   'at',
#   'chryssoula',
#   'the',
#   'place',
#   'is',
#   'very',
#   'near',
#   'to',
#   'the',
#   'harbor',
#   'and',
#   'the',
#   'bus',
#   'station',
#   'which',
#   'are',
#   'very',
#   'convenient',
#   'we',
#   'decided',
#   'to',
#   'leave',
#   'after',
#   'two',
#   'days',
#   'and',
#   'chryssoula',
#   'even',
#   'gave',
#   'us',
#   'back',
#   'some',
#   'money',
#   'for',
#   'the',
#   'third',
#   'night',
#   'not',
#   'spent',
#   'there',
#   'thank',
#   'you',
#   'chryssoula',
#   'for',
#   'your',
#   'hospitality'],
#  ['the',
#   'room',
#   'is',
#   'very',
#   'well',
#   'situated',
#   'old',
#   'and',
#   'kind',
#   'of',
#   'uncomfortable',
#   'beds',
#   'fridge',
#   'with',
#   'two',
#   'small',
#   'bottles',
#   'of',
#   'water',
#   'very',
#   'appreciated',
#   'with',
#   'ac',
#   'useful',
#   'a',
#   'quite',
#   'tiny',
#   'shower',
#   'and',
#   'a',
#   'shower',
#   'curtains',
#   'too',
#   'short',
#   'so',
#   'lot',
#   'of',
#   'water',
#   'everywhere',
#   'much',
#   'cleaning',
#   'is',
#   'needed',
#   'inside',
#   'especially',
#   'the',
#   'website',
#   'hidden',
#   'by',
#   'airbnb',
#   'old',
#   'musty',
#   'smell'],
#  ['die',
#   'ferienwohnung',
#   'war',
#   'genau',
#   'wie',
#   'beschrieben',
#   'klein',
#   'gemütlich',
#   'schlicht',
#   'zentral',
#   'gelegen',
#   'und',
#   'doch',
#   'sehr',
#   'ruhig',
#   'ein',
#   'sehr',
#   'nettes',
#   'umfeld',
#   'gutes',
#   'restaurant',
#   '3',
#   'schritte',
#   'entfernt',
#   'die',
#   'ganze',
#   'familie',
#   'von',
#   'chrysoulla',
#   'ist',
#   'sehr',
#   'zuvorkommend',
#   'mein',
#   'mann',
#   'und',
#   'ich',
#   'haben',
#   'uns',
#   'sehr',
#   'wohlgefühlt',
#   'würden',
#   'liebend',
#   'gerne',
#   'wieder',
#   'bei',
#   'chrysoulla',
#   'in',
#   'deren',
#   'ferienwohnung',
#   'wohnen',
#   'br'],
#  ['wir',
#   'kamen',
#   'erst',
#   'um',
#   'mitternacht',
#   'an',
#   'und',
#   'wurden',
#   'sehr',
#   'freundlich',
#   'aufgenommen',
#   'zimmer',
#   'ist',
#   'wie',
#   'abgebildet',
#   'versehentlich',
#   'wurde',
#   'uns',
#   'erst',
#   'ein',
#   'anderes',
#   'kleineres',
#   'zimmer',
#   'gegeben',
#   'aber',
#   'nachdem',
#   'irrtum',
#   'bemerkt',
#   'von',
#   'seiten',
#   'chryssoulas',
#   'kam',
#   'diese',
#   'uns',
#   'sogar',
#   'nach',
#   'ins',
#   'restaurant',
#   'um',
#   'uns',
#   'den',
#   'schlüssel',
#   'für',
#   'room',
#   'no',
#   '1',
#   'zu',
#   'geben'],
#  ['my',
#   'stay',
#   'at',
#   'chryssoulas',
#   'guesthouse',
#   'was',
#   'quite',
#   'nice',
#   'checkin',
#   'and',
#   'out',
#   'were',
#   'really',
#   'easy',
#   'location',
#   'is',
#   'excellenton',
#   'a',
#   'quiet',
#   'side',
#   'street',
#   'within',
#   'a',
#   '5',
#   'minute',
#   'walk',
#   'of',
#   'the',
#   'waterfront',
#   'br',
#   'brthe',
#   'room',
#   'is',
#   'exactly',
#   'as',
#   'described',
#   'and',
#   'suited',
#   'my',
#   'purposes',
#   'well',
#   'the',
#   'lights',
#   'are',
#   'not',
#   'very',
#   'bright',
#   'however',
#   'so',
#   'it',
#   'can',
#   'be',
#   'fairly',
#   'dark',
#   'in',
#   'the',
#   'room',
#   'at',
#   'night',
#   'wifi',
#   'internet',
#   'was',
#   'available',
#   'but',
#   'painfully',
#   'slow',
#   'br'],
#  ['chryssoula',
#   'était',
#   'très',
#   'sympathique',
#   'elle',
#   'a',
#   'attendu',
#   'que',
#   'nous',
#   'arrivions',
#   'de',
#   'laéroport',
#   'alors',
#   'quil',
#   'était',
#   'tard',
#   'et',
#   'elle',
#   'a',
#   'même',
#   'pris',
#   'un',
#   'moment',
#   'pour',
#   'nous',
#   'expliquer',
#   'le',
#   'fonctionnement',
#   'de',
#   'la',
#   'chambre',
#   'cette',
#   'chambre',
#   'était',
#   'idéalement',
#   'située',
#   'comme',
#   'indiqué',
#   'sur',
#   'lannonce',
#   'dans',
#   'une',
#   'ruelle',
#   'typique',
#   'de',
#   'la',
#   'vieille',
#   'ville',
#   'à',
#   'moins',
#   'de',
#   '5',
#   'min',
#   'à',
#   'pied',
#   'du',
#   'vieux',
#   'port',
#   'de',
#   'chania',
#   'et',
#   'moins',
#   'de',
#   '10',
#   'min',
#   'de',
#   'la',
#   'gare',
#   'routière',
#   'ce',
#   'qui',
#   'était',
#   'très',
#   'pratique',
#   'pour',
#   'visiter',
#   'dautres',
#   'endroits',
#   'de',
#   'plus',
#   'chryssoula',
#   'a',
#   'pris',
#   'la',
#   'peine',
#   'de',
#   'nous',
#   'donner',
#   'du',
#   'linge',
#   'de',
#   'lit',
#   'et',
#   'des',
#   'serviettes',
#   'propres',
#   'à',
#   'deux',
#   'reprises',
#   'au',
#   'début',
#   'et',
#   'au',
#   'milieu',
#   'du',
#   'séjour',
#   'une',
#   'expérience',
#   'très',
#   'sympathique',
#   'je',
#   'recommande',
#   'ce',
#   'logement'],
#  ['ich',
#   'habe',
#   'mich',
#   'wirklich',
#   'sehr',
#   'wohlgefühlt',
#   'und',
#   'werde',
#   'sicher',
#   'gerne',
#   'wieder',
#   'kommen',
#   'bin',
#   'zum',
#   'ersten',
#   'mal',
#   'auf',
#   'kreta',
#   'und',
#   'bestimmt',
#   'nicht',
#   'zum',
#   'letzten',
#   'mal',
#   'man',
#   'fühlt',
#   'sich',
#   'sehr',
#   'umsorgt',
#   'und',
#   'das',
#   'zimmer',
#   'ist',
#   'sehr',
#   'schön',
#   'wie',
#   'auf',
#   'den',
#   'bildern',
#   'ich',
#   'mag',
#   'das',
#   'fenster',
#   'besonders',
#   'und',
#   'den',
#   'blick',
#   'auf',
#   'die',
#   'kleine',
#   'gasse',
#   'its',
#   'so',
#   'amazing'],
#  ['die',
#   'unterkunft',
#   'liegt',
#   'in',
#   'der',
#   'altstadt',
#   'chanias',
#   'zentral',
#   'aber',
#   'ruhig',
#   'sie',
#   'ist',
#   'nicht',
#   'allzuweit',
#   'von',
#   'parkmöglichkeiten',
#   'außerhalb',
#   'der',
#   'altstadt',
#   'entfernt',
#   'seitenstraßen',
#   'der',
#   'piräusstraße',
#   'die',
#   'kommunikation',
#   'hat',
#   'im',
#   'vorfeld',
#   'gut',
#   'geklappt',
#   'schwiegertochter',
#   'georgia',
#   'hat',
#   'michuns',
#   'zum',
#   'vereinbarten',
#   'zeitpunkt',
#   'sehr',
#   'herzlich',
#   'empfangen',
#   'brvon',
#   'den',
#   'fotos',
#   'her',
#   'hatte',
#   'ich',
#   'mir',
#   'das',
#   'zimmer',
#   'größer',
#   'freundlicher',
#   'und',
#   'heller',
#   'vorgestellt',
#   'für',
#   'ein',
#   'zwei',
#   'tage',
#   'ok',
#   'da',
#   'man',
#   'ja',
#   'ohnehin',
#   'meist',
#   'unterwegs',
#   'ist',
#   'für',
#   'einen',
#   'längeren',
#   'aufenthalt',
#   'und',
#   'zum',
#   'wohlfühlen',
#   'fand',
#   'ich',
#   'sie',
#   'nicht',
#   'so',
#   'gut',
#   'geeignet'],
#  ['wir',
#   'haben',
#   'zwei',
#   'nächte',
#   'in',
#   'cryssoulas',
#   'unterkunft',
#   'verbracht',
#   'vom',
#   'bus',
#   'bahnhof',
#   'sehr',
#   'gut',
#   'zu',
#   'erreichen',
#   'das',
#   'video',
#   'hat',
#   'uns',
#   'den',
#   'weg',
#   'sehr',
#   'gut',
#   'gereicht',
#   'die',
#   'unterkunft',
#   'liegt',
#   'mitten',
#   'in',
#   'der',
#   'wunderschönen',
#   'altstadt',
#   'aber',
#   'in',
#   'einer',
#   'ruhigen',
#   'gasse',
#   'wir',
#   'wurden',
#   'sehr',
#   'freundlich',
#   'begrüßt',
#   'von',
#   'cryssoulas',
#   'schwiegertochter',
#   'wir',
#   'würden',
#   'wieder',
#   'kommen'],
#  ['wir',
#   'haben',
#   'die',
#   'unterkunft',
#   'auf',
#   'grund',
#   'der',
#   'guten',
#   'bewertungen',
#   'gebucht',
#   'und',
#   'wurden',
#   'auch',
#   'nicht',
#   'enttäuscht',
#   'alles',
#   'was',
#   'bisher',
#   'geschrieben',
#   'wurde',
#   'wurde',
#   'auch',
#   'genau',
#   'so',
#   'angetroffen',
#   'die',
#   'lage',
#   'ist',
#   'absolut',
#   'perfekt',
#   'bei',
#   'unserer',
#   'ankunft',
#   'hat',
#   'uns',
#   'der',
#   'vermieter',
#   'alles',
#   'über',
#   'chania',
#   'erzählt',
#   'und',
#   'auch',
#   'sehr',
#   'gute',
#   'besuchertipps',
#   'gegeben',
#   'bzgl',
#   'balos',
#   'oder',
#   'seitan',
#   'limania',
#   'zudem',
#   'erklärte',
#   'er',
#   'uns',
#   'auch',
#   'den',
#   'weg',
#   'zu',
#   'einem',
#   'günstigen',
#   'modernen',
#   'supermakt',
#   'der',
#   'nur',
#   '300',
#   'meter',
#   'entfernt',
#   'ist',
#   'brder',
#   'strand',
#   'befindet',
#   'sich',
#   'circa',
#   '20',
#   'minuten',
#   'per',
#   'fuß',
#   'entfernt',
#   'jedoch',
#   'die',
#   'einkaufsmeile',
#   'hafen',
#   'und',
#   'altstadtrestaurants',
#   'alles',
#   'sofort',
#   'zu',
#   'erreichen',
#   'man',
#   'ist',
#   'so',
#   'gesagt',
#   'mitten',
#   'im',
#   'geschehenbrdie',
#   'küche',
#   'könnte',
#   'ein',
#   'wenig',
#   'besser',
#   'ausgestattet',
#   'sein',
#   'aber',
#   'wir',
#   'sind',
#   'jeden',
#   'abend',
#   'essen',
#   'gegangen',
#   'sodass',
#   'uns',
#   'das',
#   'im',
#   'endeffekt',
#   'nicht',
#   'gestört',
#   'hatbrbrwenn',
#   'chania',
#   'dann',
#   'das',
#   'chryssoula',
#   'guesthouse'],
#  ['wir',
#   'hatten',
#   'ein',
#   'paar',
#   'schöne',
#   'tage',
#   'in',
#   'chania',
#   'wir',
#   'wurden',
#   'herzlich',
#   'empfangen',
#   'die',
#   'lage',
#   'ist',
#   'perfekt',
#   'nur',
#   'das',
#   'haus',
#   'ist',
#   'etwas',
#   'hellhörig',
#   'was',
#   'den',
#   'ein',
#   'oder',
#   'anderen',
#   'vielleicht',
#   'stören',
#   'könnte'],
#  ['ik',
#   'vond',
#   'het',
#   'leuk',
#   'dat',
#   'het',
#   'appartement',
#   'in',
#   'de',
#   'straatjes',
#   'van',
#   'het',
#   'oude',
#   'en',
#   'sfeervolle',
#   'chania',
#   'lag',
#   'het',
#   'appartement',
#   'was',
#   'goed',
#   'verzorgd',
#   'tot',
#   'slot',
#   'kreeg',
#   'ik',
#   'echt',
#   'het',
#   'gevoel',
#   'dat',
#   'chryssoula',
#   'er',
#   'voor',
#   'je',
#   'was',
#   'als',
#   'je',
#   'vragen',
#   'of',
#   'iets',
#   'dergelijks',
#   'had'],
#  ['the',
#   'location',
#   'of',
#   'chryssoula',
#   'is',
#   'spectacular',
#   'it',
#   'is',
#   'in',
#   'the',
#   'heart',
#   'of',
#   'where',
#   'everything',
#   'is',
#   'happening',
#   'with',
#   'lots',
#   'or',
#   'restaurants',
#   'and',
#   'stops',
#   'but',
#   'it',
#   'is',
#   'on',
#   'a',
#   'very',
#   'quiet',
#   'alley',
#   'so',
#   'there',
#   'is',
#   'no',
#   'street',
#   'noise',
#   'at',
#   'all',
#   'the',
#   'hosts',
#   'were',
#   'very',
#   'attentive',
#   'and',
#   'always',
#   'very',
#   'fast',
#   'to',
#   'respond',
#   'i',
#   'highly',
#   'recommend',
#   'staying',
#   'here'],
#  ['emplacement',
#   'central',
#   'à',
#   'lécart',
#   'du',
#   'brouhaha',
#   'dans',
#   'une',
#   'ruelle',
#   'calme',
#   'et',
#   'authentiquebrgrande',
#   'chambre',
#   'avec',
#   'kitchenette',
#   'et',
#   'toute',
#   'petite',
#   'sdb',
#   'petit',
#   'balcon',
#   'utilisable',
#   'uniquement',
#   'pour',
#   'faire',
#   'sécher',
#   'ses',
#   'affaires',
#   'le',
#   'rbnb',
#   'est',
#   'en',
#   'faite',
#   'gérer',
#   'par',
#   'le',
#   'fils',
#   'qui',
#   'a',
#   'une',
#   'communication',
#   'assez',
#   'directe',
#   'pour',
#   'ne',
#   'pas',
#   'dire',
#   'directive',
#   'on',
#   'nose',
#   'pas',
#   'lui',
#   'pose',
#   'trop',
#   'de',
#   'questions',
#   'sinon',
#   'cest',
#   'efficace',
#   'pour',
#   'un',
#   'séjour',
#   'de',
#   'transit',
#   'car',
#   'proche',
#   'de',
#   'la',
#   'gare',
#   'routinière',
#   'et',
#   'des',
#   'agences',
#   'de',
#   'de',
#   'location',
#   'de',
#   'voiture'],
#  ['nous',
#   'avons',
#   'été',
#   'parfaitement',
#   'accueillis',
#   'dans',
#   'le',
#   'logement',
#   'de',
#   'chryssoula',
#   'guest',
#   'house',
#   'lhôte',
#   'nous',
#   'a',
#   'accueillie',
#   'avec',
#   'une',
#   'liste',
#   'très',
#   'utile',
#   'des',
#   'bonnes',
#   'adresses',
#   'du',
#   'coin',
#   'quelle',
#   'nous',
#   'a',
#   'présentébrle',
#   'logement',
#   'est',
#   'idealement',
#   'situé',
#   'au',
#   'centre',
#   'historique',
#   'de',
#   'la',
#   'canéechania',
#   'permettant',
#   'de',
#   'tout',
#   'faire',
#   'a',
#   'pied',
#   'sur',
#   'la',
#   'ville',
#   'et',
#   'si',
#   'vous',
#   'avez',
#   'un',
#   'vehicule',
#   'cest',
#   'idealement',
#   'situé',
#   'pour',
#   'visiter',
#   'toute',
#   'la',
#   'crête',
#   'de',
#   'louest',
#   'brpetit',
#   'balcon',
#   'mignonbrbons',
#   'resto',
#   'à',
#   'deux',
#   'pas',
#   'pas',
#   'très',
#   'cher'],
#  ['todo',
#   'perfecto',
#   'un',
#   'trato',
#   'inmejorable',
#   'repetiría',
#   'sin',
#   'dudarlo'],
#  ['das',
#   'zimmer',
#   'ist',
#   'richtig',
#   'schön',
#   'sehr',
#   'zentral',
#   'sauber',
#   'hell',
#   'und',
#   'ruhig',
#   'wenige',
#   'minute',
#   'von',
#   'busbahnhof',
#   'entfernt',
#   'wir',
#   'wurden',
#   'gerne',
#   'empfange',
#   'und',
#   'würden',
#   'da',
#   'wieder',
#   'übernachten'],
#  ['be',
#   'careful',
#   'as',
#   'the',
#   'cancellation',
#   'policy',
#   'is',
#   'horrible',
#   'i',
#   'couldn’t',
#   'travel',
#   'to',
#   'greece',
#   'because',
#   'of',
#   'covid',
#   'and',
#   'the',
#   'host',
#   'didn’t',
#   'care',
#   'and',
#   'didn’t',
#   'give',
#   'back',
#   'my',
#   'money',
#   'very',
#   'upset',
#   'to',
#   'see',
#   'people',
#   'not',
#   'being',
#   'sympathetic',
#   'in',
#   'such',
#   'horrible',
#   'covid',
#   'times',
#   'for',
#   'everyone'],
#  ['george',
#   'und',
#   'seine',
#   'frau',
#   'waren',
#   'super',
#   'nett',
#   'wir',
#   'hatten',
#   'ein',
#   'paar',
#   'wunderbare',
#   'tage',
#   'in',
#   'einem',
#   'süßen',
#   'kleinen',
#   'apartment',
#   'gelegen',
#   'in',
#   'mitten',
#   'von',
#   'olivenbäumen',
#   'und',
#   'mit',
#   'eben',
#   'jener',
#   'aussicht',
#   'die',
#   'auf',
#   'dem',
#   'foto',
#   'versprochen',
#   'wird',
#   'wir',
#   'hatten',
#   'viel',
#   'ruhe',
#   'waren',
#   'aber',
#   'in',
#   'der',
#   'vorsaison',
#   'da',
#   'die',
#   'küche',
#   'war',
#   'recht',
#   'spartanisch',
#   'ausgestattet',
#   'brein',
#   'auto',
#   'ist',
#   'hier',
#   'sehr',
#   'sinnvoll',
#   'da',
#   'die',
#   'geschäfte',
#   'ein',
#   'stück',
#   'entfernt',
#   'sind',
#   'ein',
#   'strand',
#   'ist',
#   'zu',
#   'fuß',
#   'zu',
#   'erreichen',
#   'für',
#   'die',
#   'anderen',
#   'ist',
#   'wieder',
#   'ein',
#   'auto',
#   'angesagt',
#   'br',
#   'brich',
#   'kann',
#   'die',
#   'bellevue',
#   'apts',
#   'auf',
#   'jeden',
#   'fall',
#   'empfehlen',
#   'wir',
#   'kommen',
#   'gerne',
#   'wieder'],
#  ['george',
#   'hat',
#   'uns',
#   'von',
#   'der',
#   'bushaltestelle',
#   'abgeholt',
#   'uns',
#   'freundlich',
#   'empfangen',
#   'und',
#   'sofort',
#   'alles',
#   'wichtige',
#   'rund',
#   'um',
#   'das',
#   'hotel',
#   'sowie',
#   'selbiges',
#   'gezeigt',
#   'und',
#   'erklärt',
#   'hatten',
#   'wir',
#   'fragen',
#   'war',
#   'er',
#   'stehts',
#   'kompetent',
#   'und',
#   'hilfreich',
#   'die',
#   'anlage',
#   'ist',
#   'schlicht',
#   'aber',
#   'ordentlich',
#   'unser',
#   'apartment',
#   'war',
#   'sauber',
#   'aber',
#   'sehr',
#   'spartanisch',
#   'ausgestattet',
#   'wir',
#   'haben',
#   'unseren',
#   'urlaub',
#   'in',
#   'agia',
#   'pelagia',
#   'genossen',
#   'und',
#   'kommen',
#   'gerne',
#   'wieder'],
#  ['uns',
#   'überzeugte',
#   'das',
#   'bellevue',
#   'village',
#   'vor',
#   'allem',
#   'durch',
#   'seine',
#   'lage',
#   'mit',
#   'ausblick',
#   'auf',
#   'das',
#   'meer',
#   'und',
#   'das',
#   'dorf',
#   'agia',
#   'pelagia',
#   'wir',
#   'haben',
#   'das',
#   'beim',
#   'täglichen',
#   'frühstück',
#   'auf',
#   'unserem',
#   'balkon',
#   'sehr',
#   'genossen',
#   'dafür',
#   'haben',
#   'wir',
#   'auch',
#   'gerne',
#   'die',
#   '5',
#   'minuten',
#   'fußweg',
#   'zum',
#   'strand',
#   'in',
#   'kauf',
#   'genommen',
#   'die',
#   'zimmer',
#   'an',
#   'sich',
#   'sind',
#   'zwar',
#   'spartanisch',
#   'eingerichtet',
#   'aber',
#   'absolut',
#   'ausreichend',
#   'ausgestattet',
#   'und',
#   'zudem',
#   'angenehm',
#   'geräumig',
#   'br',
#   'brder',
#   'größte',
#   'pluspunkt',
#   'des',
#   'bellevue',
#   'village',
#   'sind',
#   'george',
#   'und',
#   'seine',
#   'frau',
#   'tofi',
#   'sie',
#   'haben',
#   'uns',
#   'von',
#   'anfang',
#   'an',
#   'sehr',
#   'freundlich',
#   'aufgenommen',
#   'und',
#   'ihre',
#   'tips',
#   'bezüglich',
#   'organisation',
#   'und',
#   'reisezielen',
#   'waren',
#   'gold',
#   'wert',
#   'und',
#   'durch',
#   'keinen',
#   'reiseführer',
#   'zu',
#   'ersetzen',
#   'wir',
#   'hatten',
#   'die',
#   'ganze',
#   'zeit',
#   'über',
#   'eher',
#   'das',
#   'gefühl',
#   'bei',
#   'freunden',
#   'eingeladen',
#   'statt',
#   'in',
#   'einem',
#   'hotel',
#   'zu',
#   'sein',
#   'br',
#   'brdabei',
#   'sind',
#   'auch',
#   'die',
#   'abende',
#   'zu',
#   'nennen',
#   'an',
#   'denen',
#   'tofi',
#   'für',
#   'die',
#   'gäste',
#   'traditionelle',
#   'griechische',
#   'gerichte',
#   'anbietet',
#   'wir',
#   'können',
#   'nur',
#   'wärmstens',
#   'empfehlen',
#   'diese',
#   'möglichkeit',
#   'zu',
#   'nutzen',
#   'neben',
#   'gutem',
#   'essen',
#   'ergibt',
#   'sich',
#   'auch',
#   'die',
#   'möglichkeit',
#   'kontakte',
#   'zu',
#   'anderen',
#   'gästen',
#   'zu',
#   'knüpfen',
#   'br',
#   'branimation',
#   'party',
#   'und',
#   'musik',
#   'gibt',
#   'es',
#   'im',
#   'bellvue',
#   'village',
#   'bewusst',
#   'nicht',
#   'und',
#   'dies',
#   'würde',
#   'auch',
#   'die',
#   'atmosphäre',
#   'empfindlich',
#   'stören',
#   'wir',
#   'sind',
#   'den',
#   'ein',
#   'oder',
#   'anderen',
#   'abend',
#   'zum',
#   'feiern',
#   'nach',
#   'agia',
#   'pelagia',
#   'gelaufen',
#   'was',
#   'in',
#   'ca',
#   '15',
#   'min',
#   'zu',
#   'machen',
#   'ist',
#   'wer',
#   'allerdings',
#   'den',
#   'allinclusive',
#   'rund',
#   'um',
#   'die',
#   'uhrparty',
#   'urlaub',
#   'im',
#   'hotel',
#   'sucht',
#   'für',
#   'den',
#   'ist',
#   'das',
#   'bellevuevillage',
#   'die',
#   'falsche',
#   'adresse',
#   'br',
#   'bralles',
#   'in',
#   'allem',
#   'lebt',
#   'das',
#   'bellevue',
#   'village',
#   'durch',
#   'die',
#   'authentizität',
#   'von',
#   'george',
#   'und',
#   'tofi',
#   'die',
#   'bspw',
#   'keinen',
#   'gast',
#   'wieder',
#   'gehen',
#   'lassen',
#   'ohne',
#   'ihm',
#   'nicht',
#   'mindestens',
#   '10',
#   'griechische',
#   'wörter',
#   'beigebracht',
#   'haben',
#   'efkaristo',
#   'br',
#   'br',
#   'br',
#   'br'],
#  ['très',
#   'bon',
#   'accueil',
#   'nous',
#   'avons',
#   'trouvé',
#   'facilement',
#   'grâce',
#   'aux',
#   'indications',
#   'par',
#   'mail',
#   'de',
#   'george',
#   'jeter',
#   'un',
#   'oeil',
#   'à',
#   'street',
#   'view',
#   'avant',
#   'darriver',
#   'pour',
#   'visualiser',
#   'le',
#   'panneau',
#   'sur',
#   'la',
#   'route',
#   'tout',
#   'de',
#   'même',
#   'brbonne',
#   'situation',
#   'du',
#   'logement',
#   'près',
#   'de',
#   'la',
#   'plage',
#   'accessible',
#   'à',
#   'pieds',
#   'en',
#   'dix',
#   'minutes',
#   'mais',
#   'chemin',
#   'escarpé',
#   'proche',
#   'dhéraklion',
#   'et',
#   'de',
#   'la',
#   'route',
#   'principale',
#   'brnous',
#   'avions',
#   'loué',
#   'une',
#   'voiture',
#   'un',
#   'arrêt',
#   'de',
#   'bus',
#   'est',
#   'proche',
#   'cependant',
#   'mais',
#   'la',
#   'fréquence',
#   'semble',
#   'limitée',
#   'brgîte',
#   'très',
#   'confortable',
#   'propre',
#   'conforme',
#   'aux',
#   'photos',
#   'belle',
#   'piscine',
#   'petite',
#   'résidence',
#   'bril',
#   'y',
#   'a',
#   'de',
#   'quoi',
#   'faire',
#   'la',
#   'cuisine',
#   'mais',
#   'cest',
#   'le',
#   'strict',
#   'minimum',
#   'bren',
#   'conclusion',
#   'très',
#   'bien',
#   'à',
#   'recommander',
#   'brseul',
#   'bémol',
#   'quelques',
#   'soirs',
#   'un',
#   'peu',
#   'bruyant',
#   'du',
#   'fait',
#   'de',
#   'la',
#   'proximité',
#   'de',
#   'complexes',
#   'hôteliers',
#   'boites',
#   'de',
#   'nuit',
#   'dagia',
#   'pelagia'],
#  ['george',
#   'und',
#   'seine',
#   'frau',
#   'haben',
#   'uns',
#   'sehr',
#   'herzlich',
#   'begrüßt',
#   'wenn',
#   'wir',
#   'fragen',
#   'oder',
#   'sonst',
#   'ein',
#   'problem',
#   'hatten',
#   'wurde',
#   'sich',
#   'sofort',
#   'gekümmert',
#   'br'],
#  ['tout',
#   'à',
#   'été',
#   'parfait',
#   'du',
#   'début',
#   'à',
#   'la',
#   'finbrhate',
#   'dy',
#   'retourner',
#   'un',
#   'jourbrje',
#   'recommande',
#   'vivement'],
#  ['incroyable',
#   'séjour',
#   'tout',
#   'y',
#   'est',
#   'le',
#   'lieu',
#   'est',
#   'chaleureux',
#   'calme',
#   'et',
#   'typique',
#   'à',
#   'limage',
#   'de',
#   'lhôte'],
#  ['un',
#   'ensemble',
#   'de',
#   'bungalows',
#   'blancs',
#   'et',
#   'bleus',
#   'avec',
#   'pour',
#   'chacun',
#   'un',
#   'espace',
#   'exterieur',
#   'joliment',
#   'aménagé',
#   'avec',
#   'vue',
#   'sur',
#   'la',
#   'piscine',
#   'et',
#   'la',
#   'merbrune',
#   'très',
#   'jolie',
#   'piscine',
#   'très',
#   'propre',
#   'et',
#   'assez',
#   'grande',
#   'on',
#   'a',
#   'la',
#   'place',
#   'de',
#   'nagerbravec',
#   'autour',
#   'des',
#   'transats',
#   'et',
#   'des',
#   'parasols',
#   'et',
#   'une',
#   'très',
#   'jolie',
#   'vue',
#   'sur',
#   'la',
#   'merbraménagement',
#   'des',
#   'bungalows',
#   'tout',
#   'à',
#   'fait',
#   'confortable',
#   'brpossibilité',
#   'de',
#   'petit',
#   'déjeuner',
#   'et',
#   'de',
#   'diner',
#   'sur',
#   'place',
#   'sur',
#   'une',
#   'jolie',
#   'terrasse',
#   'ombragée',
#   'avec',
#   'vue',
#   'sur',
#   'les',
#   'criques',
#   'simple',
#   'et',
#   'cest',
#   'bonbrun',
#   'accueil',
#   'très',
#   'sympathique'],
#  ['wir',
#   'hatten',
#   'für',
#   '16',
#   'tage',
#   'eine',
#   'wunderbare',
#   'unterkunft',
#   'ausgestattet',
#   'mit',
#   'allem',
#   'was',
#   'man',
#   'braucht',
#   'zur',
#   'selbtstversorgung',
#   'mit',
#   'der',
#   'zusätzlichen',
#   'option',
#   'auf',
#   'ein',
#   'gutes',
#   'frühstück',
#   'und',
#   'sehr',
#   'leckere',
#   'griechische',
#   'küche',
#   'am',
#   'abend',
#   'zu',
#   'sehr',
#   'moderaten',
#   'preisen',
#   'die',
#   'lage',
#   'das',
#   'meer',
#   'der',
#   'pool',
#   'und',
#   'der',
#   'wunderbare',
#   'ausblick',
#   'vom',
#   'balkon',
#   'über',
#   'die',
#   'bucht',
#   'waren',
#   'für',
#   'uns',
#   'perfekt'],
#  ['wir',
#   'waren',
#   'ende',
#   'juli',
#   'in',
#   'der',
#   'super',
#   'schönen',
#   'unterkunft',
#   'von',
#   'george',
#   'die',
#   'anlage',
#   'ist',
#   'sehr',
#   'gepflegt',
#   'und',
#   'lädt',
#   'zum',
#   'entspannen',
#   'ein',
#   'brder',
#   'pool',
#   'war',
#   'ebenfalls',
#   'sehr',
#   'gepflegt',
#   'trotz',
#   'mehreren',
#   'unterkünften',
#   'in',
#   'der',
#   'anlage',
#   'hatten',
#   'wir',
#   'den',
#   'pool',
#   'meistens',
#   'für',
#   'uns',
#   'alleinebrgeorge',
#   'hatte',
#   'für',
#   'uns',
#   'viele',
#   'hilfreiche',
#   'lokale',
#   'tippsbrbrwir',
#   'würden',
#   'diese',
#   'unterkunft',
#   'jederzeit',
#   'wieder',
#   'buchen'],
#  ['george',
#   'und',
#   'fofi',
#   'sind',
#   'hervorragende',
#   'gastgeber',
#   'und',
#   'haben',
#   'viele',
#   'tolle',
#   'tipps',
#   'für',
#   'ausflüge',
#   'und',
#   'restaurants',
#   'brdie',
#   'lage',
#   'ist',
#   'einfach',
#   'wundervoll',
#   'wir',
#   'haben',
#   'jeden',
#   'abend',
#   'den',
#   'sonnenuntergang',
#   'von',
#   'unserer',
#   'terrasse',
#   'genossen',
#   'und',
#   'der',
#   'blick',
#   'auf',
#   'die',
#   'bucht',
#   'ist',
#   'einmalig'],
#  ['ausgezeichnete',
#   'unterkunft',
#   'mit',
#   'schönem',
#   'blick',
#   'aufs',
#   'meer',
#   'sehr',
#   'herzliche',
#   'gastgeber',
#   'die',
#   'um',
#   'das',
#   'wohl',
#   'ihrer',
#   'gäste',
#   'äußerst',
#   'bemüht',
#   'sind',
#   'bralles',
#   'sehr',
#   'sauber',
#   'und',
#   'gepflegt',
#   'george',
#   'und',
#   'fofi',
#   'verwöhnen',
#   'auf',
#   'wunsch',
#   'in',
#   'ihrer',
#   'taverne',
#   'mit',
#   'gutem',
#   'essen',
#   'der',
#   'weg',
#   'zum',
#   'strand',
#   'und',
#   'den',
#   'tavernen',
#   'dort',
#   'ist',
#   'gut',
#   'zu',
#   'fuß',
#   'zu',
#   'machenbrgerne',
#   'wieder'],
#  ['chambre',
#   'confortable',
#   'avec',
#   'un',
#   'frigo',
#   'un',
#   'balcon',
#   'et',
#   'une',
#   'belle',
#   'vue',
#   'sur',
#   'la',
#   'mer',
#   'comme',
#   'montré',
#   'sur',
#   'les',
#   'photos',
#   'lhôtel',
#   'est',
#   'vraiment',
#   'bien',
#   'situé',
#   'très',
#   'proche',
#   'de',
#   'la',
#   'plage',
#   'et',
#   'à',
#   '5',
#   'mn',
#   'du',
#   'centre',
#   'ville',
#   'petros',
#   'est',
#   'hôte',
#   'très',
#   'accueillant',
#   'seul',
#   'petit',
#   'bémol',
#   'la',
#   'petite',
#   'salle',
#   'de',
#   'bain',
#   'et',
#   'la',
#   'douche',
#   'pas',
#   'terrible'],
#  ['der',
#   'ausblick',
#   'vom',
#   'balkon',
#   'ist',
#   'wirklich',
#   'der',
#   'hammer',
#   'zur',
#   'begrüßung',
#   'gits',
#   'noch',
#   'eine',
#   'flasche',
#   'wasser',
#   'und',
#   'eine',
#   'flasche',
#   'wein',
#   'perfekt',
#   'um',
#   'die',
#   'schöne',
#   'sicht',
#   'zu',
#   'genießen',
#   'und',
#   'anzukommen',
#   'alles',
#   'ist',
#   'sauber',
#   'und',
#   'der',
#   'ort',
#   'sehr',
#   'schön',
#   'wir',
#   'haben',
#   'uns',
#   'pudelwohl',
#   'gefühlt',
#   'vielen',
#   'dank',
#   'petros'],
#  ['petros',
#   'war',
#   'ein',
#   'super',
#   'gastgeber',
#   'und',
#   'hat',
#   'uns',
#   'mit',
#   'einer',
#   'flasche',
#   'wein',
#   'willkommen',
#   'geheißen',
#   'die',
#   'einrichtung',
#   'und',
#   'das',
#   'zimmer',
#   'waren',
#   'okay',
#   'von',
#   'der',
#   'straße',
#   'her',
#   'ist',
#   'es',
#   'sehr',
#   'laut',
#   'und',
#   'man',
#   'kann',
#   'nur',
#   'mit',
#   'geschossenem',
#   'fenstern',
#   'schlafen',
#   'kurzer',
#   'weg',
#   'zum',
#   'strand',
#   'und',
#   'auch',
#   'entlang',
#   'an',
#   'der',
#   'promenade',
#   'zum',
#   'hafen',
#   'und',
#   'zum',
#   'stadtzentrum'],
#  ['pedro',
#   'jest',
#   'właścicielem',
#   'hotelu',
#   'który',
#   'odzieczył',
#   'po',
#   'ojcu',
#   'mirsini',
#   'to',
#   'mały',
#   'stary',
#   'i',
#   'bardzo',
#   'klimatyczny',
#   'hotel',
#   'z',
#   'lat',
#   '80',
#   'świetny',
#   'stosunek',
#   'jakości',
#   'do',
#   'ceny',
#   'bardzo',
#   'dobra',
#   'lokalizacja',
#   'widok',
#   'na',
#   'morze',
#   'choć',
#   'przy',
#   'dośc',
#   'ruchliwej',
#   'drodze',
#   'za',
#   'to',
#   'niedaleko',
#   'do',
#   'różnych',
#   'plaż',
#   'br',
#   'brsam',
#   'pedro',
#   'był',
#   'jednym',
#   'z',
#   'najlepszych',
#   'gospodarzy',
#   'z',
#   'jakim',
#   'mieliśmy',
#   'do',
#   'czynienia',
#   'na',
#   'abnb',
#   'bardzo',
#   'pomocny',
#   'polecił',
#   'nam',
#   'najlepsze',
#   'knajpy',
#   'plaże',
#   'i',
#   'miejsce',
#   'do',
#   'zwiedzenia',
#   'w',
#   'okolicy',
#   'można',
#   'też',
#   'było',
#   'bez',
#   'problemu',
#   'korzystać',
#   'z',
#   'hotelowej',
#   'kuchni',
#   'by',
#   'np',
#   'zrobić',
#   'sobie',
#   'śniadanie',
#   'br',
#   'brstrzał',
#   'w',
#   'dziesiątkę'],
#  ['der',
#   'nette',
#   'gastgeber',
#   'empfing',
#   'uns',
#   'mit',
#   'einer',
#   'gratis',
#   'flasche',
#   'weisswein',
#   'und',
#   'war',
#   'stets',
#   'sehr',
#   'freundlich',
#   'und',
#   'hilfsbereit',
#   'die',
#   'unterkunft',
#   'hatte',
#   'eine',
#   'wunderschönen',
#   'meerblick',
#   'ansonsten',
#   'handelt',
#   'es',
#   'sich',
#   'um',
#   'ein',
#   'hotel',
#   'welches',
#   'eine',
#   'besten',
#   'jahre',
#   'hinter',
#   'sich',
#   'hat',
#   'die',
#   'ausstattung',
#   'ist',
#   'in',
#   'ordnung',
#   'und',
#   'eher',
#   'einfach',
#   'das',
#   'preisleistungsverhältnis',
#   'stimmt',
#   'in',
#   'jedem',
#   'fall',
#   'der',
#   'ort',
#   'ist',
#   'landschaftlich',
#   'sehr',
#   'schön',
#   'und',
#   'vorallem',
#   'seasonbedingt',
#   'ein',
#   'urlaubsort',
#   'für',
#   'shoppingliebhaber'],
#  ['pétros',
#   'sait',
#   'très',
#   'bien',
#   'accueillir',
#   'sa',
#   'clientèle',
#   'avec',
#   'classe',
#   'et',
#   'gentillessebrnous',
#   'avons',
#   'tout',
#   'apprécié',
#   'de',
#   'notre',
#   'séjourbrdaniel',
#   'et',
#   'johanne'],
#  ['the',
#   'hotel',
#   'is',
#   'in',
#   'a',
#   'good',
#   'location',
#   'but',
#   'noisy',
#   'if',
#   'you',
#   'are',
#   'on',
#   'the',
#   'street',
#   'if',
#   'it',
#   'is',
#   'summer',
#   'time',
#   'when',
#   'you',
#   'go',
#   'to',
#   'the',
#   'hotel',
#   'checkthe',
#   'air',
#   'conditioning'],
#  ['petros',
#   'ist',
#   'sehr',
#   'netter',
#   'freundlicher',
#   'und',
#   'hilfsbereiter',
#   'gastgeber',
#   'die',
#   'unterkunft',
#   'liegt',
#   'unmittelbar',
#   'am',
#   'meer',
#   'sie',
#   'ist',
#   'sehr',
#   'sauber',
#   'wir',
#   'haben',
#   'uns',
#   'sehr',
#   'wohl',
#   'gefühlt',
#   'und',
#   'würden',
#   'jederzeit',
#   'wieder',
#   'kommen'],
#  ['the',
#   'view',
#   'from',
#   'the',
#   'balcony',
#   'and',
#   'the',
#   'location',
#   'cannot',
#   'be',
#   'beat',
#   'particularly',
#   'for',
#   'the',
#   'price',
#   'point',
#   'please',
#   'note',
#   'that',
#   'this',
#   'is',
#   'a',
#   'very',
#   'basic',
#   'hotel',
#   'room',
#   'two',
#   'beds',
#   'a',
#   'shower',
#   'an',
#   'air',
#   'conditioner',
#   'there',
#   'are',
#   'no',
#   'extras',
#   'no',
#   'hair',
#   'dryer',
#   'no',
#   'iron',
#   'no',
#   'coffee',
#   'no',
#   'blankets',
#   'beyond',
#   'the',
#   'bedsheets',
#   'etc',
#   'the',
#   'owners',
#   'were',
#   'very',
#   'kind',
#   'and',
#   'hospitable',
#   'and',
#   'again',
#   'the',
#   'location',
#   'is',
#   'perfect'],
#  ['in',
#   'die',
#   'jahre',
#   'gekommenes',
#   'aber',
#   'nett',
#   'geführtes',
#   'hotel',
#   'zu',
#   'einem',
#   'fairen',
#   'preis'],
#  ['wir',
#   'haben',
#   'im',
#   'juli',
#   'eine',
#   'schöne',
#   'woche',
#   'bei',
#   'lilian',
#   'verbracht',
#   'lilian',
#   'ist',
#   'eine',
#   'nette',
#   'freundliche',
#   'vermieterin',
#   'und',
#   'die',
#   'wohnung',
#   'war',
#   'sehr',
#   'sauber',
#   'das',
#   'bungalow',
#   'sah',
#   'aus',
#   'wie',
#   'auf',
#   'den',
#   'fotos',
#   'und',
#   'war',
#   'vor',
#   'allem',
#   'sehr',
#   'schön',
#   'großbei',
#   'der',
#   'hitze',
#   'haben',
#   'wir',
#   'uns',
#   'sehr',
#   'über',
#   'die',
#   'gut',
#   'funktionierende',
#   'klimaanlage',
#   'gefreut',
#   'die',
#   'entfernung',
#   'zum',
#   'strand',
#   'ist',
#   'wirklich',
#   'nur',
#   'sehr',
#   'gering',
#   'und',
#   'alles',
#   'andere',
#   'ist',
#   'auch',
#   'gut',
#   'fußläufig',
#   'zu',
#   'erreichen',
#   'besonders',
#   'gefallen',
#   'hat',
#   'uns',
#   'allen',
#   'der',
#   'schöne',
#   'feinsandige',
#   'strand',
#   'br'],
#  ['lilian',
#   'ist',
#   'eine',
#   'sehr',
#   'freundliche',
#   'gastgeberin',
#   'die',
#   'unterkunft',
#   'ist',
#   'sehr',
#   'sauber',
#   'und',
#   'es',
#   'findet',
#   'sich',
#   'auch',
#   'alles',
#   'zur',
#   'selbstversorgung',
#   'die',
#   'unterkunft',
#   'ist',
#   'perfekt',
#   'für',
#   'zwei',
#   'personen',
#   'kurzzeitig',
#   'sind',
#   'aber',
#   'auch',
#   'die',
#   'beiden',
#   'extrabetten',
#   'im',
#   'wohnraum',
#   'gut',
#   'nutzbar',
#   'wir',
#   'haben',
#   'uns',
#   'wohl',
#   'gefühlt'],
#  ['magnifique',
#   'séjour',
#   'eleni',
#   'ainsi',
#   'que',
#   'sa',
#   'maman',
#   'sont',
#   'très',
#   'gentilles',
#   'et',
#   'serviables',
#   'logement',
#   'propre',
#   'et',
#   'proche',
#   'des',
#   'supermarchés',
#   'restaurants',
#   'et',
#   'de',
#   'la',
#   'mer',
#   'br',
#   'brmerci',
#   'encore',
#   'pour',
#   'tout',
#   'eleni',
#   'br'],
#  ['ich',
#   'hatte',
#   'eine',
#   'wirklich',
#   'schöne',
#   'zeit',
#   'hier',
#   'das',
#   'apartment',
#   'entsprach',
#   'exakt',
#   'den',
#   'bildern',
#   'war',
#   'sehr',
#   'sauber',
#   'und',
#   'gemütlich',
#   'alle',
#   'waren',
#   'sehr',
#   'freundlich',
#   'und',
#   'wenn',
#   'ich',
#   'etwas',
#   'brauchte',
#   'wurde',
#   'mir',
#   'sofort',
#   'weitergeholfen',
#   'die',
#   'aussicht',
#   'aufs',
#   'meer',
#   'war',
#   'wunderschön',
#   'und',
#   'im',
#   'paar',
#   'minuten',
#   'entfernten',
#   'dörf',
#   'hat',
#   'man',
#   'alles',
#   'bekommen',
#   'was',
#   'man',
#   'so',
#   'braucht',
#   'ich',
#   'würde',
#   'jeder',
#   'zeit',
#   'wiederkommen'],
#  ['nettes',
#   'bedbreakfast',
#   'etwas',
#   'im',
#   'hinterland',
#   'der',
#   'strand',
#   'ist',
#   'jedoch',
#   'in',
#   'etwa',
#   '10',
#   'minuten',
#   'zu',
#   'fuß',
#   'erreichbar',
#   'wir',
#   'waren',
#   'froh',
#   'nicht',
#   'direkt',
#   'mitten',
#   'im',
#   'touristenort',
#   'zu',
#   'wohnen',
#   'leider',
#   'ist',
#   'die',
#   'autobahn',
#   'in',
#   'unmittelbarer',
#   'nähe',
#   'und',
#   'stört',
#   'etwasbrbrdie',
#   'unterkunft',
#   'an',
#   'sich',
#   'ist',
#   'super',
#   'die',
#   'apartments',
#   'groß',
#   'der',
#   'pool',
#   'sehr',
#   'schön',
#   'und',
#   'die',
#   'ganze',
#   'anlage',
#   'sehr',
#   'gepflegt',
#   'achtung',
#   'frühstück',
#   'kostet',
#   'pro',
#   'person',
#   'und',
#   'tag',
#   '6',
#   '€',
#   'extra'],
#  ['in',
#   'dieser',
#   'unterkunft',
#   'haben',
#   'wir',
#   'uns',
#   'sehr',
#   'wohl',
#   'gefühlt',
#   'es',
#   'war',
#   'alles',
#   'sehr',
#   'sauber',
#   'und',
#   'der',
#   'swimmingpool',
#   'war',
#   'ein',
#   'traum',
#   'es',
#   'gab',
#   'viele',
#   'tavernen',
#   'in',
#   'der',
#   'nähe',
#   'die',
#   'problemlos',
#   'zu',
#   'fuß',
#   'zu',
#   'erreichen',
#   'waren',
#   'und',
#   'auch',
#   'zum',
#   'strand',
#   'kann',
#   'man',
#   'in',
#   'ca',
#   '20',
#   'minuten',
#   'laufen',
#   'schön',
#   'ist',
#   'dass',
#   'die',
#   'unterkunft',
#   'etwas',
#   'abseits',
#   'der',
#   'touristenströme',
#   'liegt',
#   'diese',
#   'vorteile',
#   'machen',
#   'die',
#   'verkehrsgeräusche',
#   'der',
#   'nahen',
#   'nationalstraße',
#   'wieder',
#   'wett',
#   'wobei',
#   'man',
#   'nachts',
#   'ohne',
#   'probleme',
#   'schlafen',
#   'kann',
#   'und',
#   'man',
#   'tagsüber',
#   'sowieso',
#   'die',
#   'meiste',
#   'zeit',
#   'unterwegs',
#   'ist',
#   'ich',
#   'würde',
#   'mich',
#   'jederzeit',
#   'wieder',
#   'bei',
#   'villa',
#   'life',
#   'einmieten'],
#  ['prima',
#   'verblijf',
#   'zeker',
#   'voor',
#   'die',
#   'locatie',
#   'een',
#   'hele',
#   'fijne',
#   'plek',
#   'het',
#   'is',
#   'wel',
#   'duidelijk',
#   'een',
#   'apartementencomplex',
#   'zoals',
#   'je',
#   'die',
#   'gewend',
#   'bent',
#   'het',
#   'geluid',
#   'van',
#   'de',
#   'weg',
#   'met',
#   'slapen',
#   'hadden',
#   'wij',
#   'geen',
#   'last',
#   'van',
#   'alleen',
#   'als',
#   'je',
#   'buiten',
#   'zit',
#   'maar',
#   'het',
# ...
#   'supermarkt',
#   'mit',
#   'einem',
#   'erstaunlich',
#   'großen',
#   'sortiment',
#   'hier',
#   'bekommt',
#   'man',
#   'von',
#   'kinderkleidung',
#   'über',
#   'werkzeug',
#   'bis',
#   'zur',
#   'milch',
#   'fast',
#   'alles',
#   'eine',
#   'bäckerei',
#   'befindet',
#   'sich',
#   'an',
#   'der',
#   'hauptstraße',
#   'man',
#   'sollte',
#   'aber',
#   'nicht',
#   'zu',
#   'lange',
#   'schlafen',
#   'wenn',
#   'man',
#   'noch',
#   'frisches',
#   'brot',
#   'haben',
#   'möchte',
#   'wir',
#   'hatten',
#   'eine',
#   'sehr',
#   'schöne',
#   'woche',
#   'im',
#   'mountain',
#   'paradise',
#   'und',
#   'kommen',
#   'gerne',
#   'wieder'],
#  ['das',
#   'haus',
#   'ist',
#   'sehr',
#   'schön',
#   'und',
#   'die',
#   'kommunikation',
#   'mit',
#   'despina',
#   'die',
#   'das',
#   'haus',
#   'organisiert',
#   'war',
#   'ausgesprochen',
#   'freundlich',
#   'und',
#   'einfach',
#   'alles',
#   'lief',
#   'völlig',
#   'ohne',
#   'probleme',
#   'nur',
#   'zu',
#   'empfehlen'],
#  ['wer',
#   'kreta',
#   'authentisch',
#   'in',
#   'einem',
#   'großartigen',
#   'ambiente',
#   'erleben',
#   'möchte',
#   'wird',
#   'begeistert',
#   'sein',
#   'so',
#   'wie',
#   'wir',
#   'mit',
#   'großer',
#   'herzlichkeit',
#   'hat',
#   'despina',
#   'uns',
#   'begrüßt',
#   'das',
#   'haus',
#   'ist',
#   'geschmackvoll',
#   'und',
#   'mit',
#   'sehr',
#   'viel',
#   'liebe',
#   'zum',
#   'detail',
#   'eingerichtet',
#   'und',
#   'liegt',
#   'etwas',
#   'abseits',
#   'der',
#   'durchgangsstraße',
#   'traumhaft',
#   'auf',
#   'einem',
#   'hügel',
#   'am',
#   'ende',
#   'des',
#   'tales',
#   'mit',
#   'viel',
#   'sonnebralles',
#   'war',
#   'sehr',
#   'sauber',
#   'und',
#   'wir',
#   'danken',
#   'despina',
#   'für',
#   'sehr',
#   'erholsame',
#   'tage',
#   'und',
#   'ihre',
#   'große',
#   'gastfreundschaft',
#   'und',
#   'werden',
#   'sicher',
#   'wiederkommenbrbrkatrin',
#   'und',
#   'michael'],
#  ['nous',
#   'avons',
#   'passé',
#   '4',
#   'superbes',
#   'jours',
#   'dans',
#   'cette',
#   'maison',
#   'la',
#   'région',
#   'est',
#   'magnifique',
#   'et',
#   'très',
#   'verte',
#   'si',
#   'vous',
#   'souhaitez',
#   'profiter',
#   'de',
#   'la',
#   'piscine',
#   'je',
#   'vous',
#   'déconseille',
#   'de',
#   'venir',
#   'à',
#   'partir',
#   'de',
#   'fin',
#   'octobre',
#   'la',
#   'region',
#   'est',
#   'très',
#   'humide',
#   'montagne',
#   'obligebrles',
#   'équipements',
#   'étaient',
#   'très',
#   'bienbrla',
#   'cheminée',
#   'est',
#   'très',
#   'agréable',
#   'à',
#   'utiliserbrnôtre',
#   'hôte',
#   'n’a',
#   'pas',
#   'pu',
#   'être',
#   'disponible',
#   'mais',
#   'tout',
#   'était',
#   'parfaitement',
#   'préparé',
#   'pour',
#   'notre',
#   'arrivé',
#   'despina',
#   'était',
#   'très',
#   'réactif',
#   'pour',
#   'satisfaire',
#   'notre',
#   'confortbrnous',
#   'vous',
#   'conseillons',
#   'la',
#   'région',
#   'et',
#   'la',
#   'maison',
#   'si',
#   'vous',
#   'aimez',
#   'faire',
#   'de',
#   'la',
#   'randonnée'],
#  ['très',
#   'bon',
#   'séjour',
#   'dans',
#   'la',
#   'maison',
#   'de',
#   'despina',
#   'située',
#   'dans',
#   'le',
#   'petit',
#   'village',
#   'paisible',
#   'daskifou',
#   'vue',
#   'magnifique',
#   'sur',
#   'la',
#   'vallée',
#   'et',
#   'les',
#   'montagnes',
#   'environnantes',
#   'accueil',
#   'très',
#   'chaleureux',
#   'de',
#   'despina',
#   'merci',
#   'pour',
#   'tout'],
#  ['wir',
#   'waren',
#   '4',
#   'wochen',
#   'website',
#   'hidden',
#   'by',
#   'airbnb',
#   'ist',
#   'zwar',
#   'nicht',
#   'so',
#   'warm',
#   'aber',
#   'das',
#   'war',
#   'uns',
#   'von',
#   'vornherein',
#   'klaroktober',
#   'november',
#   'dafür',
#   'haben',
#   'wir',
#   'einen',
#   'wagen',
#   'um',
#   'in',
#   'die',
#   'wärmeren',
#   'gefilde',
#   'zu',
#   'fahren',
#   'die',
#   'fahrt',
#   'zum',
#   'haus',
#   'ist',
#   'steil',
#   'das',
#   'bedeutet',
#   'ich',
#   'würde',
#   'keinen',
#   'sehr',
#   'grossen',
#   'wagen',
#   'wie',
#   'einen',
#   'bus',
#   'mietender',
#   'ausgangspunkt',
#   'ist',
#   'sehr',
#   'gut',
#   'das',
#   'haus',
#   'ist',
#   'sehr',
#   'schön',
#   'eingerichtet',
#   'die',
#   'lage',
#   'ist',
#   'sehr',
#   'gut',
#   'wir',
#   'hatten',
#   'unsere',
#   'ruhe',
#   'wir',
#   'hatten',
#   'zur',
#   'begrüßung',
#   'einen',
#   'kleines',
#   'geschenk',
#   'in',
#   'form',
#   'einen',
#   'kuchen',
#   'und',
#   'anderer',
#   'leckeren',
#   'sachen',
#   'besucher',
#   'wie',
#   'katzen',
#   'und',
#   'ziegen',
#   'gab',
#   'es',
#   'auch',
#   'öfters',
#   'kurz',
#   'gesagt',
#   'wir',
#   'hatten',
#   'einen',
#   'sehr',
#   'schönen',
#   'urlaub',
#   'und',
#   'können',
#   'das',
#   'haus',
#   'sehr',
#   'empfehlen'],
#  ['sehr',
#   'schönes',
#   'kleines',
#   'ensemble',
#   'zweier',
#   'ferienhäuser',
#   'mit',
#   'pool',
#   'brunser',
#   'haus',
#   'war',
#   'super',
#   'ausgestattet',
#   'und',
#   'sehr',
#   'geschmackvoll',
#   'eingerichtet',
#   'die',
#   'gastgeberin',
#   'hat',
#   'uns',
#   'mit',
#   'kleinen',
#   'schmankerln',
#   'verwöhnt',
#   'wir',
#   'haben',
#   'uns',
#   'sehr',
#   'wohl',
#   'gefühlt',
#   'brwunderbare',
#   'adresse',
#   'für',
#   'ruhige',
#   'und',
#   'entspannte',
#   'ferien',
#   'das',
#   'haus',
#   'liegt',
#   'mitten',
#   'in',
#   'olivenhainen',
#   'und',
#   'war',
#   'nicht',
#   'ganz',
#   'leicht',
#   'zu',
#   'finden',
#   'aber',
#   'die',
#   'suche',
#   'hat',
#   'sich',
#   'gelohnt',
#   'br',
#   'brgeorg',
#   'yvonne',
#   'und',
#   'maurice',
#   'im',
#   'oktober',
#   '2013'],
#  ['gastgeber',
#   'sehr',
#   'freundlich',
#   'und',
#   'zuvorkommend',
#   'die',
#   'beschreibung',
#   'der',
#   'unterkunft',
#   'war',
#   'teilweise',
#   'inkorrekt',
#   'die',
#   'wohnung',
#   'vassiliki',
#   'ist',
#   'nur',
#   '1',
#   'teil',
#   'eines',
#   'wohnhauses',
#   'und',
#   'besteht',
#   'praktisch',
#   'nur',
#   'aus',
#   '1',
#   'grossen',
#   'raum',
#   'es',
#   'gibt',
#   'keine',
#   '2',
#   'schlafzimmer',
#   'sondern',
#   'nur',
#   'jeweils',
#   'am',
#   'kopfende',
#   '2',
#   'betten',
#   'auf',
#   'der',
#   'mezzanine',
#   'da',
#   'der',
#   'gebäudeteil',
#   'voll',
#   'nach',
#   'süden',
#   'gerichtet',
#   'ist',
#   'ist',
#   'es',
#   'nachts',
#   'auch',
#   'bei',
#   'geöffnteten',
#   'fenstern',
#   'sehr',
#   'sehr',
#   'warm',
#   'isolierung',
#   'des',
#   'daches',
#   'ist',
#   'auch',
#   'sehr',
#   'gering',
#   'bis',
#   'inexistent',
#   'da',
#   'es',
#   'kein',
#   'separates',
#   'haus',
#   'ist',
#   'kann',
#   'man',
#   'sich',
#   'auch',
#   'nicht',
#   'hinter',
#   'das',
#   'haus',
#   'setzen',
#   'um',
#   'sich',
#   'vor',
#   'sonenhitze',
#   'zu',
#   'schützen',
#   'in',
#   'diesem',
#   'raum',
#   'wäre',
#   'eine',
#   'klimanalage',
#   'absolut',
#   'erforderlich',
#   'der',
#   'sanitärraum',
#   'ist',
#   'sehr',
#   'klein',
#   'und',
#   'das',
#   'wc',
#   'ist',
#   'in',
#   'der',
#   'dusche',
#   'intergriert',
#   'was',
#   'gewöhnungsbedürftig',
#   'ist',
#   'br',
#   'brsonst',
#   'super',
#   'lage',
#   'sehr',
#   'ruhig',
#   'sehr',
#   'guter',
#   'swimming',
#   'pool',
#   'wohnung',
#   'gut',
#   'ausgestattet',
#   'br',
#   'br',
#   'br',
#   'br'],
#  ['arrivée',
#   'de',
#   'laéroport',
#   'arrivée',
#   'dans',
#   'la',
#   'maison',
#   'très',
#   'cahotique',
#   'très',
#   'compliqué',
#   'à',
#   'trouver',
#   'il',
#   'faudrait',
#   'organiser',
#   'un',
#   'moyen',
#   'plus',
#   'simplebr',
#   'clef',
#   'wifi',
#   'proposée',
#   'sur',
#   'le',
#   'site',
#   'mais',
#   'elle',
#   'ne',
#   'fonctionnait',
#   'pas',
#   'br',
#   'ventilateur',
#   'cassé',
#   'assurait',
#   'mal',
#   'le',
#   'rafraichissement',
#   'par',
#   'conséquent',
#   'nuits',
#   'trop',
#   'chaudesbr',
#   'douche',
#   'complication',
#   'au',
#   'niveau',
#   'eau',
#   'chaude',
#   'car',
#   'si',
#   'les',
#   'voisins',
#   'prennent',
#   'leur',
#   'douche',
#   'avant',
#   'vous',
#   'cest',
#   'fichu',
#   'et',
#   'dans',
#   'une',
#   'douche',
#   'quelque',
#   'peu',
#   'réduitebr',
#   'si',
#   'vous',
#   'aimez',
#   'le',
#   'chant',
#   'des',
#   'cigales',
#   'à',
#   'outrance',
#   'vous',
#   'serez',
#   'servisbr',
#   'faire',
#   'attention',
#   'au',
#   'produit',
#   'antiinsectes',
#   'car',
#   'persistant',
#   'brbr',
#   'vue',
#   'et',
#   'paysages',
#   'très',
#   'beauxbr',
#   'parfum',
#   'des',
#   'figuiers',
#   'bienbr',
#   'piscine',
#   'bienbr',
#   'espaces',
#   'autour',
#   'de',
#   'la',
#   'maison',
#   'bienbr',
#   'passage',
#   'de',
#   'mikela',
#   'et',
#   'john',
#   'bien'],
#  ['nous',
#   'avons',
#   'passé',
#   'des',
#   'vacances',
#   'de',
#   'rêve',
#   'au',
#   'milieux',
#   'des',
#   'oliviers',
#   'le',
#   'site',
#   'est',
#   'de',
#   'toute',
#   'beauté',
#   'la',
#   'maison',
#   'très',
#   'authentique',
#   'et',
#   'la',
#   'piscine',
#   'idéale',
#   'attention',
#   'le',
#   'lieu',
#   'est',
#   'un',
#   'peu',
#   'isolé',
#   'et',
#   'l’accès',
#   'pas',
#   'forcement',
#   'facile',
#   'si',
#   'vous',
#   'avez',
#   'une',
#   'petite',
#   'voiture',
#   'de',
#   'location',
#   'malgré',
#   'tout',
#   'cest',
#   'un',
#   'bon',
#   'point',
#   'de',
#   'départ',
#   'pour',
#   'visiter',
#   'tout',
#   'louest',
#   'de',
#   'la',
#   'crète',
#   'dont',
#   'nous',
#   'avons',
#   'adoré',
#   'ses',
#   'magnifiques',
#   'plages',
#   'et',
#   'lagons',
#   'nous',
#   'sommes',
#   'arrivés',
#   'très',
#   'tard',
#   'le',
#   'soir',
#   'mais',
#   'mikela',
#   'avait',
#   'tout',
#   'prévu',
#   'pour',
#   'notre',
#   'petit',
#   'déjeuné',
#   'tout',
#   'est',
#   'prévu',
#   'si',
#   'vous',
#   'voulez',
#   'cuisiner',
#   'les',
#   'bons',
#   'produits',
#   'crétois',
#   'le',
#   'personnel',
#   'dentretien',
#   'est',
#   'très',
#   'discret',
#   'si',
#   'vous',
#   'aimez',
#   'la',
#   'nature',
#   'la',
#   'tranquillité',
#   'et',
#   'lindépendance',
#   'ce',
#   'site',
#   'est',
#   'idéal',
#   'merci',
#   'pour',
#   'ces',
#   'belles',
#   'vacances'],
#  ['un',
#   'lugar',
#   'precioso',
#   'rural',
#   'y',
#   'con',
#   'mucho',
#   'encanto',
#   'muy',
#   'recomendable',
#   'mucho',
#   'silencio',
#   'tan',
#   'solo',
#   'las',
#   'cigarras',
#   'durante',
#   'el',
#   'dia',
#   'la',
#   'conexion',
#   'wifi',
#   'no',
#   'fue',
#   'posible'],
#  ['wenn',
#   'man',
#   'ruhe',
#   'und',
#   'abgeschiedenheit',
#   'inmitten',
#   'der',
#   'natur',
#   'sucht',
#   'ist',
#   'man',
#   'hier',
#   'genau',
#   'richtig',
#   'ich',
#   'kannte',
#   'das',
#   'haus',
#   'bereits',
#   'von',
#   'freunden',
#   'und',
#   'wollte',
#   'deshalb',
#   'unbedingt',
#   'dort',
#   'hin',
#   'die',
#   'schlüsselübergabe',
#   'war',
#   'einfach',
#   'und',
#   'im',
#   'haus',
#   'wurden',
#   'wir',
#   'am',
#   'tag',
#   'der',
#   'ankunft',
#   'mit',
#   'leckereien',
#   'wasser',
#   'und',
#   'saft',
#   'verwöhnt',
#   'das',
#   'bad',
#   'ist',
#   'recht',
#   'klein',
#   'und',
#   'die',
#   'dusche',
#   'etwas',
#   'gewöhnungsbedürftig',
#   'weil',
#   'sie',
#   'direkt',
#   'neben',
#   'der',
#   'toilette',
#   'war',
#   'und',
#   'während',
#   'des',
#   'duschens',
#   'komplett',
#   'nass',
#   'wurde',
#   'braber',
#   'eigentlich',
#   'ist',
#   'das',
#   'auch',
#   'egal',
#   'weil',
#   'man',
#   'die',
#   'meiste',
#   'zeit',
#   'eh',
#   'draußen',
#   'ist',
#   'in',
#   'der',
#   'küche',
#   'gab',
#   'es',
#   'alles',
#   'was',
#   'man',
#   'brauchtebrwir',
#   'kommen',
#   'bestimmt',
#   'wieder'],
#  ['in',
#   'kurzen',
#   'worten',
#   'absolut',
#   'schön',
#   'super',
#   'sauber',
#   'und',
#   'sehr',
#   'nette',
#   'leute',
#   'br',
#   'brdie',
#   'kommunikation',
#   'vorab',
#   'war',
#   'top',
#   'und',
#   'als',
#   'wir',
#   'angereist',
#   'sind',
#   'hat',
#   'irene',
#   'schon',
#   'auf',
#   'uns',
#   'gewartet',
#   'um',
#   'uns',
#   'die',
#   'schlüssel',
#   'zu',
#   'übergeben',
#   'vorgefunden',
#   'haben',
#   'wir',
#   'ein',
#   'ganz',
#   'tolles',
#   'altstadthaus',
#   'dass',
#   'liebevoll',
#   'bis',
#   'ins',
#   'detail',
#   'renoviert',
#   'wurde',
#   'zustand',
#   '1a',
#   'und',
#   'perfekt',
#   'gereinigt',
#   'die',
#   'bilder',
#   'in',
#   'der',
#   'anzeige',
#   'sind',
#   'sehr',
#   'repräsentativ',
#   'die',
#   'ausstattung',
#   'war',
#   'hochwertig',
#   'und',
#   'komplett',
#   'die',
#   'lage',
#   'sehr',
#   'zentral',
#   'in',
#   'der',
#   'altstadt',
#   'und',
#   'trotzdem',
#   'sehr',
#   'ruhig',
#   'am',
#   'ende',
#   'einer',
#   'sackgasse',
#   'der',
#   'sandstrand',
#   'ist',
#   'etwa',
#   '10',
#   'minuten',
#   'zu',
#   'fuss',
#   'entfernt',
#   'und',
#   'ein',
#   'kleiner',
#   'supermarkt',
#   'nur',
#   'ein',
#   'paar',
#   'meter',
#   'entfernt',
#   'brwir',
#   'würden',
#   'auf',
#   'jeden',
#   'fall',
#   'wiederkommen',
#   'und',
#   'es',
#   'hat',
#   'uns',
#   'sehr',
#   'gefallen',
#   'absolut',
#   'empfehlenswert',
#   'brkleines',
#   'manko',
#   'ist',
#   'lediglich',
#   'die',
#   'parkplatzsituation',
#   'für',
#   'den',
#   'fall',
#   'dass',
#   'man',
#   'einen',
#   'mietwagen',
#   'hat',
#   'hier',
#   'kann',
#   'es',
#   'durchaus',
#   'passieren',
#   'dass',
#   'man',
#   'etwas',
#   'suchen',
#   'muss',
#   'und',
#   '10',
#   'minuten',
#   'laufen',
#   'muss'],
#  ['wir',
#   'hatten',
#   'eine',
#   'super',
#   'tolle',
#   'woche',
#   'auf',
#   'kreta',
#   'trotz',
#   'viel',
#   'regen',
#   'denn',
#   'die',
#   'total',
#   'süße',
#   'wohnung',
#   'hat',
#   'uns',
#   'für',
#   'das',
#   'schlechte',
#   'wetter',
#   'entschädigt',
#   'die',
#   'bilder',
#   'entsprechen',
#   'der',
#   'wirklichkeit',
#   'man',
#   'konnte',
#   'auch',
#   'gut',
#   'mal',
#   'ein',
#   'gemütlichen',
#   'nachmittag',
#   'oder',
#   'abend',
#   'zu',
#   'hause',
#   'verbringen',
#   'sehr',
#   'sauber',
#   'die',
#   'lage',
#   'ist',
#   'super',
#   'zentral',
#   'in',
#   'der',
#   'altstadt',
#   'gelegen',
#   'man',
#   'braucht',
#   'eigentlich',
#   'kein',
#   'auto',
#   'aglaia',
#   'war',
#   'jederzeit',
#   'per',
#   'mail',
#   'ansprechbar',
#   'und',
#   'immer',
#   'bereit',
#   'für',
#   'eine',
#   'auskunft',
#   'sie',
#   'hat',
#   'uns',
#   'am',
#   'flughafen',
#   'abgeholt',
#   'und',
#   'zu',
#   'unserem',
#   'bus',
#   'gebracht',
#   'wie',
#   'selbstverständlich',
#   'alles',
#   'sehr',
#   'herzlich',
#   'vielen',
#   'dank',
#   'nochmals',
#   'petra'],
#  ['accueil',
#   'parfait',
#   'nous',
#   'sommes',
#   'arrivés',
#   'tard',
#   'à',
#   'la',
#   'maison',
#   'aglaia',
#   'nous',
#   'avait',
#   'préparé',
#   'une',
#   'merveilleuse',
#   'salade',
#   'grecque',
#   'elle',
#   'avait',
#   'prévu',
#   'également',
#   'des',
#   'fruits',
#   'des',
#   'biscuits',
#   'etc',
#   'brnous',
#   'nous',
#   'sommes',
#   'tout',
#   'de',
#   'suite',
#   'sentis',
#   'bien',
#   'dans',
#   'cette',
#   'charmante',
#   'petite',
#   'maison',
#   'tout',
#   'est',
#   'délicat',
#   'et',
#   'propre',
#   'brsituation',
#   'géographique',
#   'top',
#   'à',
#   'deux',
#   'pas',
#   'du',
#   'port',
#   'braglaia',
#   'nous',
#   'a',
#   'très',
#   'bien',
#   'conseillé',
#   'sur',
#   'les',
#   'restaurants',
#   'à',
#   'tester',
#   'brbref',
#   'nous',
#   'avons',
#   'adoré',
#   'notre',
#   'séjour',
#   'br'],
#  ['super',
#   'accueil',
#   'plein',
#   'de',
#   'bonnes',
#   'infos',
#   'daglaia',
#   'et',
#   'de',
#   'sa',
#   'mère',
#   'brla',
#   'maison',
#   'est',
#   'vraiment',
#   'très',
#   'sympa',
#   'on',
#   'a',
#   'adoré',
#   'la',
#   'terrasse',
#   'brtrès',
#   'bien',
#   'située',
#   'dans',
#   'la',
#   'vieille',
#   'vile',
#   'à',
#   'deux',
#   'pas',
#   'du',
#   'port',
#   'dans',
#   'une',
#   'ruelle',
#   'au',
#   'calme',
#   'aucun',
#   'problème',
#   'pour',
#   'se',
#   'garer',
#   'pas',
#   'très',
#   'loin',
#   'parfait',
#   'br',
#   'br',
#   'br'],
#  ['logement',
#   'parfait',
#   'idéalement',
#   'situé',
#   'à',
#   'lentrée',
#   'du',
#   'centre',
#   'historique',
#   'de',
#   'chania',
#   'tres',
#   'propre',
#   'magnifiquement',
#   'décoré',
#   'avec',
#   'tout',
#   'le',
#   'nécessaire',
#   'et',
#   'même',
#   'plus',
#   'corbeille',
#   'de',
#   'fruits',
#   'vin',
#   'beurre',
#   'confiture',
#   'plus',
#   'les',
#   'draps',
#   'changés',
#   'en',
#   'milieu',
#   'de',
#   'semaine',
#   'avec',
#   'des',
#   'gâteaux',
#   'offerts',
#   'encore',
#   'merci',
#   'pour',
#   'ce',
#   'sejour'],
#  ['aglaia',
#   'y',
#   'su',
#   'madre',
#   'son',
#   'excelentes',
#   'anfitrionas',
#   'el',
#   'lugar',
#   'es',
#   'inmejorable',
#   'lindo',
#   'y',
#   'muy',
#   'práctico',
#   'apartamento',
#   'está',
#   'en',
#   'el',
#   'mejor',
#   'lugar',
#   'de',
#   'chania',
#   'para',
#   'poder',
#   'iniciar',
#   'los',
#   'paseos',
#   'caminar',
#   'por',
#   'las',
#   'bellas',
#   'callecitas',
#   'comprar',
#   'y',
#   'poder',
#   'comer',
#   'muuuy',
#   'bien',
#   'no',
#   'duden',
#   'en',
#   'quedarse',
#   'aquí'],
#  ['située',
#   'dans',
#   'le',
#   'quartier',
#   'du',
#   'port',
#   'vénitien',
#   'la',
#   'maison',
#   'daglaia',
#   'est',
#   'un',
#   'havre',
#   'de',
#   'paix',
#   'et',
#   'de',
#   'sérénité',
#   'dans',
#   'ce',
#   'cocon',
#   'blanc',
#   'tout',
#   'est',
#   'fait',
#   'par',
#   'notre',
#   'hôte',
#   'pour',
#   'que',
#   'notre',
#   'séjour',
#   'se',
#   'déroule',
#   'le',
#   'mieux',
#   'possiblebrmalgré',
#   'une',
#   'arrivée',
#   'tardive',
#   'tout',
#   'a',
#   'été',
#   'fait',
#   'pour',
#   'un',
#   'accueil',
#   'agréablebrla',
#   'maison',
#   'est',
#   'impeccable',
#   'rien',
#   'ne',
#   'manquebra',
#   'conseiller',
#   'à',
#   'tous',
#   'ceux',
#   'qui',
#   'aiment',
#   'se',
#   'retrouver',
#   'dans',
#   'un',
#   'endroit',
#   'calme',
#   'et',
#   'chaleureux',
#   'à',
#   'la',
#   'foisbr'],
#  ...]

# %%
from itertools import chain

flatten_comments = list(chain.from_iterable(tokenized_comments))
unique_words = set(flatten_comments)

# %%
WordsForids = {"":0}
idsForWords = {0:""}

for Id , word in enumerate(unique_words):
    WordsForids[word] = Id + 1

for Id , word in enumerate(unique_words):
    idsForWords[Id + 1] = word

# %%
# from word to number

temp = []
X = []

for comment in tokenized_comments:
    temp = []
    for word in comment:
        temp.append(WordsForids[word])
    X.append(temp)

X
# Out:
# [[73308,
#   42835,
#   40315,
#   792,
#   56469,
#   92396,
#   121134,
#   29666,
#   36206,
#   67927,
#   72509,
#   65898,
#   10228,
#   106249,
#   101978,
#   73308,
#   111253,
#   53890,
#   121772,
#   74087,
#   115739,
#   21633,
#   122112,
#   94965,
#   47071,
#   26124,
#   103233,
#   13500,
#   29666,
#   67927,
#   112397,
#   79716,
#   115739,
#   118688,
#   19467,
#   40617,
#   124069],
#  [28425,
#   55462,
#   64910,
#   39005,
#   60449,
#   67671,
#   87777,
#   121134,
#   36220,
#   97870,
#   49703,
#   168,
#   68040,
#   80638,
#   51616,
#   67965,
#   34677,
#   69766,
#   116768,
#   58894,
#   30820,
#   23098,
#   28294,
#   52981,
#   930,
#   58894,
#   82492,
#   49703,
#   108968,
#   168,
#   118218,
#   65673,
#   39005,
#   2207,
#   811,
#   21576,
#   39005,
#   60449,
#   89274,
#   23098,
#   34677,
#   98042,
#   82355,
#   69449,
#   94373,
#   39700,
#   44640,
#   123495,
#   168,
#   127412,
#   10384,
#   39005,
#   2207,
#   62184,
#   102617,
#   85595,
#   58894,
#   93111,
#   49123,
#   64910,
#   39005,
#   13838,
#   23098,
#   111361,
#   78627,
#   107682,
#   44640,
#   100529,
#   106889,
#   46020,
#   26525,
#   29368,
#   97870,
#   59899,
#   23098,
#   48100,
#   121134,
#   45099,
#   35899,
#   27517,
#   68236,
#   82066,
#   49703,
#   45718,
#   116655,
#   31331,
#   59899,
#   23098,
#   48100,
#   82946,
#   45099,
#   45718,
#   6156,
#   62362,
#   36843,
#   55435,
#   23098,
#   48100,
#   1593,
#   25349,
#   45099,
#   68236,
#   66354,
#   49703,
#   68236,
#   74507,
#   93903,
#   44640,
#   114734,
#   49703,
#   8133,
#   64910,
#   28425,
#   9471,
#   128259,
#   123282,
#   1593,
#   102617,
#   128423,
#   48782,
#   85595,
#   47759,
#   35225,
#   97870,
#   47230,
#   64910,
#   28425,
#   4188,
#   28712,
#   49703,
#   42836,
#   107117,
#   2207,
#   116186,
#   69449,
#   66354,
#   85595,
#   39005,
#   120656,
#   30489,
#   16101,
#   35225,
#   22585,
#   30489,
#   69449,
#   40253,
#   46252,
#   69766,
#   4526,
#   125356,
#   85595,
#   49020],
#  [118771,
#   126341,
#   71804,
#   76125,
#   70144,
#   82946,
#   69766,
#   104471,
#   58894,
#   81451,
#   23098,
#   29474,
#   117414,
#   123020,
#   49703,
#   50996,
#   33025,
#   8888,
#   18468,
#   117500,
#   34496,
#   70144,
#   117949,
#   121134,
#   107117,
#   126341,
#   50103,
#   107682,
#   32734,
#   107761,
#   85595,
#   69449,
#   97870,
#   119194,
#   75214,
#   43922,
#   85595,
#   106114,
#   71248,
#   49703,
#   18859,
#   126289,
#   35018,
#   87253,
#   53564,
#   65155,
#   97038,
#   58894,
#   28702,
#   73876,
#   49703,
#   107630,
#   54256,
#   69449,
#   42772,
#   23098,
#   84885,
#   32101,
#   23098,
#   42649,
#   85595,
#   69449,
#   20024,
#   53564,
#   33845,
#   17627,
#   17627,
#   107802,
#   23098,
#   107936,
#   127398,
#   117454,
#   21166,
#   27533,
#   93277],
#  [112397,
#   7341,
#   121134,
#   115739,
#   82946,
#   82541,
#   112397,
#   38767,
#   115739,
#   118482,
#   13170,
#   105511,
#   43549,
#   81822,
#   73308,
#   126995,
#   94657,
#   62193,
#   124616,
#   78496,
#   121134,
#   67927,
#   111253,
#   73484,
#   124616,
#   125221,
#   26124,
#   82076,
#   77934,
#   36206,
#   73498,
#   21677,
#   64052,
#   124391,
#   84795,
#   41307,
#   125994,
#   114402,
#   54508,
#   120910,
#   112397,
#   74188,
#   71914,
#   56040,
#   21530,
#   79669,
#   66040,
#   111343,
#   12214,
#   121877,
#   21981,
#   114402,
#   81746,
#   47071,
#   26124,
#   84027,
#   41975,
#   66067,
#   111253,
#   5152,
#   38184,
#   115739,
#   88859,
#   73308,
#   63519,
#   113664,
#   72291,
#   115739,
#   13503,
#   83262,
#   43129,
#   124166,
#   82946,
#   55401,
#   105388,
#   62079,
#   20231,
#   105511,
#   64640,
#   83262,
#   43129,
#   84741,
#   40315,
#   38767,
#   115739,
#   62080,
#   32133,
#   73308,
#   82541,
#   34064,
#   43129,
#   115739,
#   99411,
#   112397,
#   34380],
#  [56386,
#   115739,
#   61864,
#   122491,
#   22657,
#   13170,
#   73308,
#   101978,
#   34064,
#   112826,
#   108377,
#   115739,
#   21633,
#   73287,
#   109560,
#   90851,
#   37749,
#   82152,
#   112397,
#   26219,
#   45196,
#   22268,
#   67927,
#   122112,
#   37749,
#   23158,
#   122491,
#   64052,
#   26104,
#   40315,
#   31608,
#   61560,
#   21654,
#   115739,
#   80259,
#   115739,
#   40315,
#   115022,
#   92284,
#   91048,
#   20451,
#   115739,
#   88180,
#   52267,
#   84027,
#   128466,
#   122,
#   20099,
#   111738,
#   122607,
#   79716,
#   67927,
#   21633,
#   84027,
#   101112,
#   111253,
#   122925,
#   2694,
#   37749,
#   48987,
#   12008,
#   109971,
#   28459,
#   73498,
#   112397,
#   57420,
#   67927,
#   48987,
#   40617,
#   121313,
#   3188,
#   99934,
#   115918,
#   20408,
#   51871,
#   44640,
#   52718,
#   31835,
#   93992,
#   14309,
#   115739,
#   75201,
#   118688,
#   88712,
#   125591,
#   13500,
#   79964,
#   68754,
#   115739,
#   83260,
#   82541,
#   92396,
#   47760,
#   111751,
#   46385,
#   92396,
#   24841,
#   67927,
#   26124,
#   84027,
#   44869,
#   82932,
#   20099,
#   21677,
#   118334,
#   92396,
#   22322,
#   39719,
#   26745,
#   21677,
#   106311,
#   51439,
#   92396,
#   53881,
#   115739,
#   72866,
#   92396,
#   81246,
#   115415,
#   13418,
#   65898,
#   26124,
#   122816,
#   43737,
#   82076],
#  [39005,
#   939,
#   85595,
#   61801,
#   40075,
#   102246,
#   30489,
#   69449,
#   22585,
#   79659,
#   49703,
#   39005,
#   91814,
#   125653,
#   58894,
#   93178,
#   38888,
#   30489,
#   69449,
#   15991,
#   100159,
#   23098,
#   124452,
#   110393,
#   85595,
#   69449,
#   24229,
#   49703,
#   69396,
#   84799,
#   100159,
#   110393,
#   58894,
#   98313,
#   85595,
#   69449,
#   75730,
#   85595,
#   60287,
#   117949,
#   128423,
#   2095,
#   82854,
#   45099,
#   82355,
#   53881,
#   49703,
#   69449,
#   47921,
#   102730,
#   91814,
#   97408,
#   28425,
#   63537,
#   23098,
#   83913,
#   51286,
#   64910,
#   39005,
#   60449,
#   128423,
#   25663,
#   52458,
#   33025,
#   38590,
#   23098,
#   45603,
#   116886,
#   64910,
#   39005,
#   1659,
#   116186,
#   30489,
#   45603,
#   115744,
#   53564,
#   69449,
#   109666,
#   85595,
#   58937,
#   85595,
#   69449,
#   91086,
#   56386,
#   39332,
#   91814,
#   106789,
#   96615,
#   55775,
#   117454,
#   28109,
#   45099,
#   128423,
#   95519,
#   79637,
#   32286,
#   85595,
#   3853,
#   18468,
#   14035,
#   111961,
#   96804,
#   116545,
#   53564,
#   33060,
#   49703,
#   99138,
#   64348,
#   22677,
#   49703,
#   66354,
#   85595,
#   25663,
#   56386,
#   39005,
#   43922,
#   91239,
#   26525,
#   46691,
#   85595,
#   6536,
#   43416,
#   18468,
#   71248,
#   32734,
#   87992,
#   49703,
#   37221,
#   49703,
#   38559,
#   107682,
#   120916,
#   78146,
#   93110,
#   44640,
#   100529,
#   107682,
#   117949,
#   26525,
#   123455,
#   75301,
#   83913,
#   18032,
#   126654,
#   85595,
#   125641,
#   122621,
#   49703,
#   38559,
#   78146,
#   46020,
#   12593,
#   39005,
#   122532,
#   44640,
#   70889,
#   45099,
#   55775,
#   110495,
#   4526,
#   32734,
#   93067,
#   60801],
#  [40617,
#   124069,
#   10451,
#   81822,
#   124616,
#   56469,
#   92396,
#   8088,
#   112397,
#   11557,
#   26104,
#   112397,
#   83570,
#   56386,
#   31835,
#   112397,
#   31745,
#   115739,
#   124616,
#   92587,
#   42989,
#   21530,
#   49671,
#   60071,
#   84027,
#   73308,
#   74393,
#   69810,
#   73287],
#  [124616,
#   88243,
#   31835,
#   105511,
#   111616,
#   125602,
#   42176,
#   4068,
#   24841,
#   55401,
#   105388,
#   110232,
#   81110,
#   21677,
#   107541,
#   124616,
#   51871,
#   12008,
#   83009,
#   92396,
#   13500,
#   84795,
#   37749,
#   61042,
#   122363,
#   73308,
#   81822,
#   89280,
#   123857,
#   13503,
#   55400,
#   115739,
#   105388,
#   112397,
#   48831,
#   111412],
#  [60141,
#   49703,
#   96804,
#   116545,
#   78146,
#   92746,
#   49123,
#   4188,
#   107117,
#   43438,
#   102730,
#   45099,
#   64910,
#   9612,
#   117454,
#   91814,
#   53204,
#   86542,
#   63201,
#   69449,
#   77928,
#   53564,
#   2595,
#   49703,
#   44268,
#   49108,
#   85595,
#   118218,
#   65673,
#   122842,
#   49703,
#   18032,
#   62184,
#   18032,
#   97045,
#   2631,
#   107682,
#   117400,
#   18032,
#   4746,
#   75522,
#   18032,
#   119194,
#   39005,
#   69766,
#   117596,
#   73444,
#   28425,
#   43416,
#   110092,
#   11651,
#   128423,
#   44510,
#   44640,
#   930,
#   102730,
#   45099,
#   54178,
#   33163,
#   78562,
#   38940,
#   6290,
#   32734,
#   46857,
#   117454,
#   34106,
#   69449,
#   43700],
#  [69449,
#   116759,
#   17091,
#   67151,
#   11845,
#   44794,
#   1112,
#   55885,
#   119853,
#   69449,
#   41686,
#   29829,
#   11666,
#   32734,
#   14807,
#   110701],
#  [86539,
#   65351,
#   92396,
#   114331,
#   101924,
#   31574,
#   33080,
#   48302,
#   111084,
#   73498,
#   69116,
#   14371,
#   99003,
#   72088,
#   1636,
#   7841,
#   86539,
#   58272,
#   94259,
#   51093,
#   7841,
#   76408,
#   86539,
#   33440,
#   98337,
#   37175,
#   24858,
#   7841,
#   86539,
#   37825,
#   13993,
#   20737,
#   123074],
#  [85595,
#   16351,
#   73498,
#   54350,
#   125737,
#   91814,
#   39774,
#   128210,
#   81930,
#   21162,
#   114539,
#   66095,
#   56954,
#   7808,
#   43280,
#   39774,
#   80701,
#   85595,
#   117679,
#   62323,
#   114331,
#   7084,
#   124616,
#   14983,
#   39774,
#   3926,
#   71333,
#   85595,
#   55881,
#   122491,
#   60413,
#   19467,
#   91814,
#   95328,
#   73498,
#   29671,
#   128547,
#   104195,
#   103117,
#   46510,
#   85595,
#   80154,
#   85595,
#   55881,
#   89169,
#   122491,
#   60949,
#   35021,
#   61430,
#   85595,
#   61182,
#   73498,
#   64050,
#   112973,
#   122965,
#   95328,
#   81957,
#   73498,
#   92396,
#   9146,
#   35021,
#   112973,
#   60014,
#   87324,
#   104195,
#   66523,
#   47878,
#   29671,
#   48126,
#   3667,
#   73498,
#   95328,
#   79132,
#   127966,
#   29671,
#   73280,
#   86506,
#   35021,
#   14983,
#   39774,
#   3926,
#   16148,
#   117142,
#   85595,
#   95403,
#   79964,
#   32039,
#   70194,
#   114210,
#   54350,
#   115399,
#   39673,
#   106160,
#   68754,
#   91814,
#   81930,
#   122965,
#   115399,
#   58064,
#   81930,
#   40529,
#   58207,
#   114210,
#   88061,
#   43280,
#   85595,
#   43554,
#   68694,
#   92396,
#   85595,
#   23395,
#   122391,
#   81930,
#   122965,
#   84769,
#   88786,
#   112685,
#   3926,
#   62456,
#   58207,
#   114402,
#   49320,
#   28310,
#   124616,
#   81930,
#   87085,
#   52587],
#  [73308,
#   122491,
#   14655,
#   43449,
#   92396,
#   70194,
#   124616,
#   88243,
#   31835,
#   112397,
#   31849,
#   115739,
#   54969,
#   43365,
#   82541,
#   112397,
#   37071,
#   115739,
#   27149,
#   124616,
#   51871,
#   31835,
#   112397,
#   118688,
#   115739,
#   13500,
#   93075,
#   78496,
#   70194,
#   116679,
#   21677,
#   128091,
#   92177,
#   127929,
#   99638,
#   26767,
#   52267,
#   124616,
#   14655,
#   43449,
#   106352,
#   100265,
#   115739,
#   55391],
#  [811,
#   85595,
#   70539,
#   17668,
#   32734,
#   72794,
#   58894,
#   5446,
#   126289,
#   45726,
#   30489,
#   69449,
#   64653,
#   49703,
#   28702,
#   77373,
#   84799,
#   100159,
#   46062,
#   23098,
#   42649,
#   121872,
#   59399,
#   69449,
#   29525,
#   5090,
#   126289,
#   7309,
#   49703,
#   53564,
#   97038,
#   52446,
#   38033,
#   119194,
#   75214,
#   69766,
#   3051,
#   85595,
#   97979,
#   30489,
#   69449,
#   17612,
#   28109,
#   119194,
#   11764,
#   64910,
#   51286,
#   86542,
#   84773,
#   23098,
#   70194,
#   69449,
#   14667,
#   85595,
#   114331,
#   39332,
#   34068,
#   49703,
#   82492,
#   39005,
#   51717],
#  [12281,
#   79408,
#   26525,
#   58894,
#   80172,
#   76125,
#   120226,
#   65943,
#   13497,
#   44640,
#   57500,
#   4796,
#   26525,
#   41956,
#   105050,
#   23098,
#   43700,
#   97430,
#   117472,
#   123455,
#   85595,
#   70194,
#   39885,
#   104989,
#   111721,
#   119194,
#   16101,
#   73070,
#   41335,
#   11084,
#   85595,
#   77796,
#   44640,
#   6775,
#   45099,
#   22608,
#   128423,
#   117454,
#   85595,
#   91146,
#   128259,
#   78792,
#   60607,
#   107117,
#   95479,
#   94817,
#   110393,
#   93178,
#   94817,
#   74268,
#   87328,
#   67642,
#   38590,
#   67011,
#   115886,
#   45099,
#   23057,
#   64173,
#   85721,
#   128423,
#   58741,
#   18468,
#   91814,
#   7398,
#   33025,
#   81463,
#   34937,
#   110393,
#   10246,
#   111096,
#   44185,
#   49703,
#   28425,
#   99506,
#   80619,
#   61687,
#   22789,
#   25009,
#   108816,
#   75301,
#   53926,
#   87777,
#   27545,
#   44640,
#   33759,
#   91814,
#   127412,
#   80506,
#   49703,
#   83423,
#   58711,
#   64240,
#   91814,
#   37290,
#   10384,
#   91254,
#   97038,
#   28109,
#   4526,
#   114002,
#   22720,
#   85595,
#   115490,
#   86444,
#   117031,
#   42393,
#   85595,
#   117517,
#   22707,
#   110393,
#   85595,
#   97979,
#   45099,
#   69449,
#   17612,
#   49703,
#   110393,
#   22850,
#   27104,
#   65839,
#   22850,
#   127682,
#   91699,
#   13595,
#   35769,
#   87777,
#   44640,
#   54374,
#   43700,
#   85595,
#   50904,
#   51147,
#   83421,
#   114657,
#   16101,
#   94357,
#   53564,
#   16101,
#   98294,
#   117472,
#   63467,
#   18632,
#   85595,
#   102730,
#   55775,
#   116767,
#   91814,
#   47921,
#   62089,
#   69766,
#   18345],
#  [61775, 98337, 912, 87266, 104557, 86539, 81642, 31574, 115976, 6444, 6290],
#  [69766,
#   23796,
#   104557,
#   33789,
#   14713,
#   22003,
#   98337,
#   82088,
#   104557,
#   52543,
#   102919,
#   46769,
#   107380,
#   100960,
#   30084,
#   34496,
#   95095,
#   100960,
#   1447,
#   78233,
#   84919,
#   98337,
#   89006,
#   51996,
#   104557,
#   107985,
#   46252,
#   24613,
#   103090,
#   86653,
#   98478,
#   86539,
#   24867,
#   21461,
#   46918,
#   548,
#   24037,
#   33080,
#   52449,
#   98337,
#   121303,
#   91808,
#   19523,
#   50706,
#   106746,
#   73066,
#   94259,
#   100960,
#   87958,
#   58864,
#   86539,
#   76583,
#   92396,
#   69766,
#   97091,
#   104557,
#   96255,
#   86539,
#   52088,
#   20349,
#   86653,
#   46930,
#   98927,
#   125941,
#   18390,
#   53857,
#   69766,
#   14655,
#   57169,
#   111084,
#   94259,
#   21461,
#   102138,
#   39774,
#   95702,
#   109133,
#   69766,
#   89006,
#   37290,
#   57169,
#   115705,
#   114210,
#   46484,
#   90191,
#   61793,
#   19564,
#   94259,
#   14371,
#   95657,
#   7841,
#   97933,
#   86539,
#   49970,
#   31906,
#   121303,
#   103615,
#   39774,
#   95702,
#   92020,
#   86539,
#   41713,
#   84075,
#   58864,
#   35475,
#   65351,
#   51238,
#   46252,
#   24613,
#   103090,
#   60933,
#   120852,
#   109329,
#   86539,
#   75066,
#   4502,
#   14792,
#   100960,
#   98647,
#   30280,
#   76408,
#   548,
#   98647,
#   114210,
#   52543,
#   102919,
#   61515,
#   100960,
#   92396,
#   114528,
#   97091,
#   101304,
#   68732,
#   35475,
#   114210,
#   92020,
#   69766,
#   99700,
#   70144,
#   65351,
#   78704,
#   35475,
#   25879,
#   14792,
#   100960,
#   7084,
#   69766,
#   48302,
#   40454],
#  [29525,
#   97038,
#   49703,
#   94998,
#   45099,
#   32734,
#   20899,
#   117454,
#   23098,
#   70194,
#   64872,
#   69396,
#   84799,
#   23098,
#   114583,
#   34918,
#   23098,
#   2836,
#   58894,
#   93067,
#   36267,
#   69449,
#   98294,
#   53564,
#   4526,
#   128423,
#   25663,
#   116479,
#   85595,
#   61568,
#   80093,
#   28109,
#   117400,
#   18032,
#   108047,
#   70194,
#   49703,
#   168,
#   51453,
#   69449,
#   98294,
#   95479,
#   110393,
#   85595,
#   25462,
#   41454,
#   52446,
#   44305,
#   22927,
#   77894,
#   128423,
#   1028,
#   53564,
#   23807,
#   28109,
#   87528,
#   5241,
#   69449,
#   79368,
#   53564,
#   58894,
#   46411,
#   28109,
#   109666,
#   21415,
#   51003,
#   45099,
#   81687,
#   119194,
#   126540,
#   18032,
#   27658,
#   85595,
#   57109,
#   28425,
#   34315,
#   85595,
#   35031,
#   28702,
#   23098,
#   101125,
#   28425,
#   58780,
#   117454,
#   49703,
#   96525,
#   70144,
#   64910,
#   18032,
#   47316,
#   84588,
#   100260,
#   38940,
#   128423,
#   58741,
#   75783,
#   110393,
#   108099,
#   69449,
#   6750,
#   95479,
#   11140,
#   110393,
#   49703,
#   33060,
#   82978,
#   114002,
#   50097,
#   53564,
#   58894,
#   114030,
#   18032,
#   29695,
#   53899,
#   69396,
#   84799,
#   44640,
#   68754,
#   85595,
#   126737,
#   49703,
#   108869,
#   113733,
#   49703,
#   78317,
#   87383,
#   95479,
#   11266,
#   32734,
#   102601,
#   45099,
#   77796,
#   23098,
#   111903,
#   45275,
#   128471,
#   93318,
#   77894,
#   121641,
#   32734,
#   76238,
#   67528,
#   117400,
#   87932,
#   124885,
#   23227,
#   58036,
#   67553,
#   28702,
#   67553,
#   92463,
#   115666,
#   28212,
#   69766,
#   55393,
#   124885,
#   34918,
#   45076,
#   11266,
#   110080,
#   82344,
#   80105,
#   121641,
#   117400,
#   5241,
#   69766,
#   51049,
#   70194,
#   75214,
#   14812,
#   51108,
#   14371,
#   26124,
#   98355,
#   38440,
#   44678,
#   121938,
#   26124,
#   79417,
#   44678,
#   6404,
#   85595,
#   69449,
#   50097,
#   14371,
#   22487,
#   26124,
#   110080,
#   50097,
#   76935,
#   99529,
#   125401,
#   13869,
#   27031,
#   111226,
#   10782,
#   64910,
#   26124,
#   44026,
#   83328,
#   95776,
#   128423,
#   99857,
#   64910,
#   30108,
#   110080,
#   96525,
#   85595,
#   30114,
#   64910,
#   14371,
#   67553,
#   77721,
#   91814,
#   44678,
#   35201,
#   93992,
#   14371,
#   26124,
#   86345,
#   121292,
#   121641,
#   121643,
#   64910,
#   66553,
#   52342,
#   69766,
#   32003,
#   96757,
#   58780,
#   85595,
#   125389,
#   75214,
#   96757,
#   58780,
#   85595,
#   70144,
#   68288,
#   99902],
#  [39774,
#   21095,
#   69766,
#   6444,
#   28711,
#   88702,
#   113586,
#   86539,
#   6290,
#   114210,
#   33080,
#   5942,
#   102919,
#   86539,
#   59191,
#   98337,
#   86539,
#   60287,
#   102772,
#   115705,
#   127896,
#   33080,
#   7176,
#   39774,
#   57898,
#   102919,
#   91166,
#   66425,
#   123202,
#   103111,
#   98337,
#   113586,
#   113943,
#   57278,
#   123074,
#   87131,
#   56366,
#   8101,
#   86653,
#   86539,
#   5209,
#   109263,
#   92020,
#   52452,
#   24173,
#   11061,
#   100960,
#   113586,
#   86653,
#   78838,
#   67246],
#  [86539,
#   111084,
#   114210,
#   33080,
#   47660,
#   86342,
#   24315,
#   98337,
#   50245,
#   7841,
#   69683,
#   1241,
#   33230,
#   58864,
#   123202,
#   69116,
#   66136,
#   7841,
#   97769,
#   33080,
#   127243,
#   58864,
#   58724,
#   35168,
#   69766,
#   16471,
#   13144,
#   77856,
#   98337,
#   69766,
#   77856,
#   110939,
#   44280,
#   112204,
#   72509,
#   12320,
#   7841,
#   97769,
#   82467,
#   61675,
#   20857,
#   114210,
#   29620,
#   102370,
#   38931,
#   86539,
#   44727,
#   117500,
#   34496,
#   70144,
#   24315,
#   112336,
#   128476],
#  [124616,
#   56319,
#   67927,
#   60497,
#   65898,
#   10228,
#   122965,
#   57420,
#   94976,
#   14309,
#   19467,
#   115739,
#   35663,
#   112397,
#   118688,
#   84027,
#   112397,
#   116646,
#   67375,
#   88678,
#   112250,
#   14655,
#   68055,
#   76160,
#   124616,
#   76432,
#   32133,
#   78496,
#   80013,
#   31835,
#   112397,
#   18239,
#   11559,
#   49592,
#   115739,
#   51855,
#   81822,
#   105388,
#   112397,
#   9800,
#   21017,
#   54826,
#   69810,
#   73287,
#   122112,
#   80013,
#   92396,
#   71989,
#   56319,
#   99411,
#   17627],
#  [73308,
#   84181,
#   90012,
#   98251,
#   82354,
#   48987,
#   115739,
#   101978,
#   112397,
#   37071,
#   112421,
#   25521,
#   31835,
#   65898,
#   53080,
#   86837,
#   20295,
#   105388,
#   90012,
#   84027,
#   28629,
#   81626,
#   25521,
#   109035,
#   69630,
#   106484,
#   63000,
#   92598,
#   78496,
#   62259,
#   113428,
#   119398,
#   107791,
#   105388,
#   5388,
#   116114,
#   114001,
#   112250,
#   98251,
#   105388,
#   20099,
#   65685,
#   52267,
#   111084,
#   14371,
#   118622,
#   92177,
#   126869],
#  [113167,
#   28711,
#   88702,
#   113428,
#   98585,
#   73498,
#   16471,
#   6444,
#   79613,
#   98337,
#   12502,
#   95702,
#   35318,
#   113348,
#   89742,
#   114210,
#   75304,
#   69766,
#   61775,
#   8039,
#   50229,
#   2610,
#   69766,
#   121872,
#   111396,
#   84794,
#   7841,
#   86539,
#   75179,
#   17627,
#   25725,
#   111084,
#   114210,
#   88050,
#   51238,
#   28433,
#   98337,
#   67922,
#   113167,
#   14300,
#   47660,
#   86539,
#   3837,
#   127896,
#   92020,
#   33080,
#   11564,
#   118661,
#   72509,
#   18390,
#   106746,
#   14713,
#   46713,
#   22395,
#   92396,
#   86539,
#   111084,
#   88702,
#   109263,
#   69290,
#   25408,
#   73498,
#   112907,
#   94259,
#   53101,
#   38969,
#   17627],
#  [113586,
#   39332,
#   58894,
#   60559,
#   34677,
#   69766,
#   25789,
#   64910,
#   39005,
#   51222,
#   85595,
#   38827,
#   5365,
#   10147,
#   39332,
#   14641,
#   49703,
#   34677,
#   69766,
#   46020,
#   126315,
#   32734,
#   1239,
#   45099,
#   39005,
#   102275,
#   128423,
#   17817,
#   85595,
#   69449,
#   29525,
#   47759,
#   29525,
#   39332,
#   23455,
#   38888,
#   107682,
#   73444,
#   38940,
#   73708,
#   30489,
#   26525,
#   33757,
#   28369,
#   85595,
#   69449,
#   105041,
#   100159,
#   23098,
#   49819,
#   85595,
#   121872,
#   59399,
#   23098,
#   2836,
#   69396,
#   117987,
#   27365,
#   85595,
#   15538,
#   49703,
#   49819,
#   85595,
#   84885,
#   59399,
#   85595,
#   69449,
#   75730,
#   123938,
#   51286,
#   107117,
#   39332,
#   58894,
#   94998,
#   45099,
#   63451,
#   45603,
#   10941,
#   85595,
#   25663,
#   113586,
#   69766,
#   126315,
#   69449,
#   114583,
#   85595,
#   39005,
#   84361,
#   69396,
#   14188,
#   85595,
#   91373,
#   49703,
#   44640,
#   124300,
#   24522,
#   23098,
#   92746,
#   83083,
#   126289,
#   62778,
#   49703,
#   126289,
#   127816,
#   69396,
#   117454,
#   26525,
#   76125,
#   58894,
#   60559,
#   20001,
#   37704,
#   51286,
#   122806],
#  [51855,
#   63519,
#   21025,
#   47773,
#   112397,
#   9800,
#   115739,
#   68946,
#   50620,
#   69810,
#   73287,
#   74393,
#   38347,
#   21530,
#   27347,
#   31374,
#   105511,
#   43549,
#   115739,
#   128279,
#   72866,
#   21530,
#   43919,
#   31374,
#   21677,
#   1671,
#   50555,
#   112397,
#   45586,
#   115739,
#   13500,
#   25521,
#   31835,
#   112397,
#   79716,
#   65898,
#   105511,
#   20099,
#   84789,
#   51855,
#   105320,
#   13500,
#   121623,
#   26808,
#   115739,
#   20099,
#   118229,
#   105511,
#   124616,
#   24580,
#   66916,
#   110517,
#   72509,
#   85749],
#  [124616,
#   88243,
#   54106,
#   92396,
#   37749,
#   71792,
#   29852,
#   14309,
#   69630,
#   118688,
#   122816,
#   31835,
#   72866,
#   24662,
#   78496,
#   56941,
#   51401,
#   37749,
#   71792,
#   76160,
#   114789,
#   37749,
#   12912,
#   124616,
#   106910,
#   55401,
#   64052,
#   9343,
#   109775,
#   3617,
#   94661,
#   339,
#   55401,
#   55436,
#   21530,
#   42251,
#   10076,
#   112397,
#   19923,
#   100229,
#   83278,
#   20099,
#   68787,
#   68433,
#   86184,
#   51855,
#   52082,
#   13500,
#   25521,
#   28070,
#   3656,
#   115739,
#   108690,
#   120175,
#   52267,
#   84027,
#   113705,
#   43449,
#   52016,
#   119935,
#   21677,
#   23506,
#   106190,
#   92059,
#   110608,
#   31835,
#   52267,
#   12008,
#   55786,
#   82932,
#   115739,
#   21530,
#   79291,
#   81704,
#   51855,
#   122816,
#   72866,
#   72509,
#   109775,
#   78224],
#  [73308,
#   81822,
#   113705,
#   89113,
#   92396,
#   60751,
#   88243,
#   47349,
#   34064,
#   60287,
#   1465,
#   112397,
#   109775,
#   92177,
#   99638,
#   13500,
#   31425,
#   55401,
#   105388,
#   20099,
#   73869,
#   112397,
#   109775,
#   83650,
#   124616,
#   88243,
#   54106,
#   125146,
#   92396,
#   37749,
#   116474,
#   71792,
#   69630,
#   92396,
#   81246,
#   108437,
#   66916,
#   73308,
#   101978,
#   112397,
#   37071,
#   115418,
#   78496,
#   60751,
#   94661,
#   73308,
#   21017,
#   73287,
#   74393],
#  [73308,
#   81822,
#   124616,
#   88243,
#   105511,
#   8094,
#   37749,
#   50198,
#   44862,
#   106455,
#   115739,
#   101978,
#   21633,
#   72866,
#   7059,
#   36206,
#   73498,
#   57262,
#   61802,
#   20295,
#   20295,
#   21633,
#   60497,
#   72509,
#   84633,
#   124616,
#   51871,
#   31835,
#   97228,
#   87550,
#   122112,
#   6421,
#   23158,
#   55401,
#   105388,
#   37749,
#   88899,
#   36206,
#   103884,
#   15538,
#   25131,
#   115739,
#   21633,
#   112397,
#   66040,
#   38874,
#   109035,
#   49163,
#   103608,
#   25899,
#   35528,
#   815,
#   114326,
#   75200,
#   29671,
#   105388,
#   21633,
#   20099,
#   73869,
#   92177,
#   22322,
#   8807,
#   104657,
#   54809,
#   37749,
#   26140,
#   56740,
#   62906,
#   76160,
#   31835,
#   117012,
#   41401,
#   34757,
#   50555,
#   73525,
#   90191,
#   126972,
#   1799,
#   127929,
#   76160,
#   100487,
#   124616,
#   3620,
#   80258,
#   115739,
#   30202,
#   36206,
#   98614,
#   92177,
#   99638,
#   21677,
#   31835,
#   72509,
#   60627,
#   125146,
#   64052,
#   33243,
#   21981,
#   24447,
#   84027,
#   99417,
#   34266,
#   52659,
#   25474,
#   69630,
#   73308,
#   82541,
#   111616,
#   27061,
#   38664,
#   63513,
#   102586,
#   105388,
#   13500,
#   64052,
#   42285,
#   72866,
#   99999,
#   100819,
#   15538,
#   37840,
#   13500,
#   113586,
#   98585],
#  [73308,
#   42835,
#   84027,
#   88390,
#   792,
#   43449,
#   92396,
#   15538,
#   73308,
#   101978,
#   19923,
#   100229,
#   124616,
#   51871,
#   31835,
#   87550,
#   26140,
#   13500,
#   26104,
#   31835,
#   81177,
#   60910,
#   73498,
#   20099,
#   84027,
#   25899,
#   9029,
#   63344,
#   62753,
#   24447],
#  [44957,
#   69787,
#   95328,
#   93169,
#   35710,
#   95328,
#   26172,
#   92396,
#   85595,
#   25214,
#   62323,
#   95328,
#   125341,
#   91814,
#   30717,
#   15538,
#   31057,
#   95328,
#   26172,
#   73498,
#   19866,
#   83665,
#   34437,
#   73888,
#   102443,
#   44957,
#   46842,
#   95328,
#   41053,
#   35710,
#   113586,
#   29671,
#   64,
#   20001,
#   73498,
#   114402,
#   20001,
#   113087,
#   7841,
#   89795,
#   10033,
#   105297],
#  [86539,
#   89742,
#   7841,
#   113586,
#   114210,
#   92120,
#   18390,
#   114210,
#   92396,
#   86539,
#   61948,
#   7841,
#   67551,
#   84363,
#   114210,
#   88113,
#   58864,
#   14232,
#   101304,
#   68754,
#   98337,
#   37226,
#   94259,
#   18390,
#   114210,
#   46252,
#   69766,
#   33080,
#   61775,
#   12814,
#   72509,
#   24173,
#   114210,
#   14371,
#   50229,
#   67042,
#   88702,
#   76408,
#   86539,
#   31188,
#   95702,
#   33080,
#   30820,
#   98337,
#   21569,
#   33080,
#   9557,
#   102919,
#   32628,
#   91808,
#   5790,
#   84089,
#   27500,
#   20935],
#  [36267,
#   74251,
#   23098,
#   83293,
#   69396,
#   78004,
#   30489,
#   26525,
#   33757,
#   45726,
#   49703,
#   53160,
#   29525,
#   87777,
#   31947,
#   49703,
#   82978,
#   114002,
#   79368,
#   52446,
#   66272,
#   98293,
#   10807,
#   45099,
#   77796,
#   118922,
#   168,
#   105364,
#   128423,
#   68986,
#   53564,
#   91814,
#   8356,
#   122177,
#   33025,
#   128423,
#   115822,
#   107117,
#   69766,
#   26525,
#   67358,
#   49568,
#   124461,
#   45099,
#   95479,
#   110393,
#   107936,
#   37810,
#   46252,
#   108606,
#   110393,
#   26981,
#   47554,
#   21876,
#   85595,
#   50996,
#   59830,
#   117949,
#   28249,
#   45099,
#   32734,
#   117454,
#   85595,
#   98083,
#   34937,
#   64872,
#   85595,
#   69449,
#   75730,
#   46145,
#   49703,
#   44640,
#   83100,
#   85595,
#   85595,
#   89742,
#   85595,
#   93812],
#  [39005,
#   60449,
#   116768,
#   27533,
#   44801,
#   30489,
#   128423,
#   122806,
#   85595,
#   113586,
#   76583,
#   65223,
#   63186,
#   39005,
#   69766,
#   50103,
#   87777,
#   26525,
#   46691,
#   58894,
#   74185,
#   44640,
#   6536,
#   43416,
#   69396,
#   99545,
#   12281,
#   39005,
#   69766,
#   88640,
#   122806,
#   53564,
#   65099,
#   94158,
#   126289,
#   84799,
#   59971,
#   85595,
#   69449,
#   111977,
#   79439,
#   85595,
#   102730,
#   77796,
#   69766,
#   2836,
#   38940,
#   69449,
#   100159,
#   49703,
#   117400,
#   18032,
#   47316,
#   32734,
#   32641,
#   117949,
#   65099,
#   94158,
#   45099,
#   63451,
#   82978,
#   69449,
#   53204,
#   85595,
#   97897,
#   91699,
#   66272,
#   78359,
#   121125,
#   23098,
#   92746,
#   110393,
#   110393,
#   58894,
#   120895],
#  [50385, 39430, 32734, 105657, 96928, 69480, 61355, 15572],
#  [13500,
#   25521,
#   31835,
#   51439,
#   79716,
#   112397,
#   14309,
#   31849,
#   71832,
#   115739,
#   118688,
#   53840,
#   111396,
#   78496,
#   101130,
#   76160,
#   73308,
#   101978,
#   69810,
#   87140,
#   115739,
#   21017,
#   119935,
#   73287,
#   125206],
#  [14713,
#   84321,
#   51238,
#   86539,
#   6559,
#   14365,
#   114210,
#   66781,
#   91808,
#   121318,
#   92801,
#   102919,
#   14311,
#   1636,
#   7841,
#   52420,
#   98337,
#   86539,
#   88896,
#   114031,
#   87337,
#   98337,
#   114031,
#   32694,
#   87131,
#   113167,
#   8101,
#   33080,
#   112049,
#   102919,
#   50192,
#   24120,
#   92020,
#   6027,
#   32388,
#   92396,
#   34753,
#   66781,
#   52420,
#   39587,
#   86653,
#   53510],
#  [57120,
#   115739,
#   116218,
#   62850,
#   122491,
#   47347,
#   69352,
#   73308,
#   42835,
#   84027,
#   88390,
#   103842,
#   43449,
#   92396,
#   22322,
#   110015,
#   3141,
#   29666,
#   19467,
#   92396,
#   125146,
#   78496,
#   30279,
#   115739,
#   111253,
#   14950,
#   68606,
#   90899,
#   124616,
#   105511,
#   8088,
#   47191,
#   32268,
#   40138,
#   73308,
#   42835,
#   108255,
#   33132,
#   122491,
#   69630,
#   92396,
#   37749,
#   110603,
#   119935,
#   124616,
#   21981,
#   67927,
#   121313,
#   11825,
#   52659,
#   15429,
#   109175,
#   31835,
#   37856,
#   112397,
#   124306,
#   119935,
#   124616,
#   105742,
#   84027,
#   107197,
#   76160,
#   82541,
#   84027,
#   41401,
#   31835,
#   92177,
#   127929,
#   92177,
#   99638,
#   52267,
#   124616,
#   9029,
#   31835,
#   73287,
#   84027,
#   109175,
#   80533,
#   17627,
#   109606,
#   116679,
#   124616,
#   22814,
#   122996,
#   105511,
#   111616,
#   125602,
#   36380,
#   73308,
#   74393,
#   69810,
#   73287],
#  [57120,
#   55401,
#   105388,
#   78496,
#   37749,
#   121669,
#   108377,
#   105388,
#   37071,
#   100229,
#   115739,
#   98614,
#   36206,
#   68700,
#   99039,
#   98251,
#   13500,
#   39719,
#   1162,
#   81928,
#   87631,
#   115739,
#   66581,
#   42835,
#   73308,
#   95090,
#   67927,
#   29671,
#   111855,
#   81858,
#   115739,
#   31745,
#   124616,
#   109381,
#   31835,
#   94976,
#   69630,
#   120057,
#   38591,
#   29666,
#   67927,
#   31849,
#   69630,
#   112397,
#   11825,
#   52659,
#   73308,
#   81822,
#   114063,
#   108007,
#   92396,
#   88204,
#   46296,
#   83570,
#   115739,
#   74393,
#   69810,
#   73287],
#  [105388,
#   117887,
#   13500,
#   22814,
#   128202,
#   4068,
#   24841,
#   107541,
#   116218,
#   51871,
#   111253,
#   18027,
#   105511,
#   13500,
#   79964,
#   115739,
#   13500,
#   115583,
#   88204,
#   46296,
#   73308,
#   81822,
#   13500,
#   83262,
#   97456,
#   128466,
#   105511,
#   93161,
#   64937,
#   112397,
#   83570,
#   105123,
#   81822,
#   73308,
#   21633,
#   69810,
#   124616,
#   121872,
#   126972,
#   127190,
#   21530,
#   41401,
#   92396,
#   104892,
#   30782,
#   124616,
#   25521,
#   48987,
#   50555,
#   82541,
#   118505,
#   11825,
#   91437,
#   69630,
#   97228,
#   65587,
#   52659,
#   115739,
#   114326,
#   11806,
#   29220,
#   17627,
#   117012,
#   52357,
#   103294,
#   44640,
#   22814,
#   128202,
#   82541,
#   57120,
#   115739,
#   116218,
#   62850,
#   33821,
#   122816,
#   81822,
#   105388,
#   78496,
#   60398,
#   48987,
#   112397,
#   37071,
#   112421,
#   115739,
#   115275,
#   46632,
#   34728,
#   90616,
#   115739,
#   125451,
#   122491,
#   22388,
#   8013,
#   115739,
#   107541,
#   46462,
#   54430,
#   92177,
#   6163,
#   73308,
#   42835,
#   124616,
#   76432,
#   56469,
#   103884,
#   94999,
#   13500,
#   21813,
#   122112,
#   83532,
#   42969,
#   65166,
#   92396,
#   22322,
#   39719,
#   92177,
#   25474,
#   17627,
#   51340,
#   82541,
#   21633,
#   124616,
#   121443,
#   92177,
#   124847,
#   48987,
#   59001,
#   33821,
#   52267,
#   124616,
#   35859,
#   124378,
#   49973,
#   99477,
#   3970,
#   73308,
#   45713,
#   26140,
#   64883,
#   36380,
#   107791,
#   30051,
#   92177,
#   80620,
#   40325,
#   105513,
#   38664,
#   97658,
#   50555,
#   21633,
#   124616,
#   30051,
#   88026,
#   92177,
#   9029,
#   41979,
#   92177,
#   61982,
#   17627,
#   113457,
#   88717,
#   115739,
#   71623,
#   82076,
#   26124,
#   64052,
#   64806,
#   128202,
#   74652,
#   72866,
#   115739,
#   65127,
#   22523,
#   21633,
#   124616,
#   24407,
#   92599,
#   62753,
#   73308,
#   82541,
#   20099,
#   84027,
#   25899,
#   9029,
#   27061,
#   21530,
#   97685,
#   116114,
#   88204,
#   46296,
#   60451,
#   73498,
#   92396,
#   11906,
#   127412,
#   59399,
#   92177,
#   48454,
#   31835,
#   76589,
#   45133,
#   20099,
#   13776,
#   99039,
#   98251,
#   124616,
#   14382,
#   108007,
#   64052,
#   39719,
#   1322,
#   52267,
#   20099,
#   31835,
#   13500,
#   88376,
#   124616,
#   77956,
#   18632,
#   17627,
#   46385,
#   92396,
#   24841,
#   20809,
#   13500,
#   22814,
#   128202,
#   107541,
#   124616,
#   78913,
#   78496,
#   57120,
#   115739,
#   33821,
#   124616,
#   73298,
#   46462,
#   14070,
#   73287,
#   58742,
#   92134,
#   60893,
#   104123,
#   72866,
#   55006,
#   84885,
#   49973,
#   25755,
#   108105,
#   81822,
#   68677,
#   17627,
#   17627,
#   17627,
#   17627],
#  [58894,
#   93067,
#   80083,
#   39005,
#   60449,
#   117733,
#   100219,
#   89274,
#   77274,
#   56752,
#   33025,
#   81463,
#   85595,
#   57120,
#   103405,
#   32734,
#   123766,
#   23098,
#   50229,
#   32142,
#   87295,
#   15999,
#   45099,
#   15713,
#   128423,
#   98079,
#   38940,
#   69449,
#   75659,
#   102730,
#   85595,
#   46020,
#   24774,
#   42772,
#   69396,
#   122806,
#   53899,
#   85595,
#   69449,
#   20024,
#   46062,
#   23098,
#   42649,
#   91814,
#   45248,
#   32101,
#   28109,
#   109121,
#   97702,
#   64872,
#   54993,
#   49703,
#   85595,
#   69449,
#   75659,
#   119974,
#   96299,
#   1659,
#   84296,
#   26525,
#   93812,
#   32734,
#   105244,
#   85595,
#   60287,
#   53564,
#   64872,
#   105062,
#   28109,
#   69449,
#   32066,
#   73070,
#   118819,
#   83964,
#   58894,
#   77894,
#   97038,
#   58529,
#   77274,
#   46230,
#   35225,
#   98294,
#   114002,
#   10868,
#   119839,
#   75214,
#   69766,
#   85595,
#   106114,
#   77796,
#   69449,
#   91086,
#   28109,
#   117949,
#   128423,
#   48355,
#   90935,
#   2551,
#   120412,
#   58894,
#   28702,
#   23098,
#   27579,
#   92011,
#   38033,
#   124452,
#   89515,
#   32734,
#   3051,
#   16065,
#   69396,
#   62184,
#   85595,
#   69449,
#   37505,
#   85595,
#   18813,
#   29467,
#   21071,
#   85595,
#   19639,
#   9509,
#   46296],
#  [57120,
#   115739,
#   116218,
#   62850,
#   81822,
#   105388,
#   112397,
#   19923,
#   115418,
#   108465,
#   73308,
#   95090,
#   25899,
#   45242,
#   84027,
#   93606,
#   42835,
#   20295,
#   50555,
#   98614,
#   19572,
#   17627],
#  [102730,
#   23098,
#   116768,
#   63201,
#   69396,
#   62778,
#   23098,
#   69449,
#   74544,
#   38404,
#   112089,
#   32734,
#   4412,
#   37704,
#   91192],
#  [40646,
#   117454,
#   102730,
#   75214,
#   53564,
#   128423,
#   2095,
#   53564,
#   64743,
#   45726,
#   49703,
#   28369,
#   23098,
#   54954,
#   85595,
#   63186],
#  [32734,
#   101023,
#   85595,
#   56541,
#   127523,
#   49703,
#   95002,
#   87777,
#   45099,
#   99940,
#   32734,
#   93060,
#   69134,
#   107630,
#   99769,
#   87777,
#   38948,
#   38940,
#   69449,
#   98294,
#   49703,
#   69449,
#   28132,
#   58894,
#   74158,
#   98294,
#   58894,
#   97038,
#   49703,
#   49568,
#   74256,
#   46252,
#   69766,
#   69449,
#   6290,
#   85595,
#   18269,
#   122874,
#   44640,
#   40089,
#   49703,
#   44640,
#   74465,
#   49703,
#   26525,
#   58894,
#   74158,
#   38948,
#   38940,
#   69449,
#   121959,
#   44640,
#   56541,
#   102730,
#   23098,
#   62184,
#   77894,
#   8309,
#   85595,
#   52446,
#   13595,
#   49703,
#   85595,
#   50759,
#   38940,
#   6290,
#   38940,
#   26525,
#   74158,
#   50047,
#   59347,
#   87777,
#   38948,
#   38940,
#   28425,
#   7666,
#   7452,
#   49703,
#   117949,
#   126669,
#   80083,
#   58894,
#   60559],
#  [73308,
#   42835,
#   52267,
#   4648,
#   43449,
#   40315,
#   103842,
#   88243,
#   52659,
#   111253,
#   24841,
#   73498,
#   21677,
#   40387,
#   34053,
#   48062,
#   111253,
#   37749,
#   62117,
#   115964,
#   105511,
#   84027,
#   88678,
#   128466,
#   115739,
#   112397,
#   44595,
#   49973,
#   21981,
#   45196,
#   27061,
#   92177,
#   112397,
#   124946,
#   98746,
#   124616,
#   51871,
#   13500,
#   79964,
#   37749,
#   81642,
#   115739,
#   37749,
#   103842,
#   18027,
#   34064,
#   64937,
#   103884,
#   124616,
#   77300,
#   122491,
#   52267,
#   105388,
#   87550],
#  [73308,
#   122491,
#   88681,
#   78382,
#   92396,
#   37749,
#   47347,
#   7442,
#   88243,
#   78496,
#   57120,
#   124616,
#   109381,
#   31835,
#   112397,
#   114095,
#   115739,
#   42989,
#   21530,
#   61003,
#   84027,
#   117012,
#   81642,
#   67927,
#   104170,
#   112397,
#   114095,
#   11017,
#   83046,
#   57063,
#   92396,
#   37749,
#   109381,
#   42835,
#   73308,
#   20099,
#   81642,
#   49248,
#   52267,
#   105388,
#   14094,
#   86184,
#   52267,
#   105388,
#   113664,
#   55424,
#   53945,
#   97127,
#   21017,
#   107791,
#   88243,
#   36525,
#   73287,
#   70157],
#  [57120,
#   115739,
#   30795,
#   82541,
#   115743,
#   13170,
#   115739,
#   81822,
#   113664,
#   123857,
#   13503,
#   52267,
#   40552,
#   115739,
#   68754,
#   20408,
#   51871,
#   31835,
#   43312,
#   102757,
#   73308,
#   81822,
#   111616,
#   27061,
#   20099,
#   123902,
#   78496,
#   6421,
#   50047,
#   83570,
#   115739,
#   37749,
#   118229,
#   105511,
#   124616,
#   77300,
#   31835,
#   19810],
#  [126475,
#   88243,
#   111253,
#   47385,
#   118229,
#   44973,
#   79964,
#   112397,
#   11042,
#   13170,
#   124616,
#   98251,
#   13500,
#   48831,
#   16031,
#   35859,
#   52864,
#   34903,
#   82541,
#   46385,
#   112397,
#   31849,
#   115739,
#   114095,
#   57120,
#   115739,
#   30795,
#   48365,
#   105511,
#   51588,
#   92396,
#   16031,
#   34831,
#   111253,
#   105513,
#   38664,
#   37749,
#   73869,
#   21530,
#   41401,
#   115739,
#   20099,
#   23611,
#   57979,
#   31835,
#   109775,
#   92177,
#   127929,
#   92177,
#   42254,
#   73287],
#  [29525,
#   77894,
#   87777,
#   32734,
#   35018,
#   32734,
#   66272,
#   49703,
#   26525,
#   35225,
#   38948,
#   38940,
#   69449,
#   77271,
#   107682,
#   59759,
#   38940,
#   28425,
#   46230,
#   64173,
#   53564,
#   4526,
#   28702,
#   94158,
#   58894,
#   64872,
#   85595,
#   69449,
#   20024,
#   49703,
#   23098,
#   121872,
#   45076,
#   69396,
#   84799,
#   100159,
#   6885,
#   53564,
#   73758,
#   58894,
#   70593,
#   67527,
#   52446,
#   38033,
#   69449,
#   114002,
#   22720,
#   85595,
#   115490,
#   49703,
#   69449,
#   17612,
#   110393,
#   37633],
#  [37749,
#   18027,
#   34064,
#   64937,
#   31835,
#   47773,
#   37749,
#   79941,
#   34053,
#   85198,
#   63579,
#   67178,
#   40315,
#   31608,
#   80259,
#   115739,
#   40315,
#   31608,
#   2846,
#   87550,
#   98251,
#   124616,
#   792,
#   40833,
#   92177,
#   34889,
#   115739,
#   105724,
#   36206,
#   31835,
#   31849,
#   115739,
#   37749,
#   86448,
#   112397,
#   79716,
#   73308,
#   81822,
#   105388,
#   86930,
#   111412,
#   40617,
#   124069,
#   6885],
#  [6885,
#   67927,
#   84027,
#   47347,
#   13170,
#   115739,
#   55401,
#   105388,
#   111253,
#   81246,
#   31608,
#   2846,
#   47526,
#   12698,
#   124616,
#   36241,
#   115739,
#   13500,
#   25521,
#   122491,
#   48074,
#   78496,
#   37749,
#   78716,
#   68433,
#   31835,
#   26124,
#   112397,
#   124089,
#   115739,
#   21677,
#   116679,
#   26140,
#   111253,
#   32969,
#   17810,
#   115453,
#   24651,
#   73869,
#   21530,
#   41401,
#   115739,
#   21633,
#   17250,
#   48987,
#   37749,
#   104405,
#   21530,
#   80258,
#   115739,
#   21530,
#   86401],
#  [95256,
#   98926,
#   104108,
#   33247,
#   99845,
#   7809,
#   14807,
#   112677,
#   90134,
#   102919,
#   45837,
#   106318,
#   91808,
#   74212,
#   80725,
#   39719,
#   105546,
#   91423,
#   70725,
#   50623,
#   91906,
#   57588,
#   98647,
#   75603,
#   74212,
#   83283,
#   48444,
#   102230,
#   114445,
#   12069,
#   85019,
#   46679,
#   88987,
#   89675,
#   64874,
#   32237,
#   102919,
#   80500,
#   98647,
#   12477,
#   111090,
#   17627,
#   81885,
#   95256,
#   42081,
#   5498,
#   105546,
#   37073,
#   79488,
#   105546,
#   20268,
#   61442,
#   98647,
#   60709,
#   114445,
#   113318,
#   74212,
#   103955,
#   99111,
#   54864,
#   69566,
#   89936,
#   111220,
#   91808,
#   79566,
#   98647,
#   119356,
#   109201,
#   41308,
#   75097,
#   37420,
#   72690,
#   27058,
#   27932,
#   96435,
#   105546,
#   15866,
#   24975,
#   34496,
#   118044,
#   116395,
#   62261,
#   5501,
#   17627,
#   81124,
#   109201,
#   89839],
#  [37749,
#   38767,
#   13170,
#   78602,
#   105388,
#   111253,
#   81246,
#   91568,
#   31608,
#   96220,
#   115739,
#   67927,
#   104313,
#   112397,
#   37071,
#   115739,
#   27149,
#   124616,
#   88243,
#   86184,
#   40315,
#   116474,
#   82432,
#   64647,
#   89937,
#   26124,
#   50555,
#   98251,
#   84027,
#   39719,
#   107568,
#   40315,
#   89403,
#   79077,
#   70832,
#   50555,
#   55401,
#   124616,
#   86933,
#   31835,
#   92396,
#   9103,
#   115739,
#   94999,
#   43312,
#   13500,
#   85158,
#   119559,
#   92396,
#   54270,
#   125602,
#   37749,
#   86448,
#   31835,
#   14194,
#   112397,
#   79716,
#   115739,
#   81787,
#   9544,
#   84027,
#   95558,
#   52267,
#   99406],
#  [29659,
#   31817,
#   58894,
#   28702,
#   86700,
#   36220,
#   37095,
#   87777,
#   48702,
#   49703,
#   64448,
#   60449,
#   102730,
#   52458,
#   85595,
#   55775,
#   100795,
#   49703,
#   3715],
#  [86539,
#   39719,
#   114210,
#   92396,
#   69766,
#   48302,
#   89742,
#   94259,
#   72088,
#   14792,
#   100960,
#   127896,
#   46252,
#   86539,
#   50229,
#   14792,
#   18390,
#   114210,
#   126991,
#   36093,
#   47281,
#   100960,
#   62114,
#   102919,
#   86539,
#   39719,
#   111578,
#   54116,
#   125956],
#  [6885,
#   31835,
#   112397,
#   21600,
#   3656,
#   115739,
#   112648,
#   13170,
#   124616,
#   88243,
#   54106,
#   99793,
#   45196,
#   79964,
#   122816,
#   31835,
#   112397,
#   31849,
#   73308,
#   81822,
#   105388,
#   112397,
#   48831,
#   111412,
#   115739,
#   21017,
#   36525,
#   73287,
#   74393],
#  [86539,
#   32142,
#   79501,
#   86539,
#   99003,
#   98337,
#   86539,
#   89742,
#   42407,
#   14713,
#   11983,
#   128422,
#   86653,
#   86539,
#   24867,
#   54422,
#   64735,
#   126916,
#   104557,
#   35475,
#   114210,
#   69766,
#   33080,
#   37556,
#   39719,
#   111084,
#   123202,
#   1241,
#   69766,
#   77856,
#   48987,
#   54116,
#   80360,
#   24173,
#   127896,
#   14371,
#   118636,
#   14371,
#   59470,
#   115401,
#   14371,
#   2884,
#   14371,
#   104710,
#   14371,
#   61682,
#   63031,
#   86539,
#   13820,
#   35338,
#   86539,
#   82088,
#   95702,
#   33080,
#   50245,
#   98337,
#   52807,
#   98337,
#   8881,
#   86539,
#   89742,
#   114210,
#   4009],
#  [92396,
#   124616,
#   79077,
#   27590,
#   69630,
#   69352,
#   66835,
#   39719,
#   92177,
#   22322,
#   108892,
#   125234],
#  [73308,
#   81822,
#   64052,
#   78382,
#   40315,
#   792,
#   20231,
#   122112,
#   54791,
#   47349,
#   54791,
#   31835,
#   40315,
#   38767,
#   73511,
#   56332,
#   115739,
#   124616,
#   119850,
#   67927,
#   112397,
#   31849,
#   13500,
#   72373,
#   68165,
#   43341,
#   65898,
#   105511,
#   20099,
#   68787,
#   115739,
#   67927,
#   4068,
#   24841,
#   112397,
#   79716,
#   26974,
#   37749,
#   36469,
#   81822,
#   73308,
#   105388,
#   112397,
#   103884,
#   124616,
#   109775,
#   89980,
#   59297,
#   41099,
#   124616,
#   47787,
#   21530,
#   41401,
#   31835,
#   47773,
#   26140,
#   112397,
#   6562,
#   115739,
#   36206,
#   23978,
#   31835,
#   21633,
#   109775,
#   72896,
#   92177,
#   99638,
#   26808,
#   110232,
#   55401,
#   105388,
#   18136,
#   37749,
#   792,
#   67435,
#   41401,
#   17627],
#  [54791,
#   31835,
#   40315,
#   112397,
#   73511,
#   9286,
#   124616,
#   88243,
#   31835,
#   112397,
#   31849,
#   115739,
#   26124,
#   54927,
#   50555,
#   21633,
#   36206,
#   34053,
#   28291,
#   124616,
#   88243,
#   31835,
#   87550,
#   52267,
#   113705,
#   15354,
#   125357,
#   82541,
#   69630,
#   21633,
#   124616,
#   5438,
#   101249,
#   64052,
#   2804,
#   109775,
#   100806,
#   73308,
#   81822,
#   105388,
#   48831,
#   111412],
#  [29186,
#   117454,
#   117120,
#   47230,
#   64910,
#   36220,
#   57058,
#   78146,
#   58894,
#   99955,
#   49703,
#   34630,
#   122806,
#   97038,
#   49703,
#   64872,
#   44640,
#   128695,
#   68754,
#   49703,
#   85595,
#   69449,
#   77271,
#   17627,
#   2012,
#   52475,
#   45099,
#   102730,
#   117120,
#   17627],
#  [51855,
#   86184,
#   40315,
#   47773,
#   792,
#   56469,
#   37856,
#   13500,
#   29666,
#   61347,
#   76345,
#   20099,
#   84789,
#   67927,
#   112397,
#   31849,
#   115739,
#   57420,
#   54969,
#   122491,
#   112397,
#   37071,
#   115739,
#   108465,
#   51855,
#   81177,
#   70959,
#   20295,
#   52082,
#   98614,
#   48008,
#   124616,
#   90899,
#   44973,
#   79964,
#   67927,
#   27033,
#   115739,
#   64052,
#   88390,
#   126972,
#   95740,
#   108574,
#   55401,
#   21677,
#   36206,
#   55400,
#   73498,
#   21677,
#   72509,
#   40387,
#   51855,
#   22523,
#   4591,
#   56469,
#   9408],
#  [116646,
#   27876,
#   81177,
#   64052,
#   48542,
#   37749,
#   41401,
#   31835,
#   100487,
#   92396,
#   78302,
#   84885,
#   126972,
#   92177,
#   127929,
#   73029,
#   73308,
#   122491,
#   126006,
#   72866,
#   34985,
#   125146,
#   64052,
#   110024,
#   92177,
#   99411,
#   11439,
#   31835,
#   124616,
#   1502,
#   92396,
#   47760,
#   111751,
#   115739,
#   63231,
#   36471,
#   88243,
#   48987,
#   50555,
#   31835,
#   47347,
#   124616,
#   44336,
#   10985,
#   37749,
#   81642,
#   112397,
#   79716,
#   115739,
#   124616,
#   76432,
#   109381,
#   112397,
#   114095,
#   59861,
#   128466,
#   50565,
#   123448,
#   80954,
#   115739,
#   69750,
#   73357,
#   42796,
#   112121],
#  [92396,
#   19524,
#   88243,
#   81822,
#   73308,
#   105388,
#   112397,
#   48831,
#   111412,
#   26124,
#   67927,
#   36206,
#   112397,
#   31849,
#   115739,
#   37749,
#   85708,
#   67927,
#   84027,
#   103603,
#   26124,
#   47071,
#   113664,
#   23611,
#   92396,
#   37749,
#   111751,
#   124616,
#   109745,
#   92177,
#   127929,
#   92177,
#   99638,
#   122491,
#   115739,
#   21633,
#   21530,
#   41401,
#   116679,
#   21677,
#   92396,
#   11906,
#   90191,
#   126972,
#   62312,
#   79716,
#   31835,
#   81110,
#   124616,
#   88243,
#   81177,
#   76322,
#   37749,
#   69228,
#   54106,
#   107791,
#   28192,
#   48454,
#   124616,
#   22934,
#   37749,
#   54631,
#   117338,
#   73287,
#   96752,
#   109706,
#   21677,
#   6485,
#   60893,
#   59929,
#   115453,
#   116679,
#   115739,
#   21677,
#   5046,
#   8959,
#   124616,
#   16534,
#   56469,
#   110608,
#   31835,
#   51855,
#   22523,
#   21025,
#   36525,
#   73287,
#   122112,
#   77928,
#   70989,
#   91684],
#  [85804,
#   47474,
#   93599,
#   64,
#   124616,
#   108718,
#   81930,
#   39435,
#   75052,
#   76235,
#   95328,
#   114210,
#   112685,
#   68915,
#   81930,
#   127123,
#   60854,
#   20001,
#   124616,
#   92543,
#   7680,
#   95328,
#   54739,
#   62323,
#   85595,
#   73869,
#   39673,
#   99191,
#   16399,
#   55085,
#   25146,
#   126238,
#   62323,
#   10398,
#   114402,
#   20001,
#   104195,
#   72549,
#   35021,
#   95328,
#   9055,
#   59041,
#   64050,
#   19866],
#  [122806,
#   58894,
#   78792,
#   49703,
#   77894,
#   26525,
#   27156,
#   85595,
#   99025,
#   22886,
#   102730,
#   28425,
#   10384,
#   51286,
#   107117,
#   53564,
#   58894,
#   103173,
#   69449,
#   79006,
#   53564,
#   58894,
#   77894,
#   67527,
#   38033,
#   61034,
#   85595,
#   14643,
#   49703,
#   46020,
#   117400,
#   127484,
#   85595,
#   97533,
#   85041,
#   69449,
#   35995,
#   69396,
#   76109,
#   53564,
#   28702,
#   21876,
#   17164,
#   51286,
#   107117,
#   39005,
#   51238,
#   62184,
#   39005,
#   73465,
#   23098,
#   54720,
#   102730,
#   28425,
#   109602,
#   51286,
#   107117,
#   53564,
#   85595,
#   69449,
#   9839,
#   28425,
#   51453,
#   68754,
#   49703,
#   124210,
#   93406,
#   78146,
#   69766,
#   57504,
#   111067,
#   60449,
#   46332,
#   118622,
#   85595,
#   52981,
#   128259,
#   58894,
#   19440,
#   49703,
#   71339,
#   83947,
#   85595,
#   52981,
#   47733,
#   51286,
#   107117,
#   53564,
#   69396,
#   48782,
#   85595,
#   69449,
#   10868,
#   15792,
#   29525,
#   73673,
#   99138,
#   114002,
#   50047,
#   69449,
#   98294,
#   53564,
#   93903,
#   49703,
#   69449,
#   22720,
#   85595,
#   14458,
#   49703,
#   28702,
#   73876],
#  [26124,
#   67927,
#   84027,
#   58368,
#   82932,
#   92396,
#   37749,
#   109381,
#   124616,
#   25521,
#   122491,
#   47347,
#   120057,
#   115739,
#   31849,
#   21677,
#   55401,
#   50555,
#   112397,
#   51403,
#   112397,
#   48831,
#   111412,
#   112397,
#   7341],
#  [38767,
#   76915,
#   111253,
#   107591,
#   69630,
#   98934,
#   77196,
#   111253,
#   64937,
#   92396,
#   91213,
#   51871,
#   64052,
#   86401,
#   33182,
#   114402,
#   88243,
#   52267,
#   40655,
#   43449,
#   98251,
#   40552,
#   92396,
#   124616,
#   71914,
#   92177,
#   48454],
#  [989,
#   98337,
#   29339,
#   11977,
#   127896,
#   47356,
#   6444,
#   24120,
#   39774,
#   53017,
#   86539,
#   91894,
#   7841,
#   86539,
#   105221,
#   126238,
#   111396,
#   98337,
#   24173,
#   73498,
#   104333,
#   14371,
#   93606,
#   58864,
#   122087,
#   86539,
#   120473,
#   86539,
#   33657,
#   6290,
#   114210,
#   8618,
#   92396,
#   86539,
#   33080,
#   84799,
#   7841,
#   100183,
#   72509,
#   31921,
#   14371,
#   93606,
#   58864,
#   88207,
#   105529,
#   39774,
#   21095,
#   56366,
#   35585,
#   61261,
#   24173,
#   58864,
#   86539,
#   34937,
#   124445,
#   100960,
#   88501,
#   102919,
#   94908,
#   30084,
#   86539,
#   22871,
#   45026,
#   34496,
#   86539,
#   12416,
#   82100,
#   86539,
#   128534,
#   102772],
#  [86539,
#   92120,
#   104767,
#   79501,
#   86539,
#   35026,
#   99003,
#   31906,
#   72649,
#   83250,
#   86653,
#   86539,
#   72088,
#   45026,
#   98337,
#   125446,
#   4186],
#  [74208,
#   55401,
#   52082,
#   111253,
#   45597,
#   46502,
#   112397,
#   24970,
#   14553,
#   67178,
#   84027,
#   119379,
#   35699,
#   115739,
#   118854,
#   103222,
#   105511,
#   11559,
#   102794,
#   82389,
#   116829,
#   25286,
#   55401,
#   50555,
#   48455,
#   46502,
#   60893,
#   11559,
#   78587,
#   50806,
#   26602,
#   51855,
#   14996,
#   105511,
#   43549,
#   38347,
#   32636,
#   51855,
#   28638,
#   124385,
#   4068,
#   86448,
#   38347,
#   69630,
#   112397,
#   50620,
#   81110,
#   74208,
#   112397,
#   69810,
#   126453,
#   39714,
#   112397,
#   109775,
#   41538,
#   21981,
#   31835,
#   52082,
#   35153,
#   115739,
#   124616,
#   82076,
#   26124,
#   45885,
#   65898,
#   40315,
#   89980,
#   59297,
#   74952,
#   79716,
#   31835,
#   21633,
#   37749,
#   19300,
#   64937,
#   37749,
#   29987,
#   12008,
#   118757,
#   118229,
#   105511,
#   124616,
#   108634,
#   84263,
#   35699,
#   20408,
#   83352,
#   116114,
#   24866,
#   34126,
#   45196,
#   26104,
#   128325,
#   73498,
#   43341,
#   108144,
#   40833,
#   72866,
#   63231,
#   69630,
#   51855,
#   81069,
#   57979,
#   115739,
#   17035,
#   46462,
#   108007,
#   109606,
#   22523,
#   36525,
#   73287,
#   70157],
#  [98150,
#   53564,
#   58894,
#   21504,
#   128423,
#   7309,
#   53564,
#   23098,
#   109344,
#   22569,
#   45099,
#   47759,
#   79260,
#   75881],
#  [112121,
#   39005,
#   60449,
#   34106,
#   32734,
#   73629,
#   117454,
#   75522,
#   25906,
#   107117,
#   53564,
#   26525,
#   72544,
#   77895,
#   69396,
#   92876,
#   107117,
#   69766,
#   102730,
#   62184,
#   45099,
#   64910,
#   39005,
#   39005,
#   123099,
#   107682,
#   23098,
#   69449,
#   22585,
#   74498,
#   42772,
#   110393,
#   58894,
#   98313,
#   85595,
#   39399,
#   30464,
#   61862,
#   85595,
#   69449,
#   113145,
#   17403,
#   84296,
#   26525,
#   93812,
#   68110,
#   39005,
#   60449,
#   98042,
#   14761,
#   30489,
#   21501,
#   115744,
#   49703,
#   120314,
#   82091,
#   38940,
#   28425,
#   51453,
#   85595,
#   69449,
#   113145,
#   92392,
#   110689,
#   25906,
#   49703,
#   57120,
#   39005,
#   2207,
#   28702,
#   46444],
#  [29186,
#   44488,
#   51286,
#   107117,
#   74630,
#   23098,
#   109344,
#   89991,
#   37172,
#   46252,
#   89713,
#   30489,
#   69449,
#   22585,
#   34677,
#   53564,
#   4526,
#   28702,
#   73876,
#   33025,
#   38590,
#   77274,
#   124210,
#   102601,
#   64910,
#   39005,
#   60449,
#   62184,
#   91814,
#   58894,
#   93067,
#   83507,
#   49703,
#   28702,
#   80277,
#   47759,
#   22585,
#   39005,
#   69766,
#   25663,
#   84361,
#   83975,
#   85595,
#   75895,
#   23098,
#   2814,
#   85595,
#   69449,
#   98294,
#   49703,
#   85595,
#   69449,
#   107452,
#   64910,
#   43025,
#   120314,
#   23098,
#   69449,
#   20024,
#   18468,
#   63451,
#   29712,
#   49703,
#   96804,
#   52664,
#   96804,
#   58894,
#   70593,
#   39885,
#   56744,
#   14641,
#   34677,
#   39005,
#   3625,
#   110761,
#   32734,
#   63337,
#   85595,
#   1580,
#   49703,
#   22105,
#   108984,
#   106124,
#   31090,
#   49703,
#   74452,
#   30489,
#   128423,
#   35018,
#   56202,
#   97980,
#   2207,
#   116768,
#   58894,
#   84109,
#   34937,
#   39005,
#   86286,
#   60449,
#   116186,
#   79637,
#   85595,
#   107802,
#   82799,
#   58894,
#   35225,
#   77928,
#   109344,
#   112334,
#   53564,
#   23098,
#   92746,
#   110393,
#   59830,
#   119194,
#   81335,
#   32734,
#   48774,
#   45099,
#   66553,
#   70283,
#   25663,
#   98313],
#  [44957,
#   76538,
#   65071,
#   25146,
#   57502,
#   50145,
#   58855,
#   77574,
#   18693,
#   44957,
#   37856,
#   102443,
#   56157,
#   39774,
#   81930,
#   125341,
#   48911,
#   16417,
#   91814,
#   96328,
#   120277,
#   92396,
#   71780,
#   13349,
#   6334,
#   96917,
#   35021,
#   39774,
#   32891,
#   41930,
#   64,
#   95328,
#   110086,
#   20001,
#   48034,
#   102554,
#   44030,
#   104195,
#   38287,
#   91814,
#   21790,
#   58279,
#   64,
#   20001,
#   86506,
#   38738,
#   95328,
#   13349,
#   82625,
#   107583,
#   21790,
#   81930,
#   27243,
#   91814,
#   91869,
#   64,
#   120277,
#   112973,
#   14983,
#   6833,
#   91814,
#   14533,
#   56954,
#   97769,
#   4097,
#   91814,
#   57117,
#   64,
#   120277,
#   112973,
#   14983,
#   86140,
#   10029,
#   23506,
#   114402,
#   21790,
#   20001,
#   84234,
#   7841,
#   20001,
#   43344,
#   35710,
#   95328,
#   13349,
#   23587,
#   85595,
#   88390,
#   75921,
#   48034,
#   33931,
#   7841,
#   23175,
#   89169,
#   101039,
#   15761,
#   57908,
#   85595,
#   88390,
#   75921,
#   34389,
#   21790,
#   113943,
#   23587,
#   112973,
#   126187,
#   7841,
#   36206,
#   19866,
#   31516,
#   81930,
#   86148,
#   114210,
#   113485,
#   77574,
#   76538,
#   96328,
#   92791,
#   22735,
#   91814,
#   35335,
#   92396,
#   10113,
#   109537,
#   35021,
#   21790,
#   7210,
#   93599,
#   35037,
#   3667,
#   12319,
#   46385,
#   114210,
#   60854,
#   20001,
#   81961,
#   85595,
#   68787,
#   36841,
#   106968,
#   114210,
#   85595,
#   127059,
#   62323,
#   85595,
#   69376,
#   91814,
#   67821,
#   83442,
#   29671,
#   114210,
#   79429,
#   34023,
#   112373,
#   35037,
#   81930,
#   93372,
#   83455,
#   91814,
#   29671,
#   114210,
#   32855,
#   92396,
#   85595,
#   86256,
#   124616,
#   35037,
#   114402,
#   72554,
#   76538,
#   119022,
#   35710,
#   114210,
#   112685,
#   10732,
#   114402,
#   95328,
#   104195,
#   18173,
#   77574,
#   102442,
#   92585,
#   114210,
#   11462,
#   29671,
#   80747,
#   15761,
#   35710,
#   20001,
#   92396,
#   3257,
#   13349,
#   91814,
#   81961,
#   54350,
#   43549,
#   7625,
#   114445,
#   19056,
#   3926,
#   92396,
#   95328,
#   113716,
#   105320,
#   77066,
#   35021,
#   92396,
#   85595,
#   127191,
#   35710,
#   73498,
#   64,
#   120277,
#   113943,
#   56179,
#   42070,
#   109175,
#   114210,
#   28495,
#   112973,
#   88263,
#   64,
#   85595,
#   27184,
#   92396,
#   91814,
#   67709,
#   92396,
#   95328,
#   44914,
#   79916,
#   114210,
#   77574,
#   112973,
#   77066,
#   89437,
#   13349,
#   91814,
#   85595,
#   60509,
#   14983,
#   64050,
#   56191,
#   91814,
#   25821,
#   87833,
#   85595,
#   86256,
#   14983,
#   82508,
#   75052,
#   89489,
#   91814,
#   40376,
#   38738,
#   29667,
#   25828,
#   86506,
#   95328,
#   107838,
#   28495,
#   85595,
#   19999,
#   76538,
#   20001,
#   92396,
#   7120,
#   91814,
#   54489,
#   33713,
#   17211,
#   31219,
#   120618,
#   26623,
#   56586,
#   49320,
#   54969,
#   33321,
#   49027,
#   81222,
#   114402,
#   20001,
#   104332,
#   97072,
#   91814,
#   40388,
#   66867,
# ...
#   69354,
#   13561,
#   13500,
#   67927,
#   69630,
#   13500,
#   35322,
#   102320,
#   124616,
#   24580,
#   77928,
#   31835,
#   43312,
#   104648,
#   19467,
#   115739,
#   112397,
#   107344,
#   91437,
#   52267,
#   12008,
#   108437,
#   108007,
#   25899,
#   14309,
#   18870,
#   94815,
#   52267,
#   40552,
#   105511,
#   115022,
#   43549,
#   43312,
#   87550,
#   17627,
#   56021,
#   101978,
#   73308,
#   78496,
#   6421,
#   9286,
#   111253,
#   22322,
#   125660,
#   117129,
#   115739,
#   7949,
#   26767,
#   52267,
#   124616,
#   123857,
#   56469],
#  [73308,
#   81822,
#   105388,
#   92396,
#   37749,
#   77928,
#   90891,
#   112397,
#   48831,
#   111412,
#   73923,
#   37749,
#   81642,
#   115739,
#   124616,
#   40617,
#   76389,
#   45732,
#   92177,
#   51609,
#   81822,
#   26124,
#   105388,
#   85128,
#   45967,
#   55401,
#   105388,
#   112397,
#   37071,
#   115418,
#   36206,
#   87631,
#   115739,
#   105388,
#   97277,
#   21654,
#   115739,
#   54626,
#   88777,
#   64052,
#   26104,
#   67927,
#   36206,
#   49018,
#   73498,
#   73308,
#   66648,
#   21633,
#   84027,
#   106773,
#   20099,
#   73308,
#   112504,
#   100933,
#   74050,
#   81822,
#   37749,
#   73869,
#   21530,
#   26104,
#   67927,
#   81177,
#   116312,
#   92177,
#   55422,
#   124616,
#   6649,
#   31835,
#   47773,
#   27033,
#   115739,
#   125904,
#   9628,
#   20099,
#   99049,
#   37749,
#   114670,
#   115739,
#   117756,
#   79815,
#   64052,
#   26915,
#   31835,
#   26140,
#   99417,
#   92177,
#   32456,
#   45133,
#   38751,
#   21677,
#   50555,
#   105511,
#   84027,
#   88390,
#   86271,
#   72599,
#   104770],
#  [39005,
#   60449,
#   116768,
#   58894,
#   28702,
#   98895,
#   33025,
#   45967,
#   107117,
#   39005,
#   69766,
#   73444,
#   85595,
#   17811,
#   69371,
#   30489,
#   128423,
#   99545,
#   117472,
#   22585,
#   53564,
#   122967,
#   77274,
#   46230,
#   117949,
#   23098,
#   107936,
#   4526,
#   113125,
#   23098,
#   117086,
#   64049,
#   69449,
#   98294,
#   49703,
#   28425,
#   48221],
#  [73308,
#   42835,
#   40315,
#   123857,
#   115739,
#   12549,
#   20231,
#   92396,
#   8088,
#   7442,
#   26104,
#   45967,
#   115739,
#   115275,
#   20941,
#   81822,
#   105388,
#   112397,
#   19923,
#   100229,
#   115739,
#   105388,
#   115275,
#   103233,
#   117092,
#   64052,
#   26104,
#   81822,
#   73308,
#   36206,
#   101012,
#   65898,
#   10228,
#   124616,
#   21981,
#   67927,
#   109775,
#   52659,
#   115739,
#   124616,
#   57301,
#   112397,
#   57420,
#   13500,
#   26104,
#   54106,
#   121313,
#   125286,
#   115739,
#   21677,
#   54927,
#   37856,
#   67178,
#   13500,
#   39929,
#   43549,
#   76322,
#   37749,
#   39496,
#   78496,
#   37749,
#   50047,
#   115739,
#   20099,
#   6607,
#   43341,
#   55401,
#   21677,
#   12008,
#   116474,
#   18027,
#   105511,
#   124616,
#   67283,
#   73308,
#   81822,
#   78496,
#   37856,
#   43341,
#   40655,
#   58821,
#   92177,
#   20099,
#   127474,
#   37749,
#   64112,
#   106959,
#   59399,
#   115739,
#   116114,
#   15538,
#   85221,
#   59399,
#   55445,
#   21633,
#   40315,
#   19718,
#   107541,
#   124616,
#   31997,
#   26350,
#   94133,
#   31835,
#   112397,
#   92177,
#   36380,
#   64052,
#   86448,
#   82076,
#   26124,
#   12008,
#   3141,
#   106084,
#   111253,
#   22322,
#   51837,
#   53392,
#   11259,
#   37856,
#   122363,
#   21677,
#   78496,
#   3250,
#   103884,
#   117799,
#   111151,
#   34053,
#   4797,
#   9557,
#   36206,
#   40315,
#   12591,
#   34757,
#   50555,
#   48987,
#   37749,
#   103168,
#   21677,
#   38751,
#   69630,
#   72866,
#   92177,
#   41282,
#   115453,
#   108465,
#   21677,
#   67178,
#   92751,
#   21654,
#   81822,
#   15600,
#   73308,
#   42835,
#   40315,
#   112397,
#   792,
#   20231,
#   64052,
#   83018,
#   80528,
#   115739,
#   74393,
#   69810,
#   73287],
#  [13500,
#   26104,
#   31835,
#   112397,
#   79716,
#   115739,
#   124616,
#   106910,
#   111253,
#   45967,
#   124616,
#   13500,
#   26104,
#   93527,
#   67927,
#   40345,
#   37071,
#   115739,
#   43312,
#   36206,
#   79902,
#   94095,
#   60893,
#   59929,
#   26140,
#   92177,
#   36380],
#  [76589,
#   43549,
#   27964,
#   92396,
#   22322,
#   104921,
#   118705,
#   121651,
#   15600,
#   40138,
#   34380,
#   25474,
#   72509,
#   65898,
#   73308,
#   111253,
#   91115,
#   105873,
#   55401,
#   45967,
#   105388,
#   115418,
#   13500,
#   26104,
#   31835,
#   10289,
#   115739,
#   111253,
#   112397,
#   108255,
#   64940,
#   21530,
#   116423,
#   91437,
#   115739,
#   54106,
#   81177,
#   76322,
#   37749,
#   83352,
#   104648,
#   105511,
#   22322,
#   5899,
#   45196,
#   88681,
#   44640,
#   90506,
#   111253,
#   108255,
#   29402,
#   67927,
#   112397,
#   31849,
#   115739,
#   73308,
#   100622,
#   45967,
#   52267,
#   112397,
#   97539,
#   43449,
#   115739,
#   115275,
#   19300,
#   92878,
#   115739,
#   115843,
#   50620,
#   66002,
#   115739,
#   264],
#  [39005,
#   60449,
#   34106,
#   114921,
#   60562,
#   10384,
#   30489,
#   47759,
#   22585,
#   69449,
#   127430,
#   53564,
#   29186,
#   49703,
#   58894,
#   119990,
#   117400,
#   18032,
#   31093,
#   2814,
#   85595,
#   69449,
#   98294,
#   20001,
#   18032,
#   8318,
#   85595,
#   73558,
#   23098,
#   44427,
#   85595,
#   98789,
#   119301,
#   69449,
#   6040,
#   53564,
#   58894,
#   29473,
#   40253,
#   56953,
#   17476,
#   80638,
#   58894,
#   22894,
#   44364,
#   53564,
#   58894,
#   78792,
#   23098,
#   49003,
#   73758,
#   77438,
#   110393,
#   98042,
#   7435,
#   59286,
#   28109,
#   102730,
#   39332,
#   27533,
#   37108,
#   45099,
#   55775,
#   18669,
#   45967,
#   39332,
#   58894,
#   71339,
#   45099,
#   49584,
#   55775,
#   36905,
#   18032,
#   119119,
#   69449,
#   127430,
#   49703,
#   69449,
#   22585,
#   117400,
#   18032,
#   89917,
#   77796,
#   85595,
#   69449,
#   61485],
#  [58894,
#   93067,
#   117454,
#   30489,
#   69449,
#   22585,
#   85595,
#   45967,
#   38888,
#   30489,
#   128423,
#   52446,
#   128202,
#   61165,
#   57996,
#   38948,
#   29186,
#   38940,
#   69449,
#   13128,
#   49703,
#   28425,
#   84307,
#   46636,
#   80083,
#   58894,
#   64743,
#   85595,
#   45967,
#   59899,
#   45099,
#   102730],
#  [73308,
#   122491,
#   114921,
#   66061,
#   44727,
#   117500,
#   34496,
#   70144,
#   31835,
#   118505,
#   72866,
#   72509,
#   67819,
#   69630,
#   13500,
#   67927,
#   105388,
#   78496,
#   35137,
#   27191,
#   36512,
#   105123,
#   81822,
#   73308,
#   12008,
#   106961,
#   98251,
#   92396,
#   124616,
#   80470,
#   82877,
#   92177,
#   77668,
#   124616,
#   48021,
#   21530,
#   26104,
#   31835,
#   77971,
#   13500,
#   66112,
#   51855,
#   22523,
#   46462,
#   112397,
#   5653,
#   106961,
#   65898,
#   12008,
#   60287,
#   115035,
#   88116,
#   31835,
#   112397,
#   109775,
#   13500,
#   26104,
#   31835,
#   112397,
#   79716,
#   91437,
#   124616,
#   51871,
#   31835,
#   112397,
#   109775,
#   73308,
#   42835,
#   51781,
#   33132,
#   73308,
#   42835,
#   34053,
#   85198,
#   12008,
#   29533,
#   114273,
#   92396,
#   31427,
#   12008,
#   117129,
#   115739,
#   107825,
#   37791,
#   80293,
#   120402,
#   65898,
#   72599,
#   115739,
#   86178,
#   47071,
#   26124,
#   21633,
#   16274,
#   79112,
#   60627,
#   73308,
#   42835,
#   12008,
#   112397,
#   7442,
#   108007,
#   115739,
#   45713,
#   13500,
#   26104,
#   112397,
#   36380],
#  [112397,
#   37637,
#   29533,
#   101023,
#   99654,
#   77082,
#   111253,
#   81642,
#   65792,
#   26104,
#   67927,
#   47347,
#   52659,
#   115739,
#   112397,
#   10289,
#   91437,
#   124616,
#   9286,
#   55401,
#   105388,
#   111253,
#   3141,
#   127153,
#   74087,
#   73308,
#   81822,
#   105388,
#   112397,
#   48831,
#   111412,
#   59005,
#   18632,
#   52267,
#   90920,
#   115739,
#   12549,
#   63407,
#   13500,
#   26104,
#   54106,
#   125146,
#   92396,
#   122281,
#   115739,
#   67927,
#   72866,
#   115022,
#   80962,
#   92177,
#   55422,
#   69630,
#   124616,
#   45071,
#   55401,
#   50555,
#   78211,
#   17627,
#   1606,
#   23885,
#   115739,
#   50919,
#   64052,
#   112297,
#   7012],
#  [13170,
#   112397,
#   37071,
#   115739,
#   18239,
#   124616,
#   109570,
#   37749,
#   88243,
#   67927,
#   60151,
#   37174,
#   124616,
#   119850,
#   23794,
#   31835,
#   26140,
#   118622,
#   7331,
#   19888,
#   23791,
#   115739,
#   36932,
#   44094,
#   26140,
#   43341,
#   118622,
#   5653,
#   21126,
#   26124,
#   82076,
#   28638,
#   37290,
#   57301,
#   24698,
#   26140,
#   65373,
#   45196,
#   31707,
#   37290,
#   65266,
#   105511,
#   37749,
#   23989,
#   119935,
#   37749,
#   49419,
#   12214,
#   116114,
#   73858,
#   19516,
#   31835,
#   31835,
#   26124,
#   6485,
#   21633,
#   122112,
#   39463,
#   17810,
#   112397,
#   112397,
#   67819,
#   23259,
#   44640,
#   53118,
#   31835,
#   21633,
#   112397,
#   6562,
#   111151,
#   84432,
#   119935,
#   26124,
#   78085,
#   37694,
#   26104,
#   31835,
#   116679,
#   21677,
#   50555,
#   21633,
#   72866,
#   70832,
#   13500,
#   26104,
#   110827,
#   98251,
#   50555,
#   4068,
#   13625,
#   92177,
#   104562,
#   92396,
#   100250,
#   21126,
#   9830,
#   40315,
#   6597,
#   97228,
#   11053,
#   37749,
#   58895,
#   31835,
#   112397,
#   122965,
#   115739,
#   13500,
#   67917,
#   31835,
#   92396,
#   37749,
#   43537,
#   9773,
#   73498,
#   42777,
#   31835,
#   17627,
#   29415,
#   47347,
#   51871,
#   112397,
#   118688,
#   112397,
#   117879,
#   27030,
#   81642,
#   119850,
#   109775,
#   52659,
#   17627,
#   17627,
#   17627,
#   17627],
#  [88685,
#   85595,
#   38827,
#   88685,
#   30489,
#   69449,
#   22585,
#   58894,
#   24062,
#   58894,
#   82804,
#   23098,
#   23057,
#   119194,
#   84438,
#   18737,
#   32734,
#   95387,
#   25663,
#   8997,
#   102388,
#   69290,
#   123429,
#   38940,
#   128423,
#   58741,
#   28109,
#   34677,
#   95479,
#   15317,
#   110393,
#   17627,
#   15109,
#   103301,
#   109278,
#   31374,
#   128423,
#   103346,
#   33025,
#   112106,
#   75126,
#   21876,
#   41216,
#   17612,
#   63585,
#   126289,
#   100038,
#   62118,
#   27104,
#   34937,
#   117400,
#   28425,
#   30698,
#   11748,
#   16101,
#   17612,
#   87295,
#   18032,
#   117949,
#   26257,
#   49703,
#   30489,
#   26525,
#   17612,
#   61486,
#   3051,
#   51390,
#   117400,
#   18032,
#   89917,
#   128423,
#   58326,
#   44640,
#   101432,
#   23098,
#   123704,
#   18032,
#   29695,
#   110591,
#   77796,
#   45275,
#   126289,
#   74624,
#   122478,
#   34937,
#   56678,
#   96473,
#   38948,
#   49703,
#   2636,
#   58894,
#   104739,
#   9804,
#   44640,
#   105919,
#   101475,
#   98294,
#   101475,
#   2367,
#   122874,
#   85595,
#   69449,
#   22585,
#   101475,
#   83158,
#   85595,
#   93396,
#   49703,
#   65608,
#   28702],
#  [39005,
#   60449,
#   34106,
#   44640,
#   106789,
#   85595,
#   34830,
#   126289,
#   31304,
#   44640,
#   24172,
#   128423,
#   58741,
#   53564,
#   85595,
#   82978,
#   103013,
#   69449,
#   22585,
#   58894,
#   49510,
#   49703,
#   69449,
#   98294,
#   33845,
#   45275,
#   128423,
#   2095,
#   53564,
#   32734,
#   3051,
#   76458,
#   49703,
#   101938,
#   110393,
#   26665,
#   52852,
#   117400,
#   18032,
#   47316,
#   26525,
#   114002,
#   93812,
#   85595,
#   89742,
#   61505,
#   102730,
#   117949,
#   32734,
#   93067,
#   54422,
#   85595,
#   110495,
#   45099,
#   63451,
#   102730,
#   97897,
#   85595,
#   69449,
#   47921,
#   121851,
#   39005,
#   60449,
#   2151,
#   168,
#   128144,
#   51453,
#   49703,
#   2576,
#   39005,
#   125653,
#   14270,
#   58894,
#   14641,
#   128423,
#   114422,
#   28109,
#   93396,
#   43922,
#   102730,
#   89805,
#   45099,
#   55775,
#   52446,
#   44305,
#   102730,
#   53564,
#   89805,
#   117400,
#   18032,
#   52238,
#   41180,
#   28425,
#   22746,
#   54374,
#   123495,
#   128423,
#   96261,
#   39494,
#   53564,
#   58894,
#   84109,
#   117400,
#   18032,
#   89917,
#   69449,
#   64653,
#   69449,
#   99969,
#   49703,
#   30502,
#   51286,
#   58741,
#   53564,
#   82854,
#   59899,
#   45099,
#   48537,
#   93111,
#   106789],
#  [32734,
#   75094,
#   91197,
#   72075,
#   75214,
#   9833,
#   83328,
#   54168,
#   98355,
#   76698,
#   83328,
#   93872,
#   24819,
#   124885,
#   96757,
#   127897,
#   44697,
#   44678,
#   66305,
#   69449,
#   28284,
#   69290,
#   14371,
#   24780,
#   84710],
#  [108465,
#   21677,
#   33132,
#   115739,
#   75987,
#   37468,
#   37749,
#   101854,
#   1322,
#   31835,
#   21677,
#   37856,
#   60497,
#   51439,
#   51855,
#   104744,
#   13500,
#   26104,
#   101237,
#   78496,
#   83532,
#   115739,
#   106301,
#   106400,
#   12113,
#   57979,
#   54009,
#   124616,
#   85868,
#   67927,
#   43312,
#   115739,
#   64052,
#   26104,
#   101978,
#   73308,
#   45196,
#   69750,
#   37749,
#   23158,
#   111253,
#   47258,
#   80259,
#   115739,
#   82526,
#   74087,
#   13500,
#   106535,
#   31835,
#   121313,
#   122965,
#   115739,
#   124616,
#   43537,
#   81177,
#   42777,
#   22633,
#   122816,
#   34985,
#   40325,
#   37749,
#   116905,
#   67927,
#   115739,
#   11460,
#   44640,
#   102782,
#   58233,
#   52234,
#   20295,
#   123445,
#   44817,
#   31835,
#   13500,
#   21633,
#   1429,
#   22633,
#   21677,
#   124616,
#   16534,
#   56469,
#   2690,
#   45732,
#   31835,
#   92396,
#   37749,
#   21981,
#   47071,
#   26124,
#   36206,
#   73498,
#   21677,
#   35097,
#   74393,
#   128279,
#   73287],
#  [92396,
#   82077,
#   78901,
#   97228,
#   79716,
#   47347,
#   31849,
#   115739,
#   112397,
#   38767,
#   43365,
#   17627,
#   20408,
#   106910,
#   107046,
#   67927,
#   18250,
#   115739,
#   114402,
#   73308,
#   37101,
#   82541,
#   55401,
#   101164,
#   45300,
#   105511,
#   105388,
#   21914,
#   98251,
#   105388,
#   124616,
#   65685,
#   92177,
#   27343,
#   101012,
#   81822,
#   73308,
#   84027,
#   115022,
#   6469,
#   29264,
#   81110,
#   107344,
#   111151,
#   114001,
#   116423,
#   119503,
#   20295,
#   95214,
#   81289,
#   115739,
#   87550,
#   14295,
#   124616,
#   5617,
#   92396,
#   37749,
#   100857,
#   82541,
#   112397,
#   128475,
#   124616,
#   86933,
#   67927,
#   65281,
#   115739,
#   58233,
#   124616,
#   51871,
#   112397,
#   14309,
#   92396,
#   37749,
#   71792,
#   115739,
#   75201,
#   112397,
#   118688,
#   45196,
#   88681,
#   81246,
#   124558,
#   37749,
#   33140,
#   31835,
#   78302,
#   84885,
#   126972,
#   92177,
#   50464,
#   76160,
#   115739,
#   84027,
#   91583,
#   106084,
#   26140,
#   84027,
#   88390,
#   62906,
#   76160,
#   10451,
#   21017,
#   105511,
#   111616,
#   125602,
#   9408,
#   115739,
#   26124,
#   55401,
#   105388,
#   112397,
#   110232,
#   97228,
#   7341,
#   29522,
#   102320,
#   31835,
#   124961,
#   124616,
#   127922,
#   52267,
#   20099,
#   125602,
#   81110,
#   21677,
#   12008,
#   1100,
#   55401,
#   37856,
#   116679,
#   26124,
#   18577,
#   69335,
#   81110,
#   21677,
#   81177,
#   40162,
#   22152,
#   115739,
#   84885,
#   126972,
#   62312,
#   22152],
#  [73308,
#   42835,
#   40315,
#   47347,
#   123857,
#   20231,
#   105511,
#   43549,
#   11017,
#   108255,
#   120775,
#   98799,
#   124616,
#   93992,
#   101135,
#   119850,
#   55401,
#   105388,
#   52267,
#   13500,
#   7035,
#   12415,
#   125024,
#   124616,
#   5617,
#   81833,
#   37749,
#   79724,
#   21677,
#   19291,
#   21633,
#   109775,
#   31374,
#   84027,
#   127632,
#   80640,
#   25899,
#   27061,
#   92177,
#   114008,
#   110429,
#   112397,
#   31849,
#   124616,
#   51871,
#   31835,
#   47347,
#   14309,
#   92396,
#   37749,
#   71792,
#   19467,
#   21677,
#   40387,
#   44817,
#   78085,
#   109175,
#   37681,
#   67927,
#   36525,
#   1799,
#   81463,
#   79625,
#   115739,
#   52679,
#   50472,
#   52267,
#   40315,
#   81823,
#   122816,
#   55401,
#   105388,
#   45196,
#   112826,
#   108377,
#   115739,
#   92177,
#   93161,
#   60287,
#   79738,
#   65898,
#   30865,
#   36206,
#   112397,
#   19923,
#   40617,
#   124069,
#   92591,
#   1545],
#  [80083,
#   63201,
#   39005,
#   125653,
#   14270,
#   14641,
#   23098,
#   69449,
#   22585,
#   37681,
#   39005,
#   43922,
#   37108,
#   26525,
#   93010,
#   117202,
#   77727,
#   34677,
#   43922,
#   89805,
#   42126,
#   44640,
#   27749,
#   44640,
#   33137,
#   35338,
#   96299,
#   39005,
#   125653,
#   102730,
#   85595,
#   68651,
#   5005,
#   28702,
#   30489,
#   47759,
#   30464,
#   114002,
#   22585,
#   102730,
#   53564,
#   6835,
#   49703,
#   97038,
#   40115,
#   12686,
#   18250,
#   23098,
#   92746,
#   110393,
#   69396,
#   27365,
#   23291,
#   39005,
#   69766,
#   58894,
#   28702,
#   46444,
#   38940,
#   28425,
#   68754,
#   23098,
#   1245,
#   4161,
#   39005,
#   60449,
#   2151,
#   55775,
#   117454,
#   17627],
#  [47347,
#   80083,
#   50804,
#   85595,
#   6536,
#   43594,
#   38666,
#   49703,
#   85595,
#   36220,
#   30864,
#   117472,
#   22585,
#   53564,
#   4526,
#   58894,
#   113125,
#   46252,
#   69766,
#   2151,
#   69449,
#   50047,
#   119626,
#   28702,
#   38888,
#   30489,
#   69449,
#   105041,
#   68698,
#   23098,
#   92746,
#   110393,
#   69396,
#   27365,
#   30489,
#   26525,
#   33757,
#   126289,
#   45726,
#   83423,
#   60913,
#   45099,
#   66553,
#   24909,
#   110393,
#   58894,
#   98313,
#   63201,
#   17627,
#   17627,
#   17627],
#  [122806,
#   63201,
#   23455,
#   94158,
#   23098,
#   28820,
#   69396,
#   84799,
#   59971,
#   85595,
#   15538,
#   62781,
#   97038,
#   48048,
#   54256,
#   87777,
#   102730,
#   128423,
#   47730,
#   49703,
#   46020,
#   25663,
#   6705,
#   85595,
#   27749,
#   74452,
#   21014,
#   28905,
#   25663,
#   28425,
#   33564,
#   16865,
#   91814,
#   127816,
#   85595,
#   76305,
#   87777,
#   44640,
#   55069,
#   59418,
#   52475,
#   59899,
#   45099,
#   51286,
#   48098],
#  [37681,
#   75214,
#   91240,
#   122661,
#   96804,
#   80401,
#   75523,
#   44678,
#   75094,
#   26124,
#   96928,
#   5050,
#   75214,
#   98355,
#   124435,
#   2114,
#   67553,
#   91814,
#   44678,
#   25396,
#   75094,
#   85595,
#   15538,
#   121643,
#   47920,
#   92997,
#   19295,
#   85890,
#   28152,
#   68288,
#   96757,
#   50595,
#   24863,
#   58713,
#   75214,
#   47920,
#   35272,
#   69044,
#   28702,
#   14371,
#   51847,
#   91814,
#   119338,
#   61578],
#  [38888,
#   30489,
#   128423,
#   78625,
#   69396,
#   27365,
#   45234,
#   69449,
#   22585,
#   38666,
#   53564,
#   32734,
#   40168,
#   85595,
#   125471,
#   49703,
#   85595,
#   77333,
#   30489,
#   51286,
#   2823,
#   119461,
#   102730,
#   53564,
#   62184,
#   33025,
#   55775,
#   73758,
#   45099,
#   64910,
#   55775,
#   117454,
#   66553,
#   35182,
#   128423,
#   82033,
#   116777,
#   26525,
#   88685,
#   14333,
#   102730,
#   69766,
#   116768,
#   62184,
#   45099,
#   32734,
#   80083,
#   87713,
#   22585,
#   53564,
#   74021,
#   107802,
#   95479,
#   52565,
#   93780,
#   23098,
#   28294,
#   60607,
#   107117,
#   46066,
#   66553,
#   69811,
#   30489,
#   32734,
#   80093,
#   45726,
#   49703,
#   64743,
#   23098,
#   69449,
#   60982],
#  ...]

# %%
max_len = len(max(X, key=len))
X = sequence.pad_sequences(X, maxlen=max_len)
X
# Out:
# array([[     0,      0,      0, ...,  19467,  40617, 124069],
#        [     0,      0,      0, ..., 125356,  85595,  49020],
#        [     0,      0,      0, ...,  21166,  27533,  93277],
#        ...,
#        [     0,      0,      0, ...,   7841,  19381,  65351],
#        [     0,      0,      0, ...,  58864,  85103, 104767],
#        [     0,      0,      0, ...,  20285,  33761,  85886]])

# %%
from sklearn.model_selection import train_test_split
y = df["label"]

X = np.array(X)
y = np.array(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.3, shuffle = True)
X_train
# Out:
# array([[     0,      0,      0, ..., 119850,  69810,   2530],
#        [     0,      0,      0, ...,  33080,  25496,  44280],
#        [     0,      0,      0, ...,  53899,  69396,  84799],
#        ...,
#        [     0,      0,      0, ...,  98337, 104651,  24173],
#        [     0,      0,      0, ...,  17627,  58081,  32133],
#        [     0,      0,      0, ...,  97297,  97228,  36380]])

# %%
del(df, comments)

# %%
del(unique_words, temp, labels, tokenized_comments)

# %%
del(flatten_comments)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

Cs = [0.01, 1, 100]

for c in Cs:
    logisticRegr = LogisticRegression(C = c)
    logisticRegr.fit(X_train, y_train)
    print(f"C: {c} , acurracy: {logisticRegr.score(X_test, y_test)}")
# Out:
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C: 0.01 , acurracy: 0.5950157901963476
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C: 1 , acurracy: 0.5940546478099684
# C: 100 , acurracy: 0.5953590553343402
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Naive Bayes

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, log_loss, classification_report
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB, ComplementNB
classifiers = [
    GaussianNB(),
    MultinomialNB(),
    BernoulliNB(),
    ComplementNB(),               
                  ]
 
# Logging for Visual Comparison
log_cols=["Classifier", "Accuracy", "Log Loss"]
log = pd.DataFrame(columns=log_cols)
 
for clf in classifiers:
    clf.fit(X_train, y_train)
    name = clf.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = clf.predict(X_test)
    acc = accuracy_score(y_test, train_predictions)
    print("Accuracy: {:.4%}".format(acc))
    
    log_entry = pd.DataFrame([[name, acc*100, 11]], columns=log_cols)
    log = log.append(log_entry)
    
    print("="*30)
# Out:
# ==============================
# GaussianNB
# ****Results****
# Accuracy: 50.9337%
# ==============================
# ==============================
# MultinomialNB
# ****Results****
# Accuracy: 55.9659%
# ==============================
# ==============================
# BernoulliNB
# ****Results****
# Accuracy: 59.4810%
# ==============================
# ==============================
# ComplementNB
# ****Results****
# Accuracy: 55.9659%
# ==============================

# %% [markdown]
# ## Decision Tree (Random Forest, Adamboost)

# %%
from sklearn.ensemble import RandomForestClassifier

max_depths = [2, 5, 7, 10]
max_features = ["sqrt", "log2"]

for max_depth in max_depths:
    for n_feat in max_features:
        rfc = RandomForestClassifier(max_depth = max_depth, max_features = n_feat)
        rfc.fit(X_train, y_train)
        print(f"Max Depth: {max_depth}, Max features: {n_feat}, Accuracy: {rfc.score(X_test, y_test)}")
# Out:
# Max Depth: 2, Max features: sqrt, Accuracy: 0.6127282713167651
# Max Depth: 2, Max features: log2, Accuracy: 0.6141013318687354
# Max Depth: 5, Max features: sqrt, Accuracy: 0.6316765069339558
# Max Depth: 5, Max features: log2, Accuracy: 0.6173280241658657
# Max Depth: 7, Max features: sqrt, Accuracy: 0.6453384594260607
# Max Depth: 7, Max features: log2, Accuracy: 0.62453659206371
# Max Depth: 10, Max features: sqrt, Accuracy: 0.6833035836880407
# Max Depth: 10, Max features: log2, Accuracy: 0.6397089111629823

# %%
from sklearn.ensemble import AdaBoostClassifier

n_estimators_array = [10, 50, 100]
learning_rates = [0.1, 0.5, 1]

# The base estimator is Desicion Tree Classifier
for n_estimators in n_estimators_array:
    for lr in learning_rates:
        adc = AdaBoostClassifier(n_estimators = n_estimators, learning_rate = lr)
        adc.fit(X_train, y_train)
        print(f"Number of estimators: {n_estimators}, Learning rate: {lr}, Accuracy: {adc.score(X_test, y_test)}")
# Out:
# Number of estimators: 10, Learning rate: 0.1, Accuracy: 0.6126596182891666
# Number of estimators: 10, Learning rate: 0.5, Accuracy: 0.6459563366744473
# Number of estimators: 10, Learning rate: 1, Accuracy: 0.6706714266099135
# Number of estimators: 50, Learning rate: 0.1, Accuracy: 0.6708087326651105
# Number of estimators: 50, Learning rate: 0.5, Accuracy: 0.7358918028285047
# Number of estimators: 50, Learning rate: 1, Accuracy: 0.7694631333241796
# Number of estimators: 100, Learning rate: 0.1, Accuracy: 0.6995056982012907
# Number of estimators: 100, Learning rate: 0.5, Accuracy: 0.7798297404915556
# Number of estimators: 100, Learning rate: 1, Accuracy: 0.7975422216119731

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

kernels = ['rbf', 'poly', 'linear' , 'sigmoid']
cs = [0.01, 1, 10]

# decision tree does not need scaled data to perform better
# the same applies to all ensembling methods using desicion tree as base estimator
for kernel in kernels:
    for c in cs:
        svc = SVC(kernel = kernel, C = c, max_iter = 500)
        svc.fit(X_train, y_train)
        print(f"Kernel: {kernel}, C: {c}, Accuracy: {svc.score(X_test, y_test)}")
# Out:
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: rbf, C: 0.01, Accuracy: 0.6032541535081697
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: rbf, C: 1, Accuracy: 0.6014691747906082
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: rbf, C: 10, Accuracy: 0.5946038720307566
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: poly, C: 0.01, Accuracy: 0.5034326513799259
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: poly, C: 1, Accuracy: 0.5083756693670191
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: poly, C: 10, Accuracy: 0.5349443910476452
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: linear, C: 0.01, Accuracy: 0.5209391734175477
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: linear, C: 1, Accuracy: 0.5209391734175477
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: linear, C: 10, Accuracy: 0.5209391734175477
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: sigmoid, C: 0.01, Accuracy: 0.4088287793491693
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: sigmoid, C: 1, Accuracy: 0.4312783193738844
# C:\Users\zazat\anaconda3\envs\tensorflow\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Kernel: sigmoid, C: 10, Accuracy: 0.4318275435946725

# %% [markdown]
# ## Fully Connected NN without Embedding layer

# %%
# Import the dependencies
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense, LSTM, Flatten, Dropout, Conv1D, MaxPooling1D, GRU, Bidirectional
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
import numpy as np

# %%
len(X_train[20])
# Out:
# 989

# %%
X_train
# Out:
# array([[     0,      0,      0, ..., 119850,  69810,   2530],
#        [     0,      0,      0, ...,  33080,  25496,  44280],
#        [     0,      0,      0, ...,  53899,  69396,  84799],
#        ...,
#        [     0,      0,      0, ...,  98337, 104651,  24173],
#        [     0,      0,      0, ...,  17627,  58081,  32133],
#        [     0,      0,      0, ...,  97297,  97228,  36380]])

# %%
model = Sequential()
model.add(Dense(20, activation='relu', input_dim=len(X_train[0])))
model.add(Dropout(0.3))
model.add(Dense(30, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                19800
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_1 (Dense)             (None, 30)                630
#
#  dropout_1 (Dropout)         (None, 30)                0
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 20,461
# Trainable params: 20,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=10, batch_size=64)
# Out:
# Epoch 1/10
# 532/532 [==============================] - 1s 1ms/step - loss: 127.7631 - accuracy: 0.5315
# Epoch 2/10
# 532/532 [==============================] - 1s 1ms/step - loss: 1.1683 - accuracy: 0.5130
# Epoch 3/10
# 532/532 [==============================] - 1s 1ms/step - loss: 0.7701 - accuracy: 0.5036
# Epoch 4/10
# 532/532 [==============================] - 1s 1ms/step - loss: 0.7314 - accuracy: 0.5001
# Epoch 5/10
# 532/532 [==============================] - 1s 1ms/step - loss: 0.8202 - accuracy: 0.5006
# Epoch 6/10
# 532/532 [==============================] - 1s 1ms/step - loss: 0.7048 - accuracy: 0.4980
# Epoch 7/10
# 532/532 [==============================] - 1s 1ms/step - loss: 0.6927 - accuracy: 0.4990
# Epoch 8/10
# 532/532 [==============================] - 1s 1ms/step - loss: 0.6972 - accuracy: 0.5001
# Epoch 9/10
# 532/532 [==============================] - 1s 1ms/step - loss: 0.6928 - accuracy: 0.5010
# Epoch 10/10
# 532/532 [==============================] - 1s 1ms/step - loss: 0.6983 - accuracy: 0.5022

# %%
model_scores = model.evaluate(X_test, y_test, verbose=0)

# Print out the accuracy of the model on the test set
print("Model accuracy on the test dataset: {0:.2f}%".format(model_scores[1]*100))
# Out:
# Model accuracy on the test dataset: 49.67%

# %%
max_review_length = len(X_train[0])
max_words = len(WordsForids)

# %% [markdown]
# # Using Embedding Layer

# %% [markdown]
# ## Fully Connected NN

# %%
# Define the layers in the model
embedding_vector_length = 32

# Define the layers in the model
model = Sequential()
model.add(Embedding(max_words, embedding_vector_length, input_length=max_review_length))
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 989, 32)           4118304
#
#  flatten (Flatten)           (None, 31648)             0
#
#  dense_3 (Dense)             (None, 30)                949470
#
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_4 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,067,805
# Trainable params: 5,067,805
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=3, batch_size=64)
# Out:
# Epoch 1/3
# 532/532 [==============================] - 20s 37ms/step - loss: 0.4098 - accuracy: 0.8393
# Epoch 2/3
# 532/532 [==============================] - 20s 37ms/step - loss: 0.0973 - accuracy: 0.9695
# Epoch 3/3
# 532/532 [==============================] - 19s 37ms/step - loss: 0.0370 - accuracy: 0.9897

# %%
model_scores = model.evaluate(X_test, y_test, verbose=0)

# Print out the accuracy of the model on the test set
print("Model accuracy on the test dataset: {0:.2f}%".format(model_scores[1]*100))
# Out:
# Model accuracy on the test dataset: 95.61%

# %% [markdown]
# # CNN

# %%
# Define the layers in the model
embedding_vector_length = 32

# Define the layers in the model
model = Sequential()
model.add(Embedding(max_words, embedding_vector_length, input_length=max_review_length))
model.add(Conv1D(30, kernel_size = 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 989, 32)           4118304
#
#  conv1d (Conv1D)             (None, 987, 30)           2910
#
#  max_pooling1d (MaxPooling1D  (None, 493, 30)          0
#  )
#
#  flatten_1 (Flatten)         (None, 14790)             0
#
#  dense_5 (Dense)             (None, 30)                443730
#
#  dropout_3 (Dropout)         (None, 30)                0
#
#  dense_6 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 4,564,975
# Trainable params: 4,564,975
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=3, batch_size=64)
# Out:
# Epoch 1/3
# 532/532 [==============================] - 31s 56ms/step - loss: 0.2240 - accuracy: 0.9030
# Epoch 2/3
# 532/532 [==============================] - 30s 56ms/step - loss: 0.0638 - accuracy: 0.9805
# Epoch 3/3
# 532/532 [==============================] - 30s 56ms/step - loss: 0.0256 - accuracy: 0.9934

# %%
model_scores = model.evaluate(X_test, y_test, verbose=0)

# Print out the accuracy of the model on the test set
print("Model accuracy on the test dataset: {0:.2f}%".format(model_scores[1]*100))
# Out:
# Model accuracy on the test dataset: 95.52%

# %% [markdown]
# # RNN (using LSTM)

# %%
# Define the layers in the model
model = Sequential()
model.add(Embedding(max_words, embedding_vector_length, input_length=max_review_length))
model.add(LSTM(20))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 989, 32)           4118304
#
#  lstm (LSTM)                 (None, 20)                4240
#
#  dense_7 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 4,122,565
# Trainable params: 4,122,565
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=3, batch_size=64)
# Out:
# Epoch 1/3
# 532/532 [==============================] - 112s 207ms/step - loss: 0.2459 - accuracy: 0.9173
# Epoch 2/3
# 532/532 [==============================] - 109s 205ms/step - loss: 0.0852 - accuracy: 0.9741
# Epoch 3/3
# 532/532 [==============================] - 110s 206ms/step - loss: 0.0375 - accuracy: 0.9897

# %%
model_scores = model.evaluate(X_test, y_test, verbose=0)

# Print out the accuracy of the model on the test set
print("Model accuracy on the test dataset: {0:.2f}%".format(model_scores[1]*100))
# Out:
# Model accuracy on the test dataset: 96.31%

# %% [markdown]
# ## CNN-RNN(using GRU) Hybrid

# %%
embedding_vector_length = 32

# Define the layers in the model
model = Sequential()
model.add(Embedding(max_words, embedding_vector_length, input_length=max_review_length))
model.add(Conv1D(30, kernel_size = 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(GRU(20))
model.add(Dense(20, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 989, 32)           4118304
#
#  conv1d_1 (Conv1D)           (None, 987, 30)           2910
#
#  max_pooling1d_1 (MaxPooling  (None, 493, 30)          0
#  1D)
#
#  gru (GRU)                   (None, 20)                3120
#
#  dense_8 (Dense)             (None, 20)                420
#
#  dropout_4 (Dropout)         (None, 20)                0
#
#  dense_9 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 4,124,775
# Trainable params: 4,124,775
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=3, batch_size=64)
# Out:
# Epoch 1/3
# 532/532 [==============================] - 80s 148ms/step - loss: 0.2421 - accuracy: 0.9114
# Epoch 2/3
# 532/532 [==============================] - 78s 147ms/step - loss: 0.0790 - accuracy: 0.9752
# Epoch 3/3
# 532/532 [==============================] - 78s 147ms/step - loss: 0.0341 - accuracy: 0.9896

# %%
model_scores = model.evaluate(X_test, y_test, verbose=0)

# Print out the accuracy of the model on the test set
print("Model accuracy on the test dataset: {0:.2f}%".format(model_scores[1]*100))
# Out:
# Model accuracy on the test dataset: 95.26%
